# %%
import matplotlib.pyplot as plt
import gensim
import numpy as np
import spacy

from gensim.models import LdaModel
from gensim.models.wrappers import LdaMallet
from gensim.corpora import Dictionary
import pyLDAvis.gensim
import wikipedia
import re

import warnings
warnings.filterwarnings('ignore')  # Let's not pay heed to them right now
# %matplotlib inline

# %%
# We'll first create a list of articles

# %%
taj=wikipedia.page('Taj Mahal').content
covid=wikipedia.page('COvid 19 pandemic').content
sports=wikipedia.page('Cricket').content
data=wikipedia.page('Data Science').content

# %%
text=[taj, covid, sports, data]

# %%
text
# Out:
# ['The Taj Mahal (; lit.  \'Crown of the Palace\', [taːdʒ ˈmɛːɦ(ə)l]) is an ivory-white marble mausoleum on the southern bank of the river Yamuna  in the Indian city of Agra. It was commissioned in 1632 by the Mughal emperor Shah Jahan (reigned from 1628 to 1658) to house the tomb of his favourite wife, Mumtaz Mahal; it also houses the tomb of Shah Jahan himself. The tomb is the centrepiece of a 17-hectare (42-acre) complex, which includes a mosque and a guest house, and is set in formal gardens bounded on three sides by a crenellated wall.\nConstruction of the mausoleum was essentially completed in 1643, but work continued on other phases of the project for another 10 years. The Taj Mahal complex is believed to have been completed in its entirety in 1653 at a cost estimated at the time to be around 32 million rupees, which in 2020 would be approximately 70 billion rupees (about U.S. $916 million). The construction project employed some 20,000 artisans under the guidance of a board of architects led by the court architect to the emperor, Ustad Ahmad Lahauri.\nThe Taj Mahal was designated as a UNESCO World Heritage Site in 1983 for being "the jewel of Muslim art in India and one of the universally admired masterpieces of the world\'s heritage". It is regarded by many as the best example of Mughal architecture and a symbol of India\'s rich history. The Taj Mahal attracts 7–8 million visitors a year and in 2007, it was declared a winner of the New 7 Wonders of the World (2000–2007) initiative.\n\n\n== Inspiration ==\nThe Taj Mahal was commissioned by Shah Jahan in 1631, to be built in the memory of his wife Mumtaz Mahal, who died on 17 June that year, while giving birth to their 14th child, Gauhara Begum. Construction started in 1632, and the mausoleum was completed in 1648, while the surrounding buildings and garden were finished five years later. The imperial court documenting Shah Jahan\'s grief after the death of Mumtaz Mahal illustrates the love story held as the inspiration for the Taj Mahal.\n\n\n== Architecture and design ==\n\nThe Taj Mahal incorporates and expands on design traditions of Persian and earlier Mughal architecture. Specific inspiration came from successful Timurid and Mughal buildings including the Gur-e Amir (the tomb of Timur, progenitor of the Mughal dynasty, in Samarkand), Humayun\'s Tomb which inspired the Charbagh gardens and hasht-behesht (architecture) plan of the site, Itmad-Ud-Daulah\'s Tomb (sometimes called the Baby Taj), and Shah Jahan\'s own Jama Masjid in Delhi. While earlier Mughal buildings were primarily constructed of red sandstone, Shah Jahan promoted the use of white marble inlaid with semi-precious stones. Buildings under his patronage reached new levels of refinement.\n\n\n=== Tomb ===\nThe tomb is the central focus of the entire complex of the Taj Mahal. It is a large, white marble structure standing on a square plinth and consists of a symmetrical building with an iwan (an arch-shaped doorway) topped by a large dome and finial. Like most Mughal tombs, the basic elements are Persian in origin.The base structure is a large multi-chambered cube with chamfered corners forming an unequal eight-sided structure that is approximately 55 metres (180 ft) on each of the four long sides. Each side of the iwan is framed with a huge pishtaq or vaulted archway with two similarly shaped arched balconies stacked on either side. This motif of stacked pishtaqs is replicated on the chamfered corner areas, making the design completely symmetrical on all sides of the building. Four minarets frame the tomb, one at each corner of the plinth facing the chamfered corners. The main chamber houses the false sarcophagi of Mumtaz Mahal and Shah Jahan; the actual graves are at a lower level.\n\nThe most spectacular feature is the marble dome that surmounts the tomb. The dome is nearly 35 metres (115 ft) high which is close in measurement to the length of the base, and accentuated by the cylindrical "drum" it sits  ...
#  'The COVID‑19 pandemic, also known as the coronavirus pandemic, is an ongoing pandemic of coronavirus disease 2019 (COVID‑19) caused by severe acute respiratory syndrome coronavirus 2 (SARS‑CoV‑2). The disease was first identified in December 2019 in Wuhan, China. The World Health Organization declared the outbreak a Public Health Emergency of International Concern on 30 January 2020 and a pandemic on 11 March. As of 19 September 2020, more than 30.5 million cases have been reported in 188 countries and territories, resulting in more than 952,000 deaths; more than 20.7 million people have recovered.\n\nCommon symptoms include fever, cough, fatigue, shortness of breath or breathing difficulties, and loss of smell. Complications may include pneumonia and acute respiratory distress syndrome. The incubation period is typically around five days but may range from one to 14 days. There are several vaccine candidates in development, although none have completed clinical trials to prove their safety and efficacy. There is no known specific antiviral medication, so primary treatment is currently symptomatic.Recommended preventive measures include hand washing, covering mouth when coughing, social distancing, wearing a face mask in public, disinfecting surfaces, ventilating and air-filtering, and monitoring and self-isolation for people who suspect they may be infected. Authorities worldwide have responded by implementing travel restrictions, lockdowns, workplace hazard controls, and facility closures to slow the spread of the disease. Many places have also worked to increase testing capacity and trace contacts of the infected.\nThe pandemic has caused global social and economic disruption, including the largest global recession since the Great Depression. According to estimations, up to 100 million people have fallen into extreme poverty and global famines are affecting 130 million people. It has led to the postponement or cancellation of sporting, religious, political, and cultural events, widespread supply shortages exacerbated by panic buying, and decreased emissions of pollutants and greenhouse gases. Educational institutions have been partially or fully closed, with many switching to online schooling. Misinformation about the virus has circulated through social media and mass media. There have been incidents of xenophobia and discrimination against Chinese people and against those perceived as being Chinese or as being from areas with high infection rates.\n\n\n== Epidemiology ==\n\n\n=== Background ===\nOn 31 December 2019, the World Health Organization (WHO) received reports of a cluster of viral pneumonia cases of unknown cause in Wuhan, Hubei, and an investigation was launched at the start of January 2020. On 30 January, with 7,818 confirmed cases across 19 countries, the WHO declared the outbreak a Public Health Emergency of International Concern (PHEIC).Several early infected people had visited Huanan Seafood Wholesale Market; the virus is therefore thought to be of zoonotic origin. The virus that caused the outbreak is known as SARS‑CoV‑2, a newly discovered virus closely related to bat coronaviruses, pangolin coronaviruses, and SARS-CoV. The scientific consensus is that COVID-19 has a natural origin. The probable bat-to-human infection may have been among people processing bat carcasses and guano in the production of traditional Chinese medicines.The earliest known person with symptoms was later discovered to have fallen ill on 1 December 2019, and that person did not have visible connections with the later wet market cluster. Of the early cluster of cases reported that month, two-thirds were found to have a link with the market. On 13 March 2020, an unverified report from the South China Morning Post suggested a case traced back to 17 November 2019 (a 55-year-old from Hubei) may have been the first person infected. Phylogenic estimates in genetic studies conducted in early 2020 indicate that the SARS-CoV-2 virus likely j ...
#  'Cricket is a bat-and-ball game played between two teams of eleven players on a field at the centre of which is a 22-yard (20-metre) pitch with a wicket at each end, each comprising two bails balanced on three stumps. The batting side scores runs by striking the ball bowled at the wicket with the bat (and running between the wickets), while the bowling and fielding side tries to prevent this (by preventing the ball from leaving the field, and getting the ball to either wicket) and dismiss each batter (so they are "out"). Means of dismissal include being bowled, when the ball hits the stumps and dislodges the bails, and by the fielding side either catching the ball after it is hit by the bat, but before it hits the ground, or hitting a wicket with the ball before a batter can cross the crease in front of the wicket. When ten batters have been dismissed, the innings ends and the teams swap roles. The game is adjudicated by two umpires, aided by a third umpire and match referee in international matches. They communicate with two off-field scorers who record the match\'s statistical information.\nForms of cricket range from Twenty20, with each team batting for a single innings of 20 overs, to Test matches played over five days. Traditionally cricketers play in all-white kit, but in limited overs cricket they wear club or team colours. In addition to the basic kit, some players wear protective gear to prevent injury caused by the ball, which is a hard, solid spheroid made of compressed leather with a slightly raised sewn seam enclosing a cork core layered with tightly wound string.\nThe earliest reference to cricket is in South East England in the mid-16th century. It spread globally with the expansion of the British Empire, with the first international matches in the second half of the 19th century. The game\'s governing body is the International Cricket Council (ICC), which has over 100 members, twelve of which are full members who play Test matches. The game\'s rules, the Laws of Cricket, are maintained by Marylebone Cricket Club (MCC) in London. The sport is followed primarily in the Indian subcontinent, Australasia, the United Kingdom, southern Africa and the West Indies. Women\'s cricket, which is organised and played separately, has also achieved international standard. The most successful side playing international cricket is Australia, which has won seven One Day International trophies, including five World Cups, more than any other country and has been the top-rated Test side more than any other country.\n\n\n== History ==\n\n\n=== Origins ===\n\nCricket is one of many games in the "club ball" sphere that basically involve hitting a ball with a hand-held implement; others include baseball (which shares many similarities with cricket, both belonging in the more specific bat-and-ball games category), golf, hockey, tennis, squash, badminton and table tennis. In cricket\'s case, a key difference is the existence of a solid target structure, the wicket (originally, it is thought, a "wicket gate" through which sheep were herded), that the batsman must defend. The cricket historian Harry Altham identified three "groups" of "club ball" games: the "hockey group", in which the ball is driven to and fro between two targets (the goals); the "golf group", in which the ball is driven towards an undefended target (the hole); and the "cricket group", in which "the ball is aimed at a mark (the wicket) and driven away from it".It is generally believed that cricket originated as a children\'s game in the south-eastern counties of England, sometime during the medieval period. Although there are claims for prior dates, the earliest definite reference to cricket being played comes from evidence given at a court case in Guildford on Monday, 17 January 1597 (Julian calendar; equating to 30 January 1598 in the Gregorian calendar). The case concerned ownership of a certain plot of land and the court heard the testimony of a 59-year-old coroner, J ...
#  'Data science is an inter-disciplinary field that uses scientific methods, processes, algorithms and systems to extract knowledge and insights from many structural and unstructured data. Data science is related to data mining, machine learning and big data.\nData science is a "concept to unify statistics, data analysis and their related methods" in order to "understand and analyze actual phenomena" with data. It uses techniques and theories drawn from many fields within the context of mathematics, statistics, computer science, domain knowledge and information science. Turing award winner Jim Gray imagined data science as a "fourth paradigm" of science (empirical, theoretical, computational and now data-driven) and asserted that "everything about science is changing because of the impact of information technology" and the data deluge.\n\n\n== Foundations ==\nData science is an interdisciplinary field focused on extracting knowledge from data sets, which are typically large (see big data). The field encompasses analysis, preparing data for analysis, and presenting findings to inform high-level decisions in an organization. As such, it incorporates skills from computer science, mathematics, statistics, information visualization, graphic design, complex systems, communication and business. Statistician Nathan Yau, drawing on Ben Fry, also links data science to human-computer interaction: users should be able to intuitively control and explore data. In 2015, the American Statistical Association identified database management, statistics and machine learning, and distributed and parallel systems as the three emerging foundational professional communities.\n\n\n=== Relationship to statistics ===\nMany statisticians, including Nate Silver, have argued that data science is not a new field, but rather another name for statistics. Others argue that data science is distinct from statistics because it focuses on problems and techniques unique to digital data. Vasant Dhar writes that statistics emphasizes quantitative data and description. In contrast, data science deals with quantitative and qualitative data (e.g. images) and emphasizes prediction and action. Andrew Gelman of Columbia University and data scientist Vincent Granville have described statistics as a nonessential part of data science.\nStanford professor David Donoho writes that data science is not distinguished from statistics by the size of datasets or use of computing, and that many graduate programs misleadingly advertise their analytics and statistics training as the essence of a data science program. He describes data science as an applied field growing out of traditional statistics. \nIn summary, data science can be therefore described as an applied branch of statistics.\n\n\n== Etymology ==\n\n\n=== Early usage ===\nIn 1962, John Tukey described a field he called “data analysis,” which resembles modern data science. Later, attendees at a 1992 statistics symposium at the University of Montpellier II acknowledged the emergence of a new discipline focused on data of various origins and forms, combining established concepts and principles of statistics and data analysis with computing.The term “data science” has been traced back to 1974, when Peter Naur proposed it as an alternative name for computer science. In 1996, the International Federation of Classification Societies became the first conference to specifically feature data science as a topic. However, the definition was still in flux. In 1997, C.F. Jeff Wu suggested that statistics should be renamed data science. He reasoned that a new name would help statistics shed inaccurate stereotypes, such as being synonymous with accounting, or limited to describing data. In 1998, Chikio Hayashi argued for data science as a new, interdisciplinary concept, with three aspects: data design, collection, and analysis.During the 1990s, popular terms for the process of finding patterns in datasets (which were increasingly large) inc ...

# %%
def decontracted(phrase):
    # specific
    phrase = re.sub(r"won't", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

# %%
def clean(sent):
    sent=decontracted(sent)
    sent=re.sub(r'https?://\S+', '', sent)
    sent=re.sub(r'[\w\.-]+@[\w\.-]+', '', sent)
    sent = re.sub("\S*\d\S*", "", sent)
    sent=re.sub(r'[^A-Za-z0-9]+', ' ', sent)
    sent=sent.lower()
    sent=sent.translate(str.maketrans('', '', '"#%&\'()*+,-./:;<=>@[\\]^_`{|}~'))
    sent = ' '.join(e for e in sent.split() if len(e)>1)

    return sent

# %%
cleaned_taj=clean(taj)

# %%
cleaned_taj
# Out:
# 'the taj mahal lit crown of the palace ta is an ivory white marble mausoleum on the southern bank of the river yamuna in the indian city of agra it was commissioned in by the mughal emperor shah jahan reigned from to to house the tomb of his favourite wife mumtaz mahal it also houses the tomb of shah jahan himself the tomb is the centrepiece of complex which includes mosque and guest house and is set in formal gardens bounded on three sides by crenellated wall construction of the mausoleum was essentially completed in but work continued on other phases of the project for another years the taj mahal complex is believed to have been completed in its entirety in at cost estimated at the time to be around million rupees which in would be approximately billion rupees about million the construction project employed some artisans under the guidance of board of architects led by the court architect to the emperor ustad ahmad lahauri the taj mahal was designated as unesco world heritage site in for being the jewel of muslim art in india and one of the universally admired masterpieces of the world is heritage it is regarded by many as the best example of mughal architecture and symbol of india is rich history the taj mahal attracts million visitors year and in it was declared winner of the new wonders of the world initiative inspiration the taj mahal was commissioned by shah jahan in to be built in the memory of his wife mumtaz mahal who died on june that year while giving birth to their child gauhara begum construction started in and the mausoleum was completed in while the surrounding buildings and garden were finished five years later the imperial court documenting shah jahan is grief after the death of mumtaz mahal illustrates the love story held as the inspiration for the taj mahal architecture and design the taj mahal incorporates and expands on design traditions of persian and earlier mughal architecture specific inspiration came from successful timurid and mughal buildings including the gur amir the tomb of timur progenitor of the mughal dynasty in samarkand humayun is tomb which inspired the charbagh gardens and hasht behesht architecture plan of the site itmad ud daulah is tomb sometimes called the baby taj and shah jahan is own jama masjid in delhi while earlier mughal buildings were primarily constructed of red sandstone shah jahan promoted the use of white marble inlaid with semi precious stones buildings under his patronage reached new levels of refinement tomb the tomb is the central focus of the entire complex of the taj mahal it is large white marble structure standing on square plinth and consists of symmetrical building with an iwan an arch shaped doorway topped by large dome and finial like most mughal tombs the basic elements are persian in origin the base structure is large multi chambered cube with chamfered corners forming an unequal eight sided structure that is approximately metres ft on each of the four long sides each side of the iwan is framed with huge pishtaq or vaulted archway with two similarly shaped arched balconies stacked on either side this motif of stacked pishtaqs is replicated on the chamfered corner areas making the design completely symmetrical on all sides of the building four minarets frame the tomb one at each corner of the plinth facing the chamfered corners the main chamber houses the false sarcophagi of mumtaz mahal and shah jahan the actual graves are at lower level the most spectacular feature is the marble dome that surmounts the tomb the dome is nearly metres ft high which is close in measurement to the length of the base and accentuated by the cylindrical drum it sits on which is approximately metres ft high because of its shape the dome is often called an onion dome or amrud guava dome the top is decorated with lotus design which also serves to accentuate its height the shape of the dome is emphasised by four smaller domed chattris kiosks placed at its corners which replicate the on ...

# %%
cleaned_covid=clean(covid)
cleaned_sports=clean(sports)
cleaned_data=clean(data)

# %%
# cleaned=cleaned_taj + cleaned_covid + cleaned_data + cleaned_sports

# %%
# cleaned

# %%
nlp = spacy.load("en")
doc_taj=nlp(cleaned_taj)

# %%
doc_taj
# Out:
# the taj mahal lit crown of the palace ta is an ivory white marble mausoleum on the southern bank of the river yamuna in the indian city of agra it was commissioned in by the mughal emperor shah jahan reigned from to to house the tomb of his favourite wife mumtaz mahal it also houses the tomb of shah jahan himself the tomb is the centrepiece of complex which includes mosque and guest house and is set in formal gardens bounded on three sides by crenellated wall construction of the mausoleum was essentially completed in but work continued on other phases of the project for another years the taj mahal complex is believed to have been completed in its entirety in at cost estimated at the time to be around million rupees which in would be approximately billion rupees about million the construction project employed some artisans under the guidance of board of architects led by the court architect to the emperor ustad ahmad lahauri the taj mahal was designated as unesco world heritage site in for being the jewel of muslim art in india and one of the universally admired masterpieces of the world is heritage it is regarded by many as the best example of mughal architecture and symbol of india is rich history the taj mahal attracts million visitors year and in it was declared winner of the new wonders of the world initiative inspiration the taj mahal was commissioned by shah jahan in to be built in the memory of his wife mumtaz mahal who died on june that year while giving birth to their child gauhara begum construction started in and the mausoleum was completed in while the surrounding buildings and garden were finished five years later the imperial court documenting shah jahan is grief after the death of mumtaz mahal illustrates the love story held as the inspiration for the taj mahal architecture and design the taj mahal incorporates and expands on design traditions of persian and earlier mughal architecture specific inspiration came from successful timurid and mughal buildings including the gur amir the tomb of timur progenitor of the mughal dynasty in samarkand humayun is tomb which inspired the charbagh gardens and hasht behesht architecture plan of the site itmad ud daulah is tomb sometimes called the baby taj and shah jahan is own jama masjid in delhi while earlier mughal buildings were primarily constructed of red sandstone shah jahan promoted the use of white marble inlaid with semi precious stones buildings under his patronage reached new levels of refinement tomb the tomb is the central focus of the entire complex of the taj mahal it is large white marble structure standing on square plinth and consists of symmetrical building with an iwan an arch shaped doorway topped by large dome and finial like most mughal tombs the basic elements are persian in origin the base structure is large multi chambered cube with chamfered corners forming an unequal eight sided structure that is approximately metres ft on each of the four long sides each side of the iwan is framed with huge pishtaq or vaulted archway with two similarly shaped arched balconies stacked on either side this motif of stacked pishtaqs is replicated on the chamfered corner areas making the design completely symmetrical on all sides of the building four minarets frame the tomb one at each corner of the plinth facing the chamfered corners the main chamber houses the false sarcophagi of mumtaz mahal and shah jahan the actual graves are at lower level the most spectacular feature is the marble dome that surmounts the tomb the dome is nearly metres ft high which is close in measurement to the length of the base and accentuated by the cylindrical drum it sits on which is approximately metres ft high because of its shape the dome is often called an onion dome or amrud guava dome the top is decorated with lotus design which also serves to accentuate its height the shape of the dome is emphasised by four smaller domed chattris kiosks placed at its corners which replicate the oni ...

# %%
# nlp = spacy.load("en")
doc_covid=nlp(cleaned_covid)

nlp = spacy.load("en")
doc_sports=nlp(cleaned_sports)

nlp = spacy.load("en")
doc_data=nlp(cleaned_data)

# %%
article_taj = []
for w in doc_taj:
    # if it's not a stop word or punctuation mark, add it to our article
    if not w.is_stop and not w.is_punct and not w.like_num:
        # we add the lematized version of the word
        article_taj.append(w.lemma_)
        
article_covid = []
for w in doc_covid:
    # if it's not a stop word or punctuation mark, add it to our article
    if not w.is_stop and not w.is_punct and not w.like_num:
        # we add the lematized version of the word
        article_covid.append(w.lemma_)
        
        
article_data = []
for w in doc_data:
    # if it's not a stop word or punctuation mark, add it to our article
    if not w.is_stop and not w.is_punct and not w.like_num:
        # we add the lematized version of the word
        article_data.append(w.lemma_)
        
        
article_sports = []
for w in doc_sports:
    # if it's not a stop word or punctuation mark, add it to our article
    if not w.is_stop and not w.is_punct and not w.like_num:
        # we add the lematized version of the word
        article_sports.append(w.lemma_)

# %%
article_taj
# Out:
# ['taj',
#  'mahal',
#  'light',
#  'crown',
#  'palace',
#  'ta',
#  'ivory',
#  'white',
#  'marble',
#  'mausoleum',
#  'southern',
#  'bank',
#  'river',
#  'yamuna',
#  'indian',
#  'city',
#  'agra',
#  'commission',
#  'mughal',
#  'emperor',
#  'shah',
#  'jahan',
#  'reign',
#  'house',
#  'tomb',
#  'favourite',
#  'wife',
#  'mumtaz',
#  'mahal',
#  'house',
#  'tomb',
#  'shah',
#  'jahan',
#  'tomb',
#  'centrepiece',
#  'complex',
#  'include',
#  'mosque',
#  'guest',
#  'house',
#  'set',
#  'formal',
#  'garden',
#  'bound',
#  'side',
#  'crenellate',
#  'wall',
#  'construction',
#  'mausoleum',
#  'essentially',
#  'complete',
#  'work',
#  'continue',
#  'phase',
#  'project',
#  'year',
#  'taj',
#  'mahal',
#  'complex',
#  'believe',
#  'complete',
#  'entirety',
#  'cost',
#  'estimate',
#  'time',
#  'rupee',
#  'approximately',
#  'rupee',
#  'construction',
#  'project',
#  'employ',
#  'artisan',
#  'guidance',
#  'board',
#  'architect',
#  'lead',
#  'court',
#  'architect',
#  'emperor',
#  'ustad',
#  'ahmad',
#  'lahauri',
#  'taj',
#  'mahal',
#  'designate',
#  'unesco',
#  'world',
#  'heritage',
#  'site',
#  'jewel',
#  'muslim',
#  'art',
#  'india',
#  'universally',
#  'admire',
#  'masterpiece',
#  'world',
#  'heritage',
#  'regard',
#  'good',
#  'example',
#  'mughal',
#  'architecture',
#  'symbol',
#  'india',
#  'rich',
#  'history',
#  'taj',
#  'mahal',
#  'attract',
#  'visitor',
#  'year',
#  'declare',
#  'winner',
#  'new',
#  'wonder',
#  'world',
#  'initiative',
#  'inspiration',
#  'taj',
#  'mahal',
#  'commission',
#  'shah',
#  'jahan',
#  'build',
#  'memory',
#  'wife',
#  'mumtaz',
#  'mahal',
#  'die',
#  'june',
#  'year',
#  'give',
#  'birth',
#  'child',
#  'gauhara',
#  'begum',
#  'construction',
#  'start',
#  'mausoleum',
#  'complete',
#  'surround',
#  'building',
#  'garden',
#  'finish',
#  'year',
#  'later',
#  'imperial',
#  'court',
#  'document',
#  'shah',
#  'jahan',
#  'grief',
#  'death',
#  'mumtaz',
#  'mahal',
#  'illustrate',
#  'love',
#  'story',
#  'hold',
#  'inspiration',
#  'taj',
#  'mahal',
#  'architecture',
#  'design',
#  'taj',
#  'mahal',
#  'incorporate',
#  'expand',
#  'design',
#  'tradition',
#  'persian',
#  'early',
#  'mughal',
#  'architecture',
#  'specific',
#  'inspiration',
#  'come',
#  'successful',
#  'timurid',
#  'mughal',
#  'building',
#  'include',
#  'gur',
#  'amir',
#  'tomb',
#  'timur',
#  'progenitor',
#  'mughal',
#  'dynasty',
#  'samarkand',
#  'humayun',
#  'tomb',
#  'inspire',
#  'charbagh',
#  'garden',
#  'hasht',
#  'behesht',
#  'architecture',
#  'plan',
#  'site',
#  'itmad',
#  'ud',
#  'daulah',
#  'tomb',
#  'call',
#  'baby',
#  'taj',
#  'shah',
#  'jahan',
#  'jama',
#  'masjid',
#  'delhi',
#  'early',
#  'mughal',
#  'building',
#  'primarily',
#  'construct',
#  'red',
#  'sandstone',
#  'shah',
#  'jahan',
#  'promote',
#  'use',
#  'white',
#  'marble',
#  'inlay',
#  'semi',
#  'precious',
#  'stone',
#  'building',
#  'patronage',
#  'reach',
#  'new',
#  'level',
#  'refinement',
#  'tomb',
#  'tomb',
#  'central',
#  'focus',
#  'entire',
#  'complex',
#  'taj',
#  'mahal',
#  'large',
#  'white',
#  'marble',
#  'structure',
#  'stand',
#  'square',
#  'plinth',
#  'consist',
#  'symmetrical',
#  'building',
#  'iwan',
#  'arch',
#  'shape',
#  'doorway',
#  'top',
#  'large',
#  'dome',
#  'finial',
#  'like',
#  'mughal',
#  'tomb',
#  'basic',
#  'element',
#  'persian',
#  'origin',
#  'base',
#  'structure',
#  'large',
#  'multi',
#  'chamber',
#  'cube',
#  'chamfer',
#  'corner',
#  'form',
#  'unequal',
#  'side',
#  'structure',
#  'approximately',
#  'metre',
#  'ft',
#  'long',
#  'side',
#  'iwan',
#  'frame',
#  'huge',
#  'pishtaq',
#  'vault',
#  'archway',
#  'similarly',
#  'shape',
#  'arched',
#  'balcony',
#  'stack',
#  'motif',
#  'stack',
#  'pishtaqs',
#  'replicate',
#  'chamfer',
#  'corner',
#  'area',
#  'make',
#  'design',
#  'completely',
#  'symmetrical',
#  'side',
#  'building',
#  'minaret',
#  'frame',
#  'tomb',
#  'corner',
#  'plinth',
#  'face',
#  'chamfer',
#  'corner',
#  'main',
#  'chamber',
#  'house',
#  'false',
#  'sarcophagi',
#  'mumtaz',
#  'mahal',
#  'shah',
#  'jahan',
#  'actual',
#  'grave',
#  'low',
#  'level',
#  'spectacular',
#  'feature',
#  'marble',
#  'dome',
#  'surmount',
#  'tomb',
#  'dome',
#  'nearly',
#  'metre',
#  'ft',
#  'high',
#  'close',
#  'measurement',
#  'length',
#  'base',
#  'accentuate',
#  'cylindrical',
#  'drum',
#  'sit',
#  'approximately',
#  'metre',
#  'ft',
#  'high',
#  'shape',
#  'dome',
#  'call',
#  'onion',
#  'dome',
#  'amrud',
#  'guava',
#  'dome',
#  'decorate',
#  'lotus',
#  'design',
#  'serve',
#  'accentuate',
#  'height',
#  'shape',
#  'dome',
#  'emphasise',
#  'small',
#  'domed',
#  'chattris',
#  'kiosks',
#  'place',
#  'corner',
#  'replicate',
#  'onion',
#  'shape',
#  'main',
#  'dome',
#  'dome',
#  'slightly',
#  'asymmetrical',
#  'columned',
#  'basis',
#  'open',
#  'roof',
#  'tomb',
#  'provide',
#  'light',
#  'interior',
#  'tall',
#  'decorative',
#  'spire',
#  'guldasta',
#  'extend',
#  'edge',
#  'base',
#  'wall',
#  'provide',
#  'visual',
#  'emphasis',
#  'height',
#  'dome',
#  'lotus',
#  'motif',
#  'repeat',
#  'chattris',
#  'guldasta',
#  'dome',
#  'chattris',
#  'top',
#  'gild',
#  'finial',
#  'mix',
#  'traditional',
#  'persian',
#  'hindustani',
#  'decorative',
#  'element',
#  'main',
#  'finial',
#  'originally',
#  'gold',
#  'replace',
#  'copy',
#  'gild',
#  'bronze',
#  'early',
#  'century',
#  'feature',
#  'provide',
#  'clear',
#  'example',
#  'integration',
#  'traditional',
#  'persian',
#  'hindu',
#  'decorative',
#  'element',
#  'finial',
#  'top',
#  'moon',
#  'typical',
#  'islamic',
#  'motif',
#  'horn',
#  'point',
#  'heavenward',
#  'minaret',
#  'metre',
#  'ft',
#  'tall',
#  'display',
#  'designer',
#  'penchant',
#  'symmetry',
#  'design',
#  'work',
#  'minaret',
#  'traditional',
#  'element',
#  'mosque',
#  'muezzin',
#  'islamic',
#  'faithful',
#  'prayer',
#  'minaret',
#  'effectively',
#  'divide',
#  'equal',
#  'part',
#  'working',
#  'balcony',
#  'ring',
#  'tower',
#  'tower',
#  'final',
#  'balcony',
#  'surmount',
#  'chattri',
#  'mirror',
#  'design',
#  'tomb',
#  'chattris',
#  'share',
#  'decorative',
#  'element',
#  'lotus',
#  'design',
#  'top',
#  'gild',
#  'finial',
#  'minaret',
#  'construct',
#  'slightly',
#  'outside',
#  'plinth',
#  'event',
#  'collapse',
#  'typical',
#  'occurrence',
#  'tall',
#  'construction',
#  'period',
#  'material',
#  'tower',
#  'tend',
#  'fall',
#  'away',
#  'tomb',
#  'exterior',
#  'decoration',
#  'exterior',
#  'decoration',
#  'taj',
#  'mahal',
#  'fine',
#  'mughal',
#  'architecture',
#  'surface',
#  'area',
#  'change',
#  'decoration',
#  'refine',
#  'proportionally',
#  'decorative',
#  'element',
#  'create',
#  'apply',
#  'paint',
#  'stucco',
#  'stone',
#  'inlay',
#  'carving',
#  'line',
#  'islamic',
#  'prohibition',
#  'use',
#  'anthropomorphic',
#  'form',
#  'decorative',
#  'element',
#  'group',
#  'calligraphy',
#  'abstract',
#  'form',
#  'vegetative',
#  'motif',
#  'complex',
#  'passage',
#  'qur',
#  'comprise',
#  'decorative',
#  'element',
#  'recent',
#  'scholarship',
#  'suggest',
#  'amanat',
#  'khan',
#  'choose',
#  'passage',
#  'calligraphy',
#  'great',
#  'gate',
#  'read',
#  'soul',
#  'thou',
#  'art',
#  'rest',
#  'return',
#  'lord',
#  'peace',
#  'peace',
#  'calligraphy',
#  'create',
#  'calligrapher',
#  'name',
#  'abdul',
#  'haq',
#  'shah',
#  'jahan',
#  'confer',
#  'title',
#  'amanat',
#  'khan',
#  'reward',
#  'dazzling',
#  'virtuosity',
#  'near',
#  'line',
#  'qur',
#  'base',
#  'interior',
#  'dome',
#  'inscription',
#  'write',
#  'insignificant',
#  'amanat',
#  'khan',
#  'shirazi',
#  'calligraphy',
#  'compose',
#  'florid',
#  'thuluth',
#  'script',
#  'jasper',
#  'black',
#  'marble',
#  'inlaid',
#  'white',
#  'marble',
#  'panel',
#  'high',
#  'panel',
#  'write',
#  'slightly',
#  'large',
#  'script',
#  'reduce',
#  'skewing',
#  'effect',
#  'view',
#  'calligraphy',
#  'find',
#  'marble',
#  'cenotaph',
#  'tomb',
#  'particularly',
#  'detailed',
#  'delicate',
#  'abstract',
#  'form',
#  'especially',
#  'plinth',
#  'minarets',
#  'gateway',
#  'mosque',
#  'jawab',
#  'less',
#  'extent',
#  'surface',
#  'tomb',
#  'dome',
#  'vault',
#  'sandstone',
#  'building',
#  'work',
#  'tracery',
#  'incise',
#  'painting',
#  'create',
#  'elaborate',
#  'geometric',
#  'form',
#  'herringbone',
#  'inlay',
#  'define',
#  'space',
#  'adjoining',
#  'element',
#  'white',
#  'inlay',
#  'sandstone',
#  'building',
#  'dark',
#  'black',
#  'inlay',
#  'white',
#  'marble',
#  'mortar',
#  'area',
#  'marble',
#  'building',
#  'stain',
#  'paint',
#  'contrast',
#  'colour',
#  'create',
#  'complex',
#  'array',
#  'geometric',
#  'pattern',
#  'floor',
#  'walkway',
#  'use',
#  'contrast',
#  'tile',
#  'block',
#  'tessellation',
#  'pattern',
#  'low',
#  'wall',
#  'tomb',
#  'white',
#  'marble',
#  'dado',
#  'sculpt',
#  'realistic',
#  'bas',
#  'relief',
#  'depiction',
#  'flower',
#  'vine',
#  'marble',
#  'polish',
#  'emphasise',
#  'exquisite',
#  'detailing',
#  'carving',
#  'dado',
#  'frame',
#  'archway',
#  'spandrel',
#  'decorate',
#  'pietra',
#  'dura',
#  'inlay',
#  'highly',
#  'stylise',
#  'geometric',
#  'vine',
#  'flower',
#  'fruit',
#  'inlay',
#  'stone',
#  'yellow',
#  'marble',
#  'jasper',
#  'jade',
#  'polish',
#  'level',
#  'surface',
#  'wall',
#  'interior',
#  'decoration',
#  'interior',
#  'chamber',
#  'taj',
#  'mahal',
#  'reach',
#  'far',
#  'traditional',
#  'decorative',
#  'element',
#  'inlay',
#  'work',
#  'pietra',
#  'dura',
#  'lapidary',
#  'precious',
#  'semiprecious',
#  'gemstone',
#  'inner',
#  'chamber',
#  'octagon',
#  'design',
#  'allow',
#  'entry',
#  'face',
#  'door',
#  'face',
#  'garden',
#  'south',
#  'interior',
#  'wall',
#  'metre',
#  'ft',
#  'high',
#  'top',
#  'false',
#  'interior',
#  'dome',
#  'decorate',
#  'sun',
#  'motif',
#  'pishtaq',
#  'arch',
#  'define',
#  'space',
#  'ground',
#  'level',
#  'exterior',
#  'low',
#  'pishtaq',
#  'crown',
#  'second',
#  'pishtaq',
#  'midway',
#  'wall',
#  'central',
#  'upper',
#  'arch',
#  'form',
#  'balcony',
#  'view',
#  'area',
#  'balcony',
#  'exterior',
#  'window',
#  'intricate',
#  'screen',
#  'jali',
#  'cut',
#  'marble',
#  'addition',
#  'light',
#  'balcony',
#  'screen',
#  'light',
#  'enter',
#  'roof',
#  'opening',
#  'cover',
#  'chattris',
#  'corner',
#  'octagonal',
#  'marble',
#  'screen',
#  'jali',
#  'border',
#  'cenotaph',
#  'marble',
#  'panel',
#  'carve',
#  'intricate',
#  'pierce',
#  'work',
#  'remain',
#  'surface',
#  'inlay',
#  'delicate',
#  'detail',
#  'semi',
#  'precious',
#  'stone',
#  'form',
#  'twine',
#  'vine',
#  'fruit',
#  'flower',
#  'chamber',
#  'wall',
#  'highly',
#  'decorate',
#  'dado',
#  'bas',
#  'relief',
#  'intricate',
#  'lapidary',
#  'inlay',
#  'refined',
#  'calligraphy',
#  'panel',
#  'reflect',
#  'little',
#  'detail',
#  'design',
#  'element',
#  'see',
#  'exterior',
#  'complex',
#  'muslim',
#  'tradition',
#  'forbid',
#  'elaborate',
#  'decoration',
#  'grave',
#  'body',
#  'mumtaz',
#  'shah',
#  'jahan',
#  'relatively',
#  'plain',
#  'crypt',
#  'beneath',
#  'inner',
#  'chamber',
#  'face',
#  'turn',
#  'right',
#  'mecca',
#  'mumtaz',
#  'mahal',
#  'cenotaph',
#  'place',
#  'precise',
#  'centre',
#  'inner',
#  'chamber',
#  'rectangular',
#  'marble',
#  'base',
#  'metre',
#  'ft',
#  'ft',
#  'base',
#  'casket',
#  'elaborately',
#  'inlaid',
#  'precious',
#  'semiprecious',
#  'gem',
#  'calligraphic',
#  'inscription',
#  'casket',
#  'identify',
#  'praise',
#  'mumtaz',
#  'lid',
#  'casket',
#  'raise',
#  'rectangular',
#  'lozenge',
#  'mean',
#  'suggest',
#  'write',
#  'tablet',
#  'shah',
#  'jahan',
#  'cenotaph',
#  'mumtaz',
#  'western',
#  'visible',
#  'asymmetric',
#  'element',
#  'entire',
#  'complex',
#  'cenotaph',
#  'big',
#  'wife',
#  'reflect',
#  'element',
#  'large',
#  'casket',
#  'slightly',
#  'tall',
#  'base',
#  'precisely',
#  'decorate',
#  'lapidary',
#  'calligraphy',
#  'identify',
#  'lid',
#  'casket',
#  'traditional',
#  'sculpture',
#  'small',
#  'pen',
#  'box',
#  'pen',
#  'box',
#  'writing',
#  'tablet',
#  'traditional',
#  'mughal',
#  'funerary',
#  'icon',
#  'decorate',
#  'casket',
#  'man',
#  'woman',
#  'respectively',
#  'name',
#  'god',
#  'calligraphic',
#  'inscription',
#  'side',
#  'actual',
#  'tomb',
#  'mumtaz',
#  'mahal',
#  'inscription',
#  'inside',
#  'crypt',
#  'include',
#  'noble',
#  'magnificent',
#  'majestic',
#  'unique',
#  'eternal',
#  'glorious',
#  'tomb',
#  'shah',
#  'jahan',
#  'bear',
#  'calligraphic',
#  'inscription',
#  'read',
#  'travel',
#  'world',
#  'banquet',
#  'hall',
#  'eternity',
#  'night',
#  'sixth',
#  'month',
#  'rajab',
#  ...]

# %%
article_covid
# Out:
# ['pandemic',
#  'know',
#  'coronavirus',
#  'pandemic',
#  'ongoing',
#  'pandemic',
#  'coronavirus',
#  'disease',
#  'cause',
#  'severe',
#  'acute',
#  'respiratory',
#  'syndrome',
#  'coronaviru',
#  'disease',
#  'identify',
#  'december',
#  'wuhan',
#  'china',
#  'world',
#  'health',
#  'organization',
#  'declare',
#  'outbreak',
#  'public',
#  'health',
#  'emergency',
#  'international',
#  'concern',
#  'january',
#  'pandemic',
#  'march',
#  'september',
#  'case',
#  'report',
#  'country',
#  'territory',
#  'result',
#  'death',
#  'people',
#  'recover',
#  'common',
#  'symptom',
#  'include',
#  'fever',
#  'cough',
#  'fatigue',
#  'shortness',
#  'breath',
#  'breathe',
#  'difficulty',
#  'loss',
#  'smell',
#  'complication',
#  'include',
#  'pneumonia',
#  'acute',
#  'respiratory',
#  'distress',
#  'syndrome',
#  'incubation',
#  'period',
#  'typically',
#  'day',
#  'range',
#  'day',
#  'vaccine',
#  'candidate',
#  'development',
#  'complete',
#  'clinical',
#  'trial',
#  'prove',
#  'safety',
#  'efficacy',
#  'know',
#  'specific',
#  'antiviral',
#  'medication',
#  'primary',
#  'treatment',
#  'currently',
#  'symptomatic',
#  'recommend',
#  'preventive',
#  'measure',
#  'include',
#  'hand',
#  'washing',
#  'cover',
#  'mouth',
#  'cough',
#  'social',
#  'distancing',
#  'wear',
#  'face',
#  'mask',
#  'public',
#  'disinfecting',
#  'surface',
#  'ventilate',
#  'air',
#  'filtering',
#  'monitoring',
#  'self',
#  'isolation',
#  'people',
#  'suspect',
#  'infect',
#  'authority',
#  'worldwide',
#  'respond',
#  'implement',
#  'travel',
#  'restriction',
#  'lockdown',
#  'workplace',
#  'hazard',
#  'control',
#  'facility',
#  'closure',
#  'slow',
#  'spread',
#  'disease',
#  'place',
#  'work',
#  'increase',
#  'testing',
#  'capacity',
#  'trace',
#  'contact',
#  'infect',
#  'pandemic',
#  'cause',
#  'global',
#  'social',
#  'economic',
#  'disruption',
#  'include',
#  'large',
#  'global',
#  'recession',
#  'great',
#  'depression',
#  'accord',
#  'estimation',
#  'people',
#  'fall',
#  'extreme',
#  'poverty',
#  'global',
#  'famine',
#  'affect',
#  'people',
#  'lead',
#  'postponement',
#  'cancellation',
#  'sport',
#  'religious',
#  'political',
#  'cultural',
#  'event',
#  'widespread',
#  'supply',
#  'shortage',
#  'exacerbate',
#  'panic',
#  'buying',
#  'decreased',
#  'emission',
#  'pollutant',
#  'greenhouse',
#  'gas',
#  'educational',
#  'institution',
#  'partially',
#  'fully',
#  'close',
#  'switching',
#  'online',
#  'schooling',
#  'misinformation',
#  'virus',
#  'circulate',
#  'social',
#  'medium',
#  'mass',
#  'medium',
#  'incident',
#  'xenophobia',
#  'discrimination',
#  'chinese',
#  'people',
#  'perceive',
#  'chinese',
#  'area',
#  'high',
#  'infection',
#  'rate',
#  'epidemiology',
#  'background',
#  'december',
#  'world',
#  'health',
#  'organization',
#  'receive',
#  'report',
#  'cluster',
#  'viral',
#  'pneumonia',
#  'case',
#  'unknown',
#  'cause',
#  'wuhan',
#  'hubei',
#  'investigation',
#  'launch',
#  'start',
#  'january',
#  'january',
#  'confirm',
#  'case',
#  'country',
#  'declare',
#  'outbreak',
#  'public',
#  'health',
#  'emergency',
#  'international',
#  'concern',
#  'pheic',
#  'early',
#  'infected',
#  'people',
#  'visit',
#  'huanan',
#  'seafood',
#  'wholesale',
#  'market',
#  'virus',
#  'think',
#  'zoonotic',
#  'origin',
#  'virus',
#  'cause',
#  'outbreak',
#  'know',
#  'newly',
#  'discover',
#  'virus',
#  'closely',
#  'relate',
#  'bat',
#  'coronaviruse',
#  'pangolin',
#  'coronaviruses',
#  'sars',
#  'cov',
#  'scientific',
#  'consensus',
#  'natural',
#  'origin',
#  'probable',
#  'bat',
#  'human',
#  'infection',
#  'people',
#  'process',
#  'bat',
#  'carcass',
#  'guano',
#  'production',
#  'traditional',
#  'chinese',
#  'medicine',
#  'early',
#  'know',
#  'person',
#  'symptom',
#  'later',
#  'discover',
#  'fall',
#  'ill',
#  'december',
#  'person',
#  'visible',
#  'connection',
#  'later',
#  'wet',
#  'market',
#  'cluster',
#  'early',
#  'cluster',
#  'case',
#  'report',
#  'month',
#  'third',
#  'find',
#  'link',
#  'market',
#  'march',
#  'unverified',
#  'report',
#  'south',
#  'china',
#  'morning',
#  'post',
#  'suggest',
#  'case',
#  'trace',
#  'november',
#  'hubei',
#  'person',
#  'infect',
#  'phylogenic',
#  'estimate',
#  'genetic',
#  'study',
#  'conduct',
#  'early',
#  'indicate',
#  'virus',
#  'likely',
#  'jump',
#  'human',
#  'population',
#  'october',
#  'december',
#  'recognise',
#  'spread',
#  'pandemic',
#  'march',
#  'italy',
#  'iran',
#  'south',
#  'korea',
#  'japan',
#  'report',
#  'surge',
#  'number',
#  'case',
#  'later',
#  'month',
#  'number',
#  'case',
#  'outside',
#  'china',
#  'quickly',
#  'surpass',
#  'number',
#  'case',
#  'inside',
#  'china',
#  'case',
#  'official',
#  'case',
#  'count',
#  'refer',
#  'number',
#  'people',
#  'test',
#  'test',
#  'confirm',
#  'positive',
#  'accord',
#  'official',
#  'protocol',
#  'country',
#  'early',
#  'official',
#  'policy',
#  'test',
#  'mild',
#  'symptom',
#  'analysis',
#  'early',
#  'phase',
#  'outbreak',
#  'january',
#  'estimate',
#  'percent',
#  'infection',
#  'detect',
#  'undocumented',
#  'infection',
#  'source',
#  'percent',
#  'document',
#  'case',
#  'study',
#  'variety',
#  'method',
#  'estimate',
#  'number',
#  'infection',
#  'country',
#  'likely',
#  'considerably',
#  'great',
#  'report',
#  'case',
#  'april',
#  'preliminary',
#  'result',
#  'find',
#  'percent',
#  'people',
#  'test',
#  'gangelt',
#  'centre',
#  'major',
#  'infection',
#  'cluster',
#  'germany',
#  'test',
#  'positive',
#  'antibody',
#  'screen',
#  'pregnant',
#  'woman',
#  'new',
#  'york',
#  'city',
#  'blood',
#  'donor',
#  'netherlands',
#  'find',
#  'rate',
#  'positive',
#  'antibody',
#  'test',
#  'indicate',
#  'infection',
#  'report',
#  'seroprevalence',
#  'base',
#  'estimate',
#  'conservative',
#  'study',
#  'show',
#  'person',
#  'mild',
#  'symptom',
#  'detectable',
#  'antibody',
#  'result',
#  'gangelt',
#  'study',
#  'receive',
#  'substantial',
#  'press',
#  'coverage',
#  'pass',
#  'peer',
#  'review',
#  'analysis',
#  'age',
#  'china',
#  'indicate',
#  'relatively',
#  'low',
#  'proportion',
#  'case',
#  'occur',
#  'individual',
#  'clear',
#  'young',
#  'people',
#  'likely',
#  'infect',
#  'likely',
#  'develop',
#  'symptom',
#  'seek',
#  'medical',
#  'attention',
#  'test',
#  'retrospective',
#  'cohort',
#  'study',
#  'china',
#  'find',
#  'child',
#  'adult',
#  'likely',
#  'infect',
#  'initial',
#  'estimate',
#  'basic',
#  'reproduction',
#  'number',
#  'january',
#  'subsequent',
#  'analysis',
#  'conclude',
#  'percent',
#  'confidence',
#  'interval',
#  'vary',
#  'population',
#  'confuse',
#  'effective',
#  'reproduction',
#  'number',
#  'commonly',
#  'call',
#  'take',
#  'account',
#  'effect',
#  'social',
#  'distancing',
#  'herd',
#  'immunity',
#  'mid',
#  'effective',
#  'close',
#  'country',
#  'mean',
#  'spread',
#  'disease',
#  'area',
#  'time',
#  'stable',
#  'decrease',
#  'death',
#  'people',
#  'contract',
#  'recover',
#  'time',
#  'onset',
#  'symptom',
#  'death',
#  'usually',
#  'range',
#  'day',
#  'typically',
#  'day',
#  'september',
#  'approximately',
#  'death',
#  'attribute',
#  'china',
#  'june',
#  'percent',
#  'death',
#  'record',
#  'age',
#  'percent',
#  'pre',
#  'exist',
#  'health',
#  'condition',
#  'include',
#  'cardiovascular',
#  'disease',
#  'diabetes',
#  'individual',
#  'age',
#  'copd',
#  'obesity',
#  'type',
#  'diabetes',
#  'mellitus',
#  'underlie',
#  'health',
#  'condition',
#  'increase',
#  'risk',
#  'severe',
#  'illness',
#  'august',
#  'center',
#  'disease',
#  'control',
#  'prevention',
#  'report',
#  'percent',
#  'death',
#  'certificate',
#  'list',
#  'comorbidity',
#  'reported',
#  'comorbiditie',
#  'include',
#  'symptom',
#  'cause',
#  'infection',
#  'contribute',
#  'fatality',
#  'addition',
#  'pre',
#  'exist',
#  'health',
#  'condition',
#  'american',
#  'death',
#  'certificate',
#  'list',
#  'cause',
#  'death',
#  'list',
#  'condition',
#  'begin',
#  'chain',
#  'event',
#  'ultimately',
#  'lead',
#  'person',
#  'death',
#  'confirm',
#  'death',
#  'wuhan',
#  'january',
#  'report',
#  'death',
#  'outside',
#  'china',
#  'occur',
#  'february',
#  'philippines',
#  'report',
#  'death',
#  'outside',
#  'asia',
#  'france',
#  'february',
#  'post',
#  'mortem',
#  'analysis',
#  'tissue',
#  'sample',
#  'identify',
#  'early',
#  'death',
#  'go',
#  'undetected',
#  'time',
#  'include',
#  'california',
#  'woman',
#  'die',
#  'february',
#  'death',
#  'generally',
#  'refer',
#  'people',
#  'die',
#  'test',
#  'positive',
#  'accord',
#  'protocol',
#  'ignore',
#  'death',
#  'people',
#  'die',
#  'have',
#  'test',
#  'conversely',
#  'death',
#  'people',
#  'underlie',
#  'condition',
#  'lead',
#  'count',
#  'comparison',
#  'statistic',
#  'death',
#  'cause',
#  'versus',
#  'seasonal',
#  'average',
#  'indicate',
#  'excess',
#  'mortality',
#  'country',
#  'bad',
#  'affected',
#  'area',
#  'mortality',
#  'time',
#  'high',
#  'average',
#  'new',
#  'york',
#  'city',
#  'death',
#  'time',
#  'high',
#  'average',
#  'paris',
#  'twice',
#  'high',
#  'european',
#  'country',
#  'death',
#  'average',
#  'percent',
#  'high',
#  'normal',
#  'excess',
#  'mortality',
#  'include',
#  'death',
#  'strain',
#  'healthcare',
#  'system',
#  'ban',
#  'elective',
#  'surgery',
#  'multiple',
#  'measure',
#  'quantify',
#  'mortality',
#  'number',
#  'vary',
#  'region',
#  'time',
#  'influence',
#  'test',
#  'volume',
#  'healthcare',
#  'system',
#  'quality',
#  'treatment',
#  'option',
#  'government',
#  'response',
#  'time',
#  'initial',
#  'outbreak',
#  'population',
#  'characteristic',
#  'age',
#  'sex',
#  'overall',
#  'health',
#  'country',
#  'like',
#  'belgium',
#  'include',
#  'death',
#  'suspect',
#  'case',
#  'regardless',
#  'person',
#  'test',
#  'result',
#  'high',
#  'number',
#  'compare',
#  'country',
#  'include',
#  'test',
#  'confirm',
#  'case',
#  'death',
#  'case',
#  'ratio',
#  'reflect',
#  'number',
#  'death',
#  'attribute',
#  'divide',
#  'number',
#  'diagnose',
#  'case',
#  'give',
#  'time',
#  'interval',
#  'base',
#  'johns',
#  'hopkins',
#  'university',
#  'statistic',
#  'global',
#  'death',
#  'case',
#  'ratio',
#  'percent',
#  'death',
#  'case',
#  'september',
#  'number',
#  'vary',
#  'region',
#  'measure',
#  'include',
#  'case',
#  'fatality',
#  'rate',
#  'cfr',
#  'reflect',
#  'percentage',
#  'diagnosed',
#  'people',
#  'die',
#  'disease',
#  'infection',
#  'fatality',
#  'rate',
#  'ifr',
#  'reflect',
#  'percentage',
#  'infected',
#  'diagnose',
#  'undiagnose',
#  'die',
#  'disease',
#  'statistic',
#  'timebound',
#  'follow',
#  'specific',
#  'population',
#  'infection',
#  'case',
#  'resolution',
#  'world',
#  'datum',
#  'state',
#  'march',
#  'ifr',
#  'accurately',
#  'calculate',
#  'total',
#  'number',
#  'case',
#  'total',
#  'death',
#  'know',
#  'february',
#  'institute',
#  'disease',
#  'modeling',
#  'estimate',
#  'ifr',
#  'percent',
#  'confidence',
#  'interval',
#  'base',
#  'datum',
#  'china',
#  'university',
#  'oxford',
#  'centre',
#  'evidence',
#  'base',
#  'medicine',
#  'cebm',
#  'estimate',
#  'global',
#  'cfr',
#  'percent',
#  'revise',
#  'april',
#  'ifr',
#  'percent',
#  'percent',
#  'revise',
#  'acknowledge',
#  'vary',
#  'population',
#  'difference',
#  'demographic',
#  'paper',
#  'plos',
#  'medicine',
#  'estimate',
#  'ifr',
#  'area',
#  'europe',
#  'range',
#  'duration',
#  'march',
#  'say',
#  'pandemic',
#  'control',
#  'peak',
#  'ultimate',
#  'duration',
#  'outbreak',
#  'uncertain',
#  'differ',
#  'location',
#  'maciej',
#  'boni',
#  'penn',
#  'state',
#  'university',
#  'say',
#  'leave',
#  'unchecked',
#  'infectious',
#  'outbreak',
#  'typically',
#  'plateau',
#  'start',
#  'decline',
#  'disease',
#  'run',
#  'available',
#  'host',
#  'impossible',
#  'sensible',
#  'projection',
#  'right',
#  'imperial',
#  'college',
#  'study',
#  'lead',
#  'neil',
#  'ferguson',
#  'state',
#  'physical',
#  'distancing',
#  'measure',
#  'require',
#  'vaccine',
#  'available',
#  'william',
#  'schaffner',
#  'vanderbilt',
#  'university',
#  'say',
#  'coronavirus',
#  'readily',
#  'transmissible',
#  'turn',
#  'seasonal',
#  'disease',
#  'make',
#  'comeback',
#  'year',
#  'virulence',
#  'comeback',
#  'depend',
#  'herd',
#  'immunity',
#  'extent',
#  'mutation',
#  'sign',
#  'symptom',
#  'usual',
#  'incubation',
#  'period',
#  'time',
#  'infection',
#  'symptom',
#  'onset',
#  'range',
#  'day',
#  'commonly',
#  'day',
#  'infected',
#  'people',
#  'symptom',
#  'know',
#  'asymptomatic',
#  'presymptomatic',
#  'carrier',
#  'transmission',
#  'carrier',
#  'consider',
#  'possible',
#  'april',
#  'estimate',
#  'asymptomatic',
#  'ratio',
#  'range',
#  'widely',
#  'percent',
#  'symptom',
#  'relatively',
#  'non',
#  'specific',
#  'common',
#  'symptom',
#  'fever',
#  'percent',
#  'dry',
#  'cough',
#  'percent',
#  'common',
#  'symptom',
#  'include',
#  'fatigue',
#  'respiratory',
#  'sputum',
#  'production',
#  'phlegm',
#  'loss',
#  'sense',
#  'smell',
#  'loss',
#  'taste',
#  'shortness',
#  'breath',
#  'muscle',
#  'joint',
#  'pain',
#  'sore',
#  ...]

# %%
texts=[article_covid, article_data, article_sports, article_taj]

# %%
bigram = gensim.models.Phrases(texts)

# %%
texts = [bigram[line] for line in texts]

# %%
texts
# Out:
# [['pandemic',
#   'know',
#   'coronavirus',
#   'pandemic',
#   'ongoing',
#   'pandemic',
#   'coronavirus',
#   'disease',
#   'cause',
#   'severe',
#   'acute',
#   'respiratory',
#   'syndrome',
#   'coronaviru',
#   'disease',
#   'identify',
#   'december',
#   'wuhan',
#   'china',
#   'world_health',
#   'organization',
#   'declare',
#   'outbreak',
#   'public_health',
#   'emergency',
#   'international',
#   'concern',
#   'january',
#   'pandemic',
#   'march',
#   'september',
#   'case',
#   'report',
#   'country',
#   'territory',
#   'result',
#   'death',
#   'people',
#   'recover',
#   'common',
#   'symptom',
#   'include',
#   'fever',
#   'cough',
#   'fatigue',
#   'shortness',
#   'breath',
#   'breathe',
#   'difficulty',
#   'loss',
#   'smell',
#   'complication',
#   'include',
#   'pneumonia',
#   'acute',
#   'respiratory',
#   'distress',
#   'syndrome',
#   'incubation',
#   'period',
#   'typically',
#   'day',
#   'range',
#   'day',
#   'vaccine',
#   'candidate',
#   'development',
#   'complete',
#   'clinical',
#   'trial',
#   'prove',
#   'safety',
#   'efficacy',
#   'know',
#   'specific',
#   'antiviral',
#   'medication',
#   'primary',
#   'treatment',
#   'currently',
#   'symptomatic',
#   'recommend',
#   'preventive',
#   'measure',
#   'include',
#   'hand',
#   'washing',
#   'cover',
#   'mouth',
#   'cough',
#   'social_distancing',
#   'wear',
#   'face',
#   'mask',
#   'public',
#   'disinfecting',
#   'surface',
#   'ventilate',
#   'air',
#   'filtering',
#   'monitoring',
#   'self',
#   'isolation',
#   'people',
#   'suspect',
#   'infect',
#   'authority',
#   'worldwide',
#   'respond',
#   'implement',
#   'travel_restriction',
#   'lockdown',
#   'workplace',
#   'hazard',
#   'control',
#   'facility',
#   'closure',
#   'slow',
#   'spread',
#   'disease',
#   'place',
#   'work',
#   'increase',
#   'testing',
#   'capacity',
#   'trace',
#   'contact',
#   'infect',
#   'pandemic',
#   'cause',
#   'global',
#   'social',
#   'economic',
#   'disruption',
#   'include',
#   'large',
#   'global',
#   'recession',
#   'great',
#   'depression',
#   'accord',
#   'estimation',
#   'people',
#   'fall',
#   'extreme',
#   'poverty',
#   'global',
#   'famine',
#   'affect',
#   'people',
#   'lead',
#   'postponement',
#   'cancellation',
#   'sport',
#   'religious',
#   'political',
#   'cultural',
#   'event',
#   'widespread',
#   'supply',
#   'shortage',
#   'exacerbate',
#   'panic',
#   'buying',
#   'decreased',
#   'emission',
#   'pollutant',
#   'greenhouse',
#   'gas',
#   'educational',
#   'institution',
#   'partially',
#   'fully',
#   'close',
#   'switching',
#   'online',
#   'schooling',
#   'misinformation',
#   'virus',
#   'circulate',
#   'social',
#   'medium',
#   'mass',
#   'medium',
#   'incident',
#   'xenophobia',
#   'discrimination',
#   'chinese',
#   'people',
#   'perceive',
#   'chinese',
#   'area',
#   'high',
#   'infection',
#   'rate',
#   'epidemiology',
#   'background',
#   'december',
#   'world_health',
#   'organization',
#   'receive',
#   'report',
#   'cluster',
#   'viral',
#   'pneumonia',
#   'case',
#   'unknown',
#   'cause',
#   'wuhan',
#   'hubei',
#   'investigation',
#   'launch',
#   'start',
#   'january',
#   'january',
#   'confirm_case',
#   'country',
#   'declare',
#   'outbreak',
#   'public_health',
#   'emergency',
#   'international',
#   'concern',
#   'pheic',
#   'early',
#   'infected',
#   'people',
#   'visit',
#   'huanan',
#   'seafood',
#   'wholesale',
#   'market',
#   'virus',
#   'think',
#   'zoonotic',
#   'origin',
#   'virus',
#   'cause',
#   'outbreak',
#   'know',
#   'newly',
#   'discover',
#   'virus',
#   'closely',
#   'relate',
#   'bat',
#   'coronaviruse',
#   'pangolin',
#   'coronaviruses',
#   'sars',
#   'cov',
#   'scientific',
#   'consensus',
#   'natural',
#   'origin',
#   'probable',
#   'bat',
#   'human',
#   'infection',
#   'people',
#   'process',
#   'bat',
#   'carcass',
#   'guano',
#   'production',
#   'traditional',
#   'chinese',
#   'medicine',
#   'early_know',
#   'person',
#   'symptom',
#   'later',
#   'discover',
#   'fall',
#   'ill',
#   'december',
#   'person',
#   'visible',
#   'connection',
#   'later',
#   'wet',
#   'market',
#   'cluster',
#   'early',
#   'cluster',
#   'case',
#   'report',
#   'month',
#   'third',
#   'find',
#   'link',
#   'market',
#   'march',
#   'unverified',
#   'report',
#   'south',
#   'china',
#   'morning',
#   'post',
#   'suggest',
#   'case',
#   'trace',
#   'november',
#   'hubei',
#   'person',
#   'infect',
#   'phylogenic',
#   'estimate',
#   'genetic',
#   'study',
#   'conduct',
#   'early',
#   'indicate',
#   'virus',
#   'likely',
#   'jump',
#   'human',
#   'population',
#   'october',
#   'december',
#   'recognise',
#   'spread',
#   'pandemic',
#   'march',
#   'italy',
#   'iran',
#   'south_korea',
#   'japan',
#   'report',
#   'surge',
#   'number',
#   'case',
#   'later',
#   'month',
#   'number',
#   'case',
#   'outside',
#   'china',
#   'quickly',
#   'surpass',
#   'number',
#   'case',
#   'inside',
#   'china',
#   'case',
#   'official',
#   'case',
#   'count',
#   'refer',
#   'number',
#   'people',
#   'test',
#   'test',
#   'confirm',
#   'positive',
#   'accord',
#   'official',
#   'protocol',
#   'country',
#   'early',
#   'official',
#   'policy',
#   'test',
#   'mild',
#   'symptom',
#   'analysis',
#   'early',
#   'phase',
#   'outbreak',
#   'january',
#   'estimate',
#   'percent',
#   'infection',
#   'detect',
#   'undocumented',
#   'infection',
#   'source',
#   'percent',
#   'document',
#   'case',
#   'study',
#   'variety',
#   'method',
#   'estimate',
#   'number',
#   'infection',
#   'country',
#   'likely',
#   'considerably',
#   'great',
#   'report',
#   'case',
#   'april',
#   'preliminary',
#   'result',
#   'find',
#   'percent',
#   'people',
#   'test',
#   'gangelt',
#   'centre',
#   'major',
#   'infection',
#   'cluster',
#   'germany',
#   'test_positive',
#   'antibody',
#   'screen',
#   'pregnant',
#   'woman',
#   'new_york',
#   'city',
#   'blood',
#   'donor',
#   'netherlands',
#   'find',
#   'rate',
#   'positive',
#   'antibody',
#   'test',
#   'indicate',
#   'infection',
#   'report',
#   'seroprevalence',
#   'base',
#   'estimate',
#   'conservative',
#   'study',
#   'show',
#   'person',
#   'mild',
#   'symptom',
#   'detectable',
#   'antibody',
#   'result',
#   'gangelt',
#   'study',
#   'receive',
#   'substantial',
#   'press',
#   'coverage',
#   'pass',
#   'peer',
#   'review',
#   'analysis',
#   'age',
#   'china',
#   'indicate',
#   'relatively',
#   'low',
#   'proportion',
#   'case',
#   'occur',
#   'individual',
#   'clear',
#   'young',
#   'people',
#   'likely',
#   'infect',
#   'likely',
#   'develop',
#   'symptom',
#   'seek',
#   'medical',
#   'attention',
#   'test',
#   'retrospective',
#   'cohort',
#   'study',
#   'china',
#   'find',
#   'child',
#   'adult',
#   'likely',
#   'infect',
#   'initial',
#   'estimate',
#   'basic',
#   'reproduction',
#   'number',
#   'january',
#   'subsequent',
#   'analysis',
#   'conclude',
#   'percent',
#   'confidence',
#   'interval',
#   'vary',
#   'population',
#   'confuse',
#   'effective',
#   'reproduction',
#   'number',
#   'commonly',
#   'call',
#   'take',
#   'account',
#   'effect',
#   'social_distancing',
#   'herd',
#   'immunity',
#   'mid',
#   'effective',
#   'close',
#   'country',
#   'mean',
#   'spread',
#   'disease',
#   'area',
#   'time',
#   'stable',
#   'decrease',
#   'death',
#   'people',
#   'contract',
#   'recover',
#   'time',
#   'onset',
#   'symptom',
#   'death',
#   'usually',
#   'range',
#   'day',
#   'typically',
#   'day',
#   'september',
#   'approximately',
#   'death',
#   'attribute',
#   'china',
#   'june',
#   'percent',
#   'death',
#   'record',
#   'age',
#   'percent',
#   'pre',
#   'exist',
#   'health',
#   'condition',
#   'include',
#   'cardiovascular',
#   'disease',
#   'diabetes',
#   'individual',
#   'age',
#   'copd',
#   'obesity',
#   'type',
#   'diabetes',
#   'mellitus',
#   'underlie',
#   'health',
#   'condition',
#   'increase',
#   'risk',
#   'severe',
#   'illness',
#   'august',
#   'center',
#   'disease',
#   'control',
#   'prevention',
#   'report',
#   'percent',
#   'death',
#   'certificate',
#   'list',
#   'comorbidity',
#   'reported',
#   'comorbiditie',
#   'include',
#   'symptom',
#   'cause',
#   'infection',
#   'contribute',
#   'fatality',
#   'addition',
#   'pre',
#   'exist',
#   'health',
#   'condition',
#   'american',
#   'death',
#   'certificate',
#   'list',
#   'cause',
#   'death',
#   'list',
#   'condition',
#   'begin',
#   'chain',
#   'event',
#   'ultimately',
#   'lead',
#   'person',
#   'death',
#   'confirm',
#   'death',
#   'wuhan',
#   'january',
#   'report',
#   'death',
#   'outside',
#   'china',
#   'occur',
#   'february',
#   'philippines',
#   'report',
#   'death',
#   'outside',
#   'asia',
#   'france',
#   'february',
#   'post',
#   'mortem',
#   'analysis',
#   'tissue',
#   'sample',
#   'identify',
#   'early',
#   'death',
#   'go',
#   'undetected',
#   'time',
#   'include',
#   'california',
#   'woman',
#   'die',
#   'february',
#   'death',
#   'generally',
#   'refer',
#   'people_die',
#   'test_positive',
#   'accord',
#   'protocol',
#   'ignore',
#   'death',
#   'people_die',
#   'have',
#   'test',
#   'conversely',
#   'death',
#   'people',
#   'underlie',
#   'condition',
#   'lead',
#   'count',
#   'comparison',
#   'statistic',
#   'death',
#   'cause',
#   'versus',
#   'seasonal',
#   'average',
#   'indicate',
#   'excess',
#   'mortality',
#   'country',
#   'bad',
#   'affected',
#   'area',
#   'mortality',
#   'time',
#   'high',
#   'average',
#   'new_york',
#   'city',
#   'death',
#   'time',
#   'high',
#   'average',
#   'paris',
#   'twice',
#   'high',
#   'european',
#   'country',
#   'death',
#   'average',
#   'percent',
#   'high',
#   'normal',
#   'excess',
#   'mortality',
#   'include',
#   'death',
#   'strain',
#   'healthcare',
#   'system',
#   'ban',
#   'elective',
#   'surgery',
#   'multiple',
#   'measure',
#   'quantify',
#   'mortality',
#   'number',
#   'vary',
#   'region',
#   'time',
#   'influence',
#   'test',
#   'volume',
#   'healthcare',
#   'system',
#   'quality',
#   'treatment',
#   'option',
#   'government',
#   'response',
#   'time',
#   'initial',
#   'outbreak',
#   'population',
#   'characteristic',
#   'age',
#   'sex',
#   'overall',
#   'health',
#   'country',
#   'like',
#   'belgium',
#   'include',
#   'death',
#   'suspect',
#   'case',
#   'regardless',
#   'person',
#   'test',
#   'result',
#   'high',
#   'number',
#   'compare',
#   'country',
#   'include',
#   'test',
#   'confirm_case',
#   'death',
#   'case',
#   'ratio',
#   'reflect',
#   'number',
#   'death',
#   'attribute',
#   'divide',
#   'number',
#   'diagnose',
#   'case',
#   'give',
#   'time',
#   'interval',
#   'base',
#   'johns',
#   'hopkins',
#   'university',
#   'statistic',
#   'global',
#   'death',
#   'case',
#   'ratio',
#   'percent',
#   'death',
#   'case',
#   'september',
#   'number',
#   'vary',
#   'region',
#   'measure',
#   'include',
#   'case',
#   'fatality',
#   'rate',
#   'cfr',
#   'reflect',
#   'percentage',
#   'diagnosed',
#   'people_die',
#   'disease',
#   'infection',
#   'fatality',
#   'rate',
#   'ifr',
#   'reflect',
#   'percentage',
#   'infected',
#   'diagnose',
#   'undiagnose',
#   'die',
#   'disease',
#   'statistic',
#   'timebound',
#   'follow',
#   'specific',
#   'population',
#   'infection',
#   'case',
#   'resolution',
#   'world',
#   'datum',
#   'state',
#   'march',
#   'ifr',
#   'accurately',
#   'calculate',
#   'total',
#   'number',
#   'case',
#   'total',
#   'death',
#   'know',
#   'february',
#   'institute',
#   'disease',
#   'modeling',
#   'estimate',
#   'ifr',
#   'percent',
#   'confidence',
#   'interval',
#   'base',
#   'datum',
#   'china',
#   'university',
#   'oxford',
#   'centre',
#   'evidence',
#   'base',
#   'medicine',
#   'cebm',
#   'estimate',
#   'global',
#   'cfr',
#   'percent',
#   'revise',
#   'april',
#   'ifr',
#   'percent',
#   'percent',
#   'revise',
#   'acknowledge',
#   'vary',
#   'population',
#   'difference',
#   'demographic',
#   'paper',
#   'plos',
#   'medicine',
#   'estimate',
#   'ifr',
#   'area',
#   'europe',
#   'range',
#   'duration',
#   'march',
#   'say',
#   'pandemic',
#   'control',
#   'peak',
#   'ultimate',
#   'duration',
#   'outbreak',
#   'uncertain',
#   'differ',
#   'location',
#   'maciej',
#   'boni',
#   'penn',
#   'state',
#   'university',
#   'say',
#   'leave',
#   'unchecked',
#   'infectious',
#   'outbreak',
#   'typically',
#   'plateau',
#   'start',
#   'decline',
#   'disease',
#   'run',
#   'available',
#   'host',
#   'impossible',
#   'sensible',
#   'projection',
#   'right',
#   'imperial',
#   'college',
#   'study',
#   'lead',
#   'neil',
#   'ferguson',
#   'state',
#   'physical_distancing',
#   'measure',
#   'require',
#   'vaccine',
#   'available',
#   'william',
#   'schaffner',
#   'vanderbilt',
#   'university',
#   'say',
#   'coronavirus',
#   'readily',
#   'transmissible',
#   'turn',
#   'seasonal',
#   'disease',
#   'make',
#   'comeback',
#   'year',
#   'virulence',
#   'comeback',
#   'depend',
#   'herd',
#   'immunity',
#   'extent',
#   'mutation',
#   'sign',
#   'symptom',
#   'usual',
#   'incubation',
#   'period',
#   'time',
#   'infection',
#   'symptom',
#   'onset',
#   'range',
#   'day',
#   'commonly',
#   'day',
#   'infected',
#   'people',
#   'symptom',
#   'know',
#   'asymptomatic',
#   'presymptomatic',
#   'carrier',
#   'transmission',
#   'carrier',
#   'consider',
#   'possible',
#   'april',
#   'estimate',
#   'asymptomatic',
#   'ratio',
#   'range',
#   'widely',
#   'percent',
#   'symptom',
#   'relatively',
#   'non',
#   'specific',
#   'common',
#   'symptom',
#   'fever',
#   'percent',
#   'dry',
#   'cough',
#   'percent',
#   'common',
#   'symptom',
#   'include',
#   'fatigue',
#   'respiratory',
#   'sputum',
#   'production',
#   'phlegm',
#   'loss',
#   'sense',
#   'smell',
#   'loss',
#   'taste',
#   'shortness',
#   'breath',
#   'muscle',
#   'joint',
#   'pain',
#   'sore',
#   'throat',
#   'headache',
#   'chills',
#   'vomit',
#   'cough',
#   'blood',
#   'diarrhea',
#   'rash',
#   'develop',
#   'symptom',
#   'approximately',
#   'seriously',
#   'ill',
#   'difficulty',
#   'breathe',
#   'emergency',
#   'symptom',
#   'include',
#   'difficulty',
#   ...],
#  ['data_science',
#   'inter',
#   'disciplinary',
#   'field',
#   'use',
#   'scientific',
#   'method',
#   'process',
#   'algorithm',
#   'system',
#   'extract',
#   'knowledge',
#   'insight',
#   'structural',
#   'unstructured',
#   'data',
#   'data_science',
#   'relate',
#   'datum',
#   'mining',
#   'machine_learning',
#   'big',
#   'data',
#   'data_science',
#   'concept',
#   'unify',
#   'statistics',
#   'data',
#   'analysis',
#   'relate',
#   'method',
#   'order',
#   'understand',
#   'analyze',
#   'actual',
#   'phenomenon',
#   'datum',
#   'use',
#   'technique',
#   'theory',
#   'draw',
#   'field',
#   'context',
#   'mathematic',
#   'statistic',
#   'computer',
#   'science',
#   'domain',
#   'knowledge',
#   'information',
#   'science',
#   'turing',
#   'award',
#   'winner',
#   'jim',
#   'gray',
#   'imagine',
#   'datum_science',
#   'fourth',
#   'paradigm',
#   'science',
#   'empirical',
#   'theoretical',
#   'computational',
#   'datum',
#   'drive',
#   'assert',
#   'science',
#   'change',
#   'impact',
#   'information',
#   'technology',
#   'datum',
#   'deluge',
#   'foundation',
#   'data_science',
#   'interdisciplinary',
#   'field',
#   'focus',
#   'extract',
#   'knowledge',
#   'data',
#   'set',
#   'typically',
#   'large',
#   'big_datum',
#   'field',
#   'encompass',
#   'analysis',
#   'prepare',
#   'datum',
#   'analysis',
#   'present',
#   'finding',
#   'inform',
#   'high',
#   'level',
#   'decision',
#   'organization',
#   'incorporate',
#   'skill',
#   'computer',
#   'science',
#   'mathematic',
#   'statistic',
#   'information',
#   'visualization',
#   'graphic',
#   'design',
#   'complex',
#   'system',
#   'communication',
#   'business',
#   'statistician',
#   'nathan',
#   'yau',
#   'draw',
#   'ben',
#   'fry',
#   'link',
#   'datum_science',
#   'human',
#   'computer',
#   'interaction',
#   'user',
#   'able',
#   'intuitively',
#   'control',
#   'explore',
#   'datum',
#   'american',
#   'statistical',
#   'association',
#   'identify',
#   'database',
#   'management',
#   'statistic',
#   'machine_learning',
#   'distributed',
#   'parallel',
#   'system',
#   'emerge',
#   'foundational',
#   'professional',
#   'community',
#   'relationship',
#   'statistic',
#   'statistician',
#   'include',
#   'nate',
#   'silver',
#   'argue',
#   'data_science',
#   'new',
#   'field',
#   'statistic',
#   'argue',
#   'data_science',
#   'distinct',
#   'statistic',
#   'focus',
#   'problem',
#   'technique',
#   'unique',
#   'digital',
#   'datum',
#   'vasant',
#   'dhar',
#   'write',
#   'statistic',
#   'emphasize',
#   'quantitative',
#   'datum',
#   'description',
#   'contrast',
#   'data_science',
#   'deal',
#   'quantitative',
#   'qualitative',
#   'data',
#   'image',
#   'emphasize',
#   'prediction',
#   'action',
#   'andrew',
#   'gelman',
#   'columbia',
#   'university',
#   'data_scientist',
#   'vincent',
#   'granville',
#   'describe',
#   'statistic',
#   'nonessential',
#   'data_science',
#   'stanford',
#   'professor',
#   'david',
#   'donoho',
#   'write',
#   'data_science',
#   'distinguish',
#   'statistic',
#   'size',
#   'dataset',
#   'use',
#   'computing',
#   'graduate',
#   'program',
#   'misleadingly',
#   'advertise',
#   'analytic',
#   'statistic',
#   'training',
#   'essence',
#   'datum_science',
#   'program',
#   'describe',
#   'datum_science',
#   'applied',
#   'field',
#   'grow',
#   'traditional',
#   'statistic',
#   'summary',
#   'datum_science',
#   'describe',
#   'applied',
#   'branch',
#   'statistic',
#   'etymology',
#   'early',
#   'usage',
#   'john',
#   'tukey',
#   'describe',
#   'field',
#   'call',
#   'datum',
#   'analysis',
#   'resemble',
#   'modern',
#   'datum_science',
#   'later',
#   'attendee',
#   'statistic',
#   'symposium',
#   'university',
#   'montpellier',
#   'ii',
#   'acknowledge',
#   'emergence',
#   'new',
#   'discipline',
#   'focus',
#   'datum',
#   'origin',
#   'form',
#   'combine',
#   'establish',
#   'concept',
#   'principle',
#   'statistic',
#   'datum',
#   'analysis',
#   'compute',
#   'term',
#   'datum_science',
#   'trace',
#   'peter',
#   'naur',
#   'propose',
#   'alternative',
#   'computer',
#   'science',
#   'international',
#   'federation',
#   'classification',
#   'society',
#   'conference',
#   'specifically',
#   'feature',
#   'datum_science',
#   'topic',
#   'definition',
#   'flux',
#   'jeff',
#   'wu',
#   'suggest',
#   'statistic',
#   'rename',
#   'datum_science',
#   'reason',
#   'new',
#   'help',
#   'statistic',
#   'shed',
#   'inaccurate',
#   'stereotype',
#   'synonymous',
#   'accounting',
#   'limit',
#   'describe',
#   'datum',
#   'chikio',
#   'hayashi',
#   'argue',
#   'data_science',
#   'new',
#   'interdisciplinary',
#   'concept',
#   'aspect',
#   'data',
#   'design',
#   'collection',
#   'analysis',
#   'popular',
#   'term',
#   'process',
#   'find',
#   'pattern',
#   'dataset',
#   'increasingly',
#   'large',
#   'include',
#   'knowledge',
#   'discovery',
#   'datum',
#   'mining',
#   'modern',
#   'usage',
#   'modern',
#   'conception',
#   'data_science',
#   'independent',
#   'discipline',
#   'attribute',
#   'william',
#   'cleveland',
#   'paper',
#   'advocate',
#   'expansion',
#   'statistic',
#   'theory',
#   'technical',
#   'area',
#   'significantly',
#   'change',
#   'field',
#   'warrant',
#   'new',
#   'data_science',
#   'widely',
#   'year',
#   'committee',
#   'datum_science',
#   'technology',
#   'launch',
#   'data_science',
#   'journal',
#   'columbia',
#   'university',
#   'launch',
#   'journal',
#   'data_science',
#   'american',
#   'statistical',
#   'association',
#   'section',
#   'statistical',
#   'learning',
#   'datum',
#   'mining',
#   'change',
#   'section',
#   'statistical',
#   'learning',
#   'datum_science',
#   'reflect',
#   'ascendant',
#   'popularity',
#   'datum_science',
#   'professional',
#   'title',
#   'data_scientist',
#   'attribute',
#   'dj',
#   'patil',
#   'jeff',
#   'hammerbacher',
#   'national',
#   'science',
#   'board',
#   'report',
#   'long',
#   'live',
#   'digital',
#   'data',
#   'collection',
#   'enable',
#   'research',
#   'education',
#   'century',
#   'refer',
#   'broadly',
#   'key',
#   'role',
#   'manage',
#   'digital',
#   'datum',
#   'collection',
#   'consensus',
#   'definition',
#   'datum_science',
#   'consider',
#   'buzzword',
#   'career',
#   'data_science',
#   'data_science',
#   'grow',
#   'field',
#   'career',
#   'data_scientist',
#   'rank',
#   'good',
#   'job',
#   'america',
#   'glassdoor',
#   'rank',
#   'number',
#   'good',
#   'job',
#   'educational',
#   'path',
#   'order',
#   'data_scientist',
#   'significant',
#   'education',
#   'experience',
#   'require',
#   'step',
#   'data_scientist',
#   'earn',
#   'bachelor',
#   'degree',
#   'typically',
#   'quantitative',
#   'field',
#   'coding',
#   'bootcamp',
#   'available',
#   'alternate',
#   'pre',
#   'qualification',
#   'supplement',
#   'bachelor',
#   'degree',
#   'data_scientist',
#   'complete',
#   'master',
#   'degree',
#   'phd',
#   'quantitative',
#   'scientific',
#   'field',
#   'qualification',
#   'meet',
#   'step',
#   'data_scientist',
#   'apply',
#   'entry',
#   'level',
#   'job',
#   'field',
#   'data_scientist',
#   'later',
#   'choose',
#   'specialize',
#   'sub',
#   'field',
#   'datum_science',
#   'specialization',
#   'associated',
#   'career',
#   'machine_learning',
#   'scientist',
#   'machine_learning',
#   'scientist',
#   'research',
#   'new',
#   'method',
#   'datum',
#   'analysis',
#   'create',
#   'algorithms',
#   'data',
#   'engineer',
#   'data',
#   'engineer',
#   'prepare',
#   'big_datum',
#   'infrastructure',
#   'analyze',
#   'datum',
#   'scientist',
#   'software',
#   'engineer',
#   'design',
#   'build',
#   'integrate',
#   'datum',
#   'resource',
#   'manage',
#   'big',
#   'data',
#   'data',
#   'analyst',
#   'datum',
#   'analyst',
#   'utilize',
#   'large',
#   'data',
#   'set',
#   'gather',
#   'information',
#   'meet',
#   'company',
#   'need',
#   'data',
#   'consultant',
#   'datum',
#   'consultant',
#   'work',
#   'business',
#   'determine',
#   'good',
#   'usage',
#   'information',
#   'yield',
#   'datum',
#   'analysis',
#   'datum',
#   'architect',
#   'datum',
#   'architect',
#   'build',
#   'datum',
#   'solution',
#   'optimize',
#   'performance',
#   'design',
#   'application',
#   'application',
#   'architect',
#   'application',
#   'architect',
#   'track',
#   'application',
#   'business',
#   'interact',
#   'user',
#   'application',
#   'impact',
#   'datum_science',
#   'big_datum',
#   'quickly',
#   'vital',
#   'tool',
#   'business',
#   'company',
#   'size',
#   'availability',
#   'interpretation',
#   'big_datum',
#   'alter',
#   'business',
#   'model',
#   'old',
#   'industry',
#   'enable',
#   'creation',
#   'new',
#   'one',
#   'datum',
#   'drive',
#   'business',
#   'worth',
#   'collectively',
#   'increase',
#   'year',
#   'datum',
#   'scientist',
#   'responsible',
#   'break',
#   'big_datum',
#   'usable',
#   'information',
#   'create',
#   'software',
#   'algorithm',
#   'help',
#   'company',
#   'organization',
#   'determine',
#   'optimal',
#   'operation',
#   'big_datum',
#   'continue',
#   'major',
#   'impact',
#   'world',
#   'data_science',
#   'close',
#   'relationship',
#   'technology',
#   'technique',
#   'variety',
#   'different',
#   'technology',
#   'technique',
#   'data_science',
#   'depend',
#   'application',
#   'recently',
#   'featured',
#   'end',
#   'end',
#   'platform',
#   'develop',
#   'heavily',
#   'data_science',
#   'machine_learning',
#   'technique',
#   'linear',
#   'regression',
#   'logistic',
#   'regression',
#   'decision',
#   'tree',
#   'support',
#   'vector',
#   'machine',
#   'svm',
#   'clustering',
#   'technique',
#   'group',
#   'datum',
#   'dimensionality',
#   'reduction',
#   'reduce',
#   'complexity',
#   'datum',
#   'computation',
#   'perform',
#   'quickly',
#   'machine_learning',
#   'technique',
#   'perform',
#   'task',
#   'inference',
#   'pattern',
#   'datum',
#   'language',
#   'python',
#   'program',
#   'language',
#   'simple',
#   'syntax',
#   'commonly',
#   'data_science',
#   'number',
#   'python',
#   'library',
#   'datum_science',
#   'include',
#   'numpy',
#   'panda',
#   'scipy',
#   'program',
#   'language',
#   'design',
#   'statistician',
#   'datum',
#   'mining',
#   'optimize',
#   'computation',
#   'julia',
#   'high',
#   'level',
#   'high',
#   'performance',
#   'dynamic',
#   'programming',
#   'language',
#   'suited',
#   'numerical',
#   'analysis',
#   'computational',
#   'science',
#   'framework',
#   'tensorflow',
#   'framework',
#   'create',
#   'machine_learning',
#   'model',
#   'develop',
#   'google',
#   'pytorch',
#   'framework',
#   'machine_learning',
#   'develop',
#   'facebook',
#   'jupyter',
#   'notebook',
#   'interactive',
#   'web',
#   'interface',
#   'python',
#   'allow',
#   'fast',
#   'experimentation',
#   'apache',
#   'hadoop',
#   'software',
#   'framework',
#   'process',
#   'datum',
#   'large',
#   'distribute',
#   'system',
#   'visualization',
#   'tool',
#   'plotly',
#   'provide',
#   'rich',
#   'set',
#   'interactive',
#   'scientific',
#   'graphing',
#   'library',
#   'tableau',
#   'make',
#   'variety',
#   'software',
#   'data',
#   'visualization',
#   'powerbi',
#   'business',
#   'analytic',
#   'service',
#   'microsoft',
#   'qlik',
#   'produce',
#   'software',
#   'qlikview',
#   'qlik',
#   'sense',
#   'data',
#   'visualization',
#   'business',
#   'intelligence',
#   'anychart',
#   'provide',
#   'javascript',
#   'library',
#   'tool',
#   'data',
#   'visualization',
#   'chart',
#   'dashboard',
#   'google',
#   'chart',
#   'javascript',
#   'base',
#   'web',
#   'service',
#   'support',
#   'google',
#   'create',
#   'graphical',
#   'chart',
#   'sisense',
#   'provide',
#   'end',
#   'build',
#   'datum',
#   'visualization',
#   'include',
#   'dashboard',
#   'report',
#   'webix',
#   'ui',
#   'toolkit',
#   'include',
#   'dedicated',
#   'tool',
#   'information',
#   'visualization',
#   'platform',
#   'rapidminer',
#   'data_science',
#   'software',
#   'platform',
#   'develop',
#   'company',
#   'dataiku',
#   'collaborative',
#   'datum_science',
#   'software',
#   'market',
#   'big',
#   'data',
#   'anaconda',
#   'provide',
#   'comprehensive',
#   'free',
#   'open',
#   'source',
#   'distribution',
#   'python',
#   'programming',
#   'language',
#   'matlab',
#   'compute',
#   'environment',
#   'heavily',
#   'industry',
#   'academia',
#   'reference'],
#  ['cricket',
#   'bat',
#   'ball',
#   'game',
#   'play',
#   'team',
#   'player',
#   'field',
#   'centre',
#   'pitch',
#   'wicket',
#   'end',
#   'comprise',
#   'bail',
#   'balance',
#   'stump',
#   'batting',
#   'score_run',
#   'strike',
#   'ball',
#   'bowl',
#   'wicket',
#   'bat',
#   'run',
#   'wicket',
#   'bowling',
#   'field',
#   'try',
#   'prevent',
#   'prevent',
#   'ball',
#   'leave',
#   'field',
#   'get',
#   'ball',
#   'wicket',
#   'dismiss',
#   'batter',
#   'mean',
#   'dismissal',
#   'include',
#   'bowl',
#   'ball',
#   'hit',
#   'stump',
#   'dislodge',
#   'bail',
#   'fielding',
#   'catch',
#   'ball',
#   'hit',
#   'bat',
#   'hit',
#   'ground',
#   'hit',
#   'wicket',
#   'ball',
#   'batter',
#   'cross',
#   'crease',
#   'wicket',
#   'batter',
#   'dismiss',
#   'innings',
#   'end',
#   'team',
#   'swap',
#   'role',
#   'game',
#   'adjudicate',
#   'umpire',
#   'aid',
#   'umpire',
#   'match',
#   'referee',
#   'international',
#   'match',
#   'communicate',
#   'field',
#   'scorer',
#   'record',
#   'match',
#   'statistical',
#   'information',
#   'form',
#   'cricket',
#   'range',
#   'team',
#   'batting',
#   'single',
#   'inning',
#   'over',
#   'test_match',
#   'play',
#   'day',
#   'traditionally',
#   'cricketer',
#   'play',
#   'white',
#   'kit',
#   'limited_over',
#   'cricket',
#   'wear',
#   'club',
#   'team',
#   'colour',
#   'addition',
#   'basic',
#   'kit',
#   'player',
#   'wear',
#   'protective',
#   'gear',
#   'prevent',
#   'injury',
#   'cause',
#   'ball',
#   'hard',
#   'solid',
#   'spheroid',
#   'compress',
#   'leather',
#   'slightly',
#   'raise',
#   'sewn',
#   'seam',
#   'enclose',
#   'cork',
#   'core',
#   'layer',
#   'tightly',
#   'wind',
#   'stre',
#   'early',
#   'reference',
#   'cricket',
#   'south',
#   'east',
#   'england',
#   'century',
#   'spread',
#   'globally',
#   'expansion',
#   'british',
#   'empire',
#   'international',
#   'match',
#   'second',
#   'half',
#   'century',
#   'game',
#   'govern',
#   'body',
#   'international_cricket',
#   'council',
#   'icc_member',
#   'member',
#   'play',
#   'test_match',
#   'game',
#   'rule',
#   'law',
#   'cricket',
#   'maintain',
#   'marylebone',
#   'cricket',
#   'club',
#   'mcc',
#   'london',
#   'sport',
#   'follow',
#   'primarily',
#   'indian',
#   'subcontinent',
#   'australasia',
#   'united',
#   'kingdom',
#   'southern',
#   'africa',
#   'west',
#   'indies',
#   'woman',
#   'cricket',
#   'organise',
#   'play',
#   'separately',
#   'achieve',
#   'international',
#   'standard',
#   'successful',
#   'play',
#   'international_cricket',
#   'australia',
#   'win',
#   'day',
#   'international',
#   'trophy',
#   'include',
#   'world_cup',
#   'country',
#   'rate',
#   'test',
#   'country',
#   'history',
#   'origin',
#   'cricket',
#   'game',
#   'club',
#   'ball',
#   'sphere',
#   'basically',
#   'involve',
#   'hit_ball',
#   'hand',
#   'hold',
#   'implement',
#   'include',
#   'baseball',
#   'share',
#   'similarity',
#   'cricket',
#   'belong',
#   'specific',
#   'bat',
#   'ball',
#   'game',
#   'category',
#   'golf',
#   'hockey',
#   'tennis',
#   'squash',
#   'badminton',
#   'table',
#   'tennis',
#   'cricket',
#   'case',
#   'key',
#   'difference',
#   'existence',
#   'solid',
#   'target',
#   'structure',
#   'wicket',
#   'originally',
#   'think',
#   'wicket',
#   'gate',
#   'sheep',
#   'herd',
#   'batsman',
#   'defend',
#   'cricket',
#   'historian',
#   'harry',
#   'altham',
#   'identify',
#   'group',
#   'club',
#   'ball',
#   'game',
#   'hockey',
#   'group',
#   'ball',
#   'drive',
#   'fro',
#   'target',
#   'goal',
#   'golf',
#   'group',
#   'ball',
#   'drive',
#   'undefended',
#   'target',
#   'hole',
#   'cricket',
#   'group',
#   'ball',
#   'aim',
#   'mark',
#   'wicket',
#   'drive',
#   'away',
#   'generally',
#   'believe',
#   'cricket',
#   'originate',
#   'child',
#   'game',
#   'south',
#   'eastern',
#   'county',
#   'england',
#   'medieval',
#   'period',
#   'claim',
#   'prior',
#   'date',
#   'early',
#   'definite',
#   'reference',
#   'cricket',
#   'play',
#   'come',
#   'evidence',
#   'give',
#   'court',
#   'case',
#   'guildford',
#   'monday',
#   'january',
#   'julian',
#   'calendar',
#   'equate',
#   'january',
#   'gregorian',
#   'calendar',
#   'case',
#   'concerned',
#   'ownership',
#   'certain',
#   'plot',
#   'land',
#   'court',
#   'hear',
#   'testimony',
#   'coroner',
#   'john',
#   'derrick',
#   'give',
#   'witness',
#   'scholler',
#   'ffree',
#   'schoole',
#   'guldeford',
#   'hee',
#   'diverse',
#   'fellow',
#   'runne',
#   'play',
#   'creckett',
#   'play',
#   'give',
#   'derrick',
#   'age',
#   'half',
#   'century',
#   'early',
#   'school',
#   'certain',
#   'cricket',
#   'play',
#   'boy',
#   'surrey',
#   'view',
#   'originally',
#   'child',
#   'game',
#   'reinforce',
#   'randle',
#   'cotgrave',
#   'english',
#   'french',
#   'dictionary',
#   'define',
#   'noun',
#   'crosse',
#   'crooked',
#   'staff',
#   'wherewith',
#   'boy',
#   'play',
#   'cricket',
#   'verb',
#   'form',
#   'crosser',
#   'play',
#   'cricket',
#   'possible',
#   'source',
#   'sport',
#   'old',
#   'english',
#   'word',
#   'cryce',
#   'cricc',
#   'meaning',
#   'crutch',
#   'staff',
#   'samuel',
#   'johnson',
#   'dictionary',
#   'derive',
#   'cricket',
#   'cryce',
#   'saxon',
#   'stick',
#   'old',
#   'french',
#   'word',
#   'criquet',
#   'mean',
#   'kind',
#   'club',
#   'stick',
#   'give',
#   'strong',
#   'medieval',
#   'trade',
#   'connection',
#   'south',
#   'east',
#   'england',
#   'county',
#   'flander',
#   'belong',
#   'duchy',
#   'burgundy',
#   'derive',
#   'middle',
#   'dutch',
#   'use',
#   'flander',
#   'time',
#   'krick',
#   'mean',
#   'stick',
#   'crook',
#   'possible',
#   'source',
#   'middle',
#   'dutch',
#   'word',
#   'krickstoel',
#   'meaning',
#   'long',
#   'low',
#   'stool',
#   'kneel',
#   'church',
#   'resemble',
#   'long',
#   'low',
#   'wicket',
#   'stump',
#   'early',
#   'cricket',
#   'accord',
#   'heiner',
#   'gillmeister',
#   'european',
#   'language',
#   'expert',
#   'bonn',
#   'university',
#   'cricket',
#   'derive',
#   'middle',
#   'dutch',
#   'phrase',
#   'hockey',
#   'meet',
#   'de',
#   'krik',
#   'ket',
#   'sen',
#   'stick',
#   'chase',
#   'gillmeister',
#   'suggest',
#   'sport',
#   'flemish',
#   'origin',
#   'growth',
#   'amateur',
#   'professional',
#   'cricket',
#   'england',
#   'main',
#   'object',
#   'game',
#   'score_run',
#   'early',
#   'form',
#   'cricket',
#   'differ',
#   'modern',
#   'game',
#   'certain',
#   'key',
#   'technical',
#   'aspect',
#   'north',
#   'american',
#   'variant',
#   'cricket',
#   'know',
#   'wicket',
#   'retain',
#   'aspect',
#   'ball',
#   'bowl',
#   'underarm',
#   'bowler',
#   'ground',
#   'batsman',
#   'arm',
#   'bat',
#   'shape',
#   'resemble',
#   'hockey',
#   'stick',
#   'batsman',
#   'defend',
#   'low',
#   'stump',
#   'wicket',
#   'run',
#   'call',
#   'notch',
#   'scorer',
#   'record',
#   'notch',
#   'tally',
#   'stick',
#   'year',
#   'cotgrave',
#   'dictionary',
#   'publish',
#   'ecclesiastical',
#   'court',
#   'record',
#   'sidlesham',
#   'sussex',
#   'state',
#   'parishioner',
#   'bartholomew',
#   'wyatt',
#   'richard',
#   'fail',
#   'attend',
#   'church',
#   'easter',
#   'sunday',
#   'play',
#   'cricket',
#   'fine',
#   'order',
#   'penance',
#   'early',
#   'mention',
#   'adult',
#   'participation',
#   'cricket',
#   'time',
#   'early_know',
#   'organise',
#   'inter',
#   'parish',
#   'village',
#   'match_play',
#   'chevene',
#   'kent',
#   'player',
#   'call',
#   'jasper',
#   'vinall',
#   'die',
#   'accidentally',
#   'strike',
#   'head',
#   'match',
#   'parish',
#   'team',
#   'sussex',
#   'cricket',
#   'remain',
#   'low',
#   'key',
#   'local',
#   'pursuit',
#   'century',
#   'know',
#   'numerous',
#   'reference',
#   'find',
#   'record',
#   'ecclesiastical',
#   'court',
#   'case',
#   'proscribe',
#   'time',
#   'puritan',
#   'commonwealth',
#   'problem',
#   'nearly',
#   'issue',
#   'sunday',
#   'play',
#   'puritan',
#   'consider',
#   'cricket',
#   'profane',
#   'play',
#   'sabbath',
#   'especially',
#   'large',
#   'crowd',
#   'gambling',
#   'involve',
#   'accord',
#   'social',
#   'historian',
#   'derek',
#   'birley',
#   'great',
#   'upsurge',
#   'sport',
#   'restoration',
#   'gambling',
#   'sport',
#   'problem',
#   'significant',
#   'parliament',
#   'pass',
#   'gambling',
#   'act',
#   'limit',
#   'stake',
#   'case',
#   'colossal',
#   'sum',
#   'exceed',
#   'annual',
#   'income',
#   'population',
#   'prizefight',
#   'horse',
#   'racing',
#   'blood',
#   'sport',
#   'cricket',
#   'perceive',
#   'gamble',
#   'sport',
#   'rich',
#   'patron',
#   'match',
#   'high',
#   'stake',
#   'form',
#   'team',
#   'engage',
#   'professional',
#   'player',
#   'end',
#   'century',
#   'cricket',
#   'develop',
#   'major',
#   'sport',
#   'spread',
#   'england',
#   'take',
#   'abroad',
#   'english',
#   'mariner',
#   'coloniser',
#   'early',
#   'reference',
#   'cricket',
#   'overseas',
#   'date',
#   'newspaper',
#   'report',
#   'survive',
#   'great',
#   'cricket',
#   'match_play',
#   'sussex',
#   'guinea',
#   'apiece',
#   'early_know',
#   'contest',
#   'generally',
#   'consider',
#   'class',
#   'match',
#   'patron',
#   'player',
#   'social',
#   'class',
#   'know',
#   'gentry',
#   'begin',
#   'classify',
#   'amateur',
#   'establish',
#   'clear',
#   'distinction',
#   'professional',
#   'invariably',
#   'member',
#   'working',
#   'class',
#   'point',
#   'have',
#   'separate',
#   'changing',
#   'dining',
#   'facility',
#   'gentry',
#   'include',
#   'high',
#   'rank',
#   'noble',
#   'duke',
#   'richmond',
#   'exert',
#   'honour',
#   'code',
#   'noblesse',
#   'oblige',
#   'claim',
#   'right',
#   'leadership',
#   'sporting',
#   'contest',
#   'take',
#   'especially',
#   'necessary',
#   'play',
#   'alongside',
#   'social',
#   'inferior',
#   'win',
#   'bet',
#   'time',
#   'perception',
#   'take',
#   'hold',
#   'typical',
#   'amateur',
#   'play',
#   'class',
#   'cricket',
#   'amateurism',
#   'abolish',
#   'public',
#   'school',
#   'education',
#   'go',
#   'cambridge',
#   'oxford',
#   'university',
#   'society',
#   'insist',
#   'people',
#   'officer',
#   'gentleman',
#   'destiny',
#   'provide',
#   'leadership',
#   'purely',
#   'financial',
#   'sense',
#   'cricket',
#   'amateur',
#   'theoretically',
#   'claim',
#   'expense',
#   'play',
#   'professional',
#   'counterpart',
#   'play',
#   'contract',
#   'pay',
#   'wage',
#   'match',
#   'fee',
#   'practice',
#   'amateur',
#   'claim',
#   'actual',
#   'expenditure',
#   'derisive',
#   'term',
#   'shamateur',
#   'coin',
#   'describe',
#   'practice',
#   'english',
#   'cricket',
#   'century',
#   'game',
#   'undergo',
#   'major',
#   'development',
#   'century',
#   'england',
#   'national',
#   'sport',
#   'success',
#   'underwrite',
#   'twin',
#   'necessity',
#   'patronage',
#   'betting',
#   'cricket',
#   'prominent',
#   'london',
#   'early',
#   'middle',
#   'year',
#   'century',
#   'large',
#   'crowd',
#   'flock',
#   'match',
#   'artillery',
#   'ground',
#   'finsbury',
#   'single',
#   'wicket',
#   'form',
#   'sport',
#   'attract',
#   'huge',
#   'crowd',
#   'wager',
#   'match',
#   'popularity',
#   'peak',
#   'season',
#   'bowling',
#   'undergo',
#   'evolution',
#   'bowler',
#   'begin',
#   'pitch',
#   'ball',
#   'instead',
#   'roll',
#   'skim',
#   'batsman',
#   'cause',
#   'revolution',
#   'bat',
#   'design',
#   'deal',
#   'bouncing',
#   'ball',
#   'necessary',
#   'introduce',
#   'modern',
#   'straight',
#   'bat',
#   'place',
#   'old',
#   'hockey',
#   'stick',
#   'shape',
#   'hambledon',
#   'club',
#   'found',
#   'year',
#   'formation',
#   'marylebone',
#   'cricket',
#   'club',
#   'mcc',
#   'opening',
#   'lord',
#   'old',
#   'ground',
#   'hambledon',
#   'game',
#   'great',
#   'club',
#   'focal',
#   'point',
#   'mcc',
#   'quickly',
#   'sport',
#   'premier',
#   'club',
#   'custodian',
#   'law',
#   'cricket',
#   'new',
#   'law',
#   'introduce',
#   'century',
#   'include',
#   'stump',
#   'wicket',
#   'leg',
#   'wicket',
#   'lbw',
#   'century',
#   'see',
#   'underarm',
#   'bowling',
#   'supersede',
#   'roundarm',
#   'overarm',
#   'bowl',
#   'development',
#   'controversial',
#   'organisation',
#   'game',
#   'county',
#   'level',
#   'lead',
#   'creation',
#   'county',
#   'club',
#   'start',
#   'sussex',
#   'december',
#   'lead',
#   'county',
#   'club',
#   'form',
#   'official',
#   'county',
#   'championship',
#   'begin',
#   'famous',
#   'player',
#   'century',
#   'grace',
#   'start',
#   'long',
#   'influential',
#   'career',
#   'especially',
#   'career',
#   'grace',
#   'distinction',
#   'amateur',
#   'professional',
#   'blur',
#   'existence',
#   'player',
#   'like',
#   'nominally',
#   'amateur',
#   'term',
#   'financial',
#   'gain',
#   'de',
#   'facto',
#   'professional',
#   'grace',
#   'say',
#   'pay',
#   'money',
#   'play',
#   'cricket',
#   'professional',
#   'decade',
#   'world',
#   'war',
#   'call',
#   'golden',
#   'age',
#   'cricket',
#   'nostalgic',
#   'prompt',
#   'collective',
#   'sense',
#   'loss',
#   'result',
#   'war',
#   'period',
#   'produce',
#   'great',
#   'player',
#   'memorable',
#   'match',
#   'especially',
#   'organise',
#   'competition',
#   'county',
#   'test',
#   'level',
#   'develop',
#   'cricket',
#   'international',
#   'sport',
#   'british',
#   'empire',
#   'instrumental',
#   'spread',
#   'game',
#   'overseas',
#   'middle',
#   'century',
#   'establish',
#   'australia',
#   ...],
#  ['taj_mahal',
#   'light',
#   'crown',
#   'palace',
#   'ta',
#   'ivory',
#   'white_marble',
#   'mausoleum',
#   'southern',
#   'bank',
#   'river',
#   'yamuna',
#   'indian',
#   'city',
#   'agra',
#   'commission',
#   'mughal',
#   'emperor',
#   'shah_jahan',
#   'reign',
#   'house',
#   'tomb',
#   'favourite',
#   'wife',
#   'mumtaz_mahal',
#   'house',
#   'tomb',
#   'shah_jahan',
#   'tomb',
#   'centrepiece',
#   'complex',
#   'include',
#   'mosque',
#   'guest',
#   'house',
#   'set',
#   'formal',
#   'garden',
#   'bound',
#   'side',
#   'crenellate',
#   'wall',
#   'construction',
#   'mausoleum',
#   'essentially',
#   'complete',
#   'work',
#   'continue',
#   'phase',
#   'project',
#   'year',
#   'taj_mahal',
#   'complex',
#   'believe',
#   'complete',
#   'entirety',
#   'cost',
#   'estimate',
#   'time',
#   'rupee',
#   'approximately',
#   'rupee',
#   'construction',
#   'project',
#   'employ',
#   'artisan',
#   'guidance',
#   'board',
#   'architect',
#   'lead',
#   'court',
#   'architect',
#   'emperor',
#   'ustad',
#   'ahmad',
#   'lahauri',
#   'taj_mahal',
#   'designate',
#   'unesco',
#   'world',
#   'heritage',
#   'site',
#   'jewel',
#   'muslim',
#   'art',
#   'india',
#   'universally',
#   'admire',
#   'masterpiece',
#   'world',
#   'heritage',
#   'regard',
#   'good',
#   'example',
#   'mughal',
#   'architecture',
#   'symbol',
#   'india',
#   'rich',
#   'history',
#   'taj_mahal',
#   'attract',
#   'visitor',
#   'year',
#   'declare',
#   'winner',
#   'new',
#   'wonder',
#   'world',
#   'initiative',
#   'inspiration',
#   'taj_mahal',
#   'commission',
#   'shah_jahan',
#   'build',
#   'memory',
#   'wife',
#   'mumtaz_mahal',
#   'die',
#   'june',
#   'year',
#   'give',
#   'birth',
#   'child',
#   'gauhara',
#   'begum',
#   'construction',
#   'start',
#   'mausoleum',
#   'complete',
#   'surround',
#   'building',
#   'garden',
#   'finish',
#   'year',
#   'later',
#   'imperial',
#   'court',
#   'document',
#   'shah_jahan',
#   'grief',
#   'death',
#   'mumtaz_mahal',
#   'illustrate',
#   'love',
#   'story',
#   'hold',
#   'inspiration',
#   'taj_mahal',
#   'architecture',
#   'design',
#   'taj_mahal',
#   'incorporate',
#   'expand',
#   'design',
#   'tradition',
#   'persian',
#   'early',
#   'mughal',
#   'architecture',
#   'specific',
#   'inspiration',
#   'come',
#   'successful',
#   'timurid',
#   'mughal',
#   'building',
#   'include',
#   'gur',
#   'amir',
#   'tomb',
#   'timur',
#   'progenitor',
#   'mughal',
#   'dynasty',
#   'samarkand',
#   'humayun',
#   'tomb',
#   'inspire',
#   'charbagh',
#   'garden',
#   'hasht',
#   'behesht',
#   'architecture',
#   'plan',
#   'site',
#   'itmad',
#   'ud',
#   'daulah',
#   'tomb',
#   'call',
#   'baby',
#   'taj',
#   'shah_jahan',
#   'jama',
#   'masjid',
#   'delhi',
#   'early',
#   'mughal',
#   'building',
#   'primarily',
#   'construct',
#   'red',
#   'sandstone',
#   'shah_jahan',
#   'promote',
#   'use',
#   'white_marble',
#   'inlay',
#   'semi',
#   'precious',
#   'stone',
#   'building',
#   'patronage',
#   'reach',
#   'new',
#   'level',
#   'refinement',
#   'tomb',
#   'tomb',
#   'central',
#   'focus',
#   'entire',
#   'complex',
#   'taj_mahal',
#   'large',
#   'white_marble',
#   'structure',
#   'stand',
#   'square',
#   'plinth',
#   'consist',
#   'symmetrical',
#   'building',
#   'iwan',
#   'arch',
#   'shape',
#   'doorway',
#   'top',
#   'large',
#   'dome',
#   'finial',
#   'like',
#   'mughal',
#   'tomb',
#   'basic',
#   'element',
#   'persian',
#   'origin',
#   'base',
#   'structure',
#   'large',
#   'multi',
#   'chamber',
#   'cube',
#   'chamfer',
#   'corner',
#   'form',
#   'unequal',
#   'side',
#   'structure',
#   'approximately',
#   'metre_ft',
#   'long',
#   'side',
#   'iwan',
#   'frame',
#   'huge',
#   'pishtaq',
#   'vault',
#   'archway',
#   'similarly',
#   'shape',
#   'arched',
#   'balcony',
#   'stack',
#   'motif',
#   'stack',
#   'pishtaqs',
#   'replicate',
#   'chamfer',
#   'corner',
#   'area',
#   'make',
#   'design',
#   'completely',
#   'symmetrical',
#   'side',
#   'building',
#   'minaret',
#   'frame',
#   'tomb',
#   'corner',
#   'plinth',
#   'face',
#   'chamfer',
#   'corner',
#   'main',
#   'chamber',
#   'house',
#   'false',
#   'sarcophagi',
#   'mumtaz_mahal',
#   'shah_jahan',
#   'actual',
#   'grave',
#   'low',
#   'level',
#   'spectacular',
#   'feature',
#   'marble',
#   'dome',
#   'surmount',
#   'tomb',
#   'dome',
#   'nearly',
#   'metre_ft',
#   'high',
#   'close',
#   'measurement',
#   'length',
#   'base',
#   'accentuate',
#   'cylindrical',
#   'drum',
#   'sit',
#   'approximately',
#   'metre_ft',
#   'high',
#   'shape',
#   'dome',
#   'call',
#   'onion',
#   'dome',
#   'amrud',
#   'guava',
#   'dome',
#   'decorate',
#   'lotus',
#   'design',
#   'serve',
#   'accentuate',
#   'height',
#   'shape',
#   'dome',
#   'emphasise',
#   'small',
#   'domed',
#   'chattris',
#   'kiosks',
#   'place',
#   'corner',
#   'replicate',
#   'onion',
#   'shape',
#   'main',
#   'dome',
#   'dome',
#   'slightly',
#   'asymmetrical',
#   'columned',
#   'basis',
#   'open',
#   'roof',
#   'tomb',
#   'provide',
#   'light',
#   'interior',
#   'tall',
#   'decorative',
#   'spire',
#   'guldasta',
#   'extend',
#   'edge',
#   'base',
#   'wall',
#   'provide',
#   'visual',
#   'emphasis',
#   'height',
#   'dome',
#   'lotus',
#   'motif',
#   'repeat',
#   'chattris',
#   'guldasta',
#   'dome',
#   'chattris',
#   'top',
#   'gild',
#   'finial',
#   'mix',
#   'traditional',
#   'persian',
#   'hindustani',
#   'decorative_element',
#   'main',
#   'finial',
#   'originally',
#   'gold',
#   'replace',
#   'copy',
#   'gild',
#   'bronze',
#   'early',
#   'century',
#   'feature',
#   'provide',
#   'clear',
#   'example',
#   'integration',
#   'traditional',
#   'persian',
#   'hindu',
#   'decorative_element',
#   'finial',
#   'top',
#   'moon',
#   'typical',
#   'islamic',
#   'motif',
#   'horn',
#   'point',
#   'heavenward',
#   'minaret',
#   'metre_ft',
#   'tall',
#   'display',
#   'designer',
#   'penchant',
#   'symmetry',
#   'design',
#   'work',
#   'minaret',
#   'traditional',
#   'element',
#   'mosque',
#   'muezzin',
#   'islamic',
#   'faithful',
#   'prayer',
#   'minaret',
#   'effectively',
#   'divide',
#   'equal',
#   'part',
#   'working',
#   'balcony',
#   'ring',
#   'tower',
#   'tower',
#   'final',
#   'balcony',
#   'surmount',
#   'chattri',
#   'mirror',
#   'design',
#   'tomb',
#   'chattris',
#   'share',
#   'decorative_element',
#   'lotus',
#   'design',
#   'top',
#   'gild',
#   'finial',
#   'minaret',
#   'construct',
#   'slightly',
#   'outside',
#   'plinth',
#   'event',
#   'collapse',
#   'typical',
#   'occurrence',
#   'tall',
#   'construction',
#   'period',
#   'material',
#   'tower',
#   'tend',
#   'fall',
#   'away',
#   'tomb',
#   'exterior',
#   'decoration',
#   'exterior',
#   'decoration',
#   'taj_mahal',
#   'fine',
#   'mughal',
#   'architecture',
#   'surface',
#   'area',
#   'change',
#   'decoration',
#   'refine',
#   'proportionally',
#   'decorative_element',
#   'create',
#   'apply',
#   'paint',
#   'stucco',
#   'stone',
#   'inlay',
#   'carving',
#   'line',
#   'islamic',
#   'prohibition',
#   'use',
#   'anthropomorphic',
#   'form',
#   'decorative_element',
#   'group',
#   'calligraphy',
#   'abstract',
#   'form',
#   'vegetative',
#   'motif',
#   'complex',
#   'passage',
#   'qur',
#   'comprise',
#   'decorative_element',
#   'recent',
#   'scholarship',
#   'suggest',
#   'amanat',
#   'khan',
#   'choose',
#   'passage',
#   'calligraphy',
#   'great',
#   'gate',
#   'read',
#   'soul',
#   'thou',
#   'art',
#   'rest',
#   'return',
#   'lord',
#   'peace',
#   'peace',
#   'calligraphy',
#   'create',
#   'calligrapher',
#   'name',
#   'abdul',
#   'haq',
#   'shah_jahan',
#   'confer',
#   'title',
#   'amanat',
#   'khan',
#   'reward',
#   'dazzling',
#   'virtuosity',
#   'near',
#   'line',
#   'qur',
#   'base',
#   'interior',
#   'dome',
#   'inscription',
#   'write',
#   'insignificant',
#   'amanat',
#   'khan',
#   'shirazi',
#   'calligraphy',
#   'compose',
#   'florid',
#   'thuluth',
#   'script',
#   'jasper',
#   'black',
#   'marble',
#   'inlaid',
#   'white_marble',
#   'panel',
#   'high',
#   'panel',
#   'write',
#   'slightly',
#   'large',
#   'script',
#   'reduce',
#   'skewing',
#   'effect',
#   'view',
#   'calligraphy',
#   'find',
#   'marble',
#   'cenotaph',
#   'tomb',
#   'particularly',
#   'detailed',
#   'delicate',
#   'abstract',
#   'form',
#   'especially',
#   'plinth',
#   'minarets',
#   'gateway',
#   'mosque',
#   'jawab',
#   'less',
#   'extent',
#   'surface',
#   'tomb',
#   'dome',
#   'vault',
#   'sandstone',
#   'building',
#   'work',
#   'tracery',
#   'incise',
#   'painting',
#   'create',
#   'elaborate',
#   'geometric',
#   'form',
#   'herringbone',
#   'inlay',
#   'define',
#   'space',
#   'adjoining',
#   'element',
#   'white',
#   'inlay',
#   'sandstone',
#   'building',
#   'dark',
#   'black',
#   'inlay',
#   'white_marble',
#   'mortar',
#   'area',
#   'marble',
#   'building',
#   'stain',
#   'paint',
#   'contrast',
#   'colour',
#   'create',
#   'complex',
#   'array',
#   'geometric',
#   'pattern',
#   'floor',
#   'walkway',
#   'use',
#   'contrast',
#   'tile',
#   'block',
#   'tessellation',
#   'pattern',
#   'low',
#   'wall',
#   'tomb',
#   'white_marble',
#   'dado',
#   'sculpt',
#   'realistic',
#   'bas',
#   'relief',
#   'depiction',
#   'flower',
#   'vine',
#   'marble',
#   'polish',
#   'emphasise',
#   'exquisite',
#   'detailing',
#   'carving',
#   'dado',
#   'frame',
#   'archway',
#   'spandrel',
#   'decorate',
#   'pietra',
#   'dura',
#   'inlay',
#   'highly',
#   'stylise',
#   'geometric',
#   'vine',
#   'flower',
#   'fruit',
#   'inlay',
#   'stone',
#   'yellow',
#   'marble',
#   'jasper',
#   'jade',
#   'polish',
#   'level',
#   'surface',
#   'wall',
#   'interior',
#   'decoration',
#   'interior',
#   'chamber',
#   'taj_mahal',
#   'reach',
#   'far',
#   'traditional',
#   'decorative_element',
#   'inlay',
#   'work',
#   'pietra',
#   'dura',
#   'lapidary',
#   'precious',
#   'semiprecious',
#   'gemstone',
#   'inner',
#   'chamber',
#   'octagon',
#   'design',
#   'allow',
#   'entry',
#   'face',
#   'door',
#   'face',
#   'garden',
#   'south',
#   'interior',
#   'wall',
#   'metre_ft',
#   'high',
#   'top',
#   'false',
#   'interior',
#   'dome',
#   'decorate',
#   'sun',
#   'motif',
#   'pishtaq',
#   'arch',
#   'define',
#   'space',
#   'ground',
#   'level',
#   'exterior',
#   'low',
#   'pishtaq',
#   'crown',
#   'second',
#   'pishtaq',
#   'midway',
#   'wall',
#   'central',
#   'upper',
#   'arch',
#   'form',
#   'balcony',
#   'view',
#   'area',
#   'balcony',
#   'exterior',
#   'window',
#   'intricate',
#   'screen',
#   'jali',
#   'cut',
#   'marble',
#   'addition',
#   'light',
#   'balcony',
#   'screen',
#   'light',
#   'enter',
#   'roof',
#   'opening',
#   'cover',
#   'chattris',
#   'corner',
#   'octagonal',
#   'marble',
#   'screen',
#   'jali',
#   'border',
#   'cenotaph',
#   'marble',
#   'panel',
#   'carve',
#   'intricate',
#   'pierce',
#   'work',
#   'remain',
#   'surface',
#   'inlay',
#   'delicate',
#   'detail',
#   'semi',
#   'precious',
#   'stone',
#   'form',
#   'twine',
#   'vine',
#   'fruit',
#   'flower',
#   'chamber',
#   'wall',
#   'highly',
#   'decorate',
#   'dado',
#   'bas',
#   'relief',
#   'intricate',
#   'lapidary',
#   'inlay',
#   'refined',
#   'calligraphy',
#   'panel',
#   'reflect',
#   'little',
#   'detail',
#   'design',
#   'element',
#   'see',
#   'exterior',
#   'complex',
#   'muslim',
#   'tradition',
#   'forbid',
#   'elaborate',
#   'decoration',
#   'grave',
#   'body',
#   'mumtaz',
#   'shah_jahan',
#   'relatively',
#   'plain',
#   'crypt',
#   'beneath',
#   'inner',
#   'chamber',
#   'face',
#   'turn',
#   'right',
#   'mecca',
#   'mumtaz_mahal',
#   'cenotaph',
#   'place',
#   'precise',
#   'centre',
#   'inner',
#   'chamber',
#   'rectangular',
#   'marble',
#   'base',
#   'metre_ft',
#   'ft',
#   'base',
#   'casket',
#   'elaborately',
#   'inlaid',
#   'precious',
#   'semiprecious',
#   'gem',
#   'calligraphic',
#   'inscription',
#   'casket',
#   'identify',
#   'praise',
#   'mumtaz',
#   'lid',
#   'casket',
#   'raise',
#   'rectangular',
#   'lozenge',
#   'mean',
#   'suggest',
#   'write',
#   'tablet',
#   'shah_jahan',
#   'cenotaph',
#   'mumtaz',
#   'western',
#   'visible',
#   'asymmetric',
#   'element',
#   'entire',
#   'complex',
#   'cenotaph',
#   'big',
#   'wife',
#   'reflect',
#   'element',
#   'large',
#   'casket',
#   'slightly',
#   'tall',
#   'base',
#   'precisely',
#   'decorate',
#   'lapidary',
#   'calligraphy',
#   'identify',
#   'lid',
#   'casket',
#   'traditional',
#   'sculpture',
#   'small',
#   'pen',
#   'box',
#   'pen',
#   'box',
#   'writing',
#   'tablet',
#   'traditional',
#   'mughal',
#   'funerary',
#   'icon',
#   'decorate',
#   'casket',
#   'man',
#   'woman',
#   'respectively',
#   'name',
#   'god',
#   'calligraphic',
#   'inscription',
#   'side',
#   'actual',
#   'tomb',
#   'mumtaz_mahal',
#   'inscription',
#   'inside',
#   'crypt',
#   'include',
#   'noble',
#   'magnificent',
#   'majestic',
#   'unique',
#   'eternal',
#   'glorious',
#   'tomb',
#   'shah_jahan',
#   'bear',
#   'calligraphic',
#   'inscription',
#   'read',
#   'travel',
#   'world',
#   'banquet',
#   'hall',
#   'eternity',
#   'night',
#   'sixth',
#   'month',
#   'rajab',
#   'year',
#   'hijri',
#   'garden',
#   'complex',
#   'set',
#   'large',
#   'ft',
#   'square',
#   'charbagh',
#   'mughal',
#   'garden',
#   'garden',
#   'use',
#   'raise',
#   'pathway',
#   'divide',
#   'quarter',
#   'garden',
#   'sink',
#   'parterre',
#   'flowerbed',
#   'halfway',
#   'tomb',
#   'gateway',
#   'centre',
#   'garden',
#   'raise',
#   'marble',
#   'water',
#   'tank',
#   'reflect',
#   'pool',
#   'position',
#   'north',
#   'south',
#   'axis',
#   'reflect',
#   'image',
#   'mausoleum',
#   'elevated',
#   'marble',
#   'water',
#   'tank',
#   'call',
#   'al',
#   'hawd',
#   ...]]

# %%
texts[1][0:10]
# Out:
# ['data_science',
#  'inter',
#  'disciplinary',
#  'field',
#  'use',
#  'scientific',
#  'method',
#  'process',
#  'algorithm',
#  'system']

# %%
dictionary = Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
corpus
# Out:
# [[(0, 1),
#   (1, 1),
#   (2, 3),
#   (3, 1),
#   (4, 1),
#   (5, 1),
#   (6, 1),
#   (7, 1),
#   (8, 1),
#   (9, 5),
#   (10, 11),
#   (11, 2),
#   (12, 1),
#   (13, 1),
#   (14, 2),
#   (15, 2),
#   (16, 2),
#   (17, 1),
#   (18, 4),
#   (19, 1),
#   (20, 4),
#   (21, 1),
#   (22, 5),
#   (23, 1),
#   (24, 4),
#   (25, 3),
#   (26, 1),
#   (27, 1),
#   (28, 2),
#   (29, 3),
#   (30, 1),
#   (31, 1),
#   (32, 3),
#   (33, 2),
#   (34, 2),
#   (35, 9),
#   (36, 1),
#   (37, 1),
#   (38, 1),
#   (39, 17),
#   (40, 2),
#   (41, 1),
#   (42, 1),
#   (43, 1),
#   (44, 1),
#   (45, 1),
#   (46, 4),
#   (47, 10),
#   (48, 1),
#   (49, 1),
#   (50, 1),
#   (51, 1),
#   (52, 1),
#   (53, 4),
#   (54, 6),
#   (55, 4),
#   (56, 3),
#   (57, 3),
#   (58, 2),
#   (59, 5),
#   (60, 1),
#   (61, 1),
#   (62, 1),
#   (63, 1),
#   (64, 8),
#   (65, 1),
#   (66, 3),
#   (67, 2),
#   (68, 1),
#   (69, 8),
#   (70, 1),
#   (71, 3),
#   (72, 1),
#   (73, 1),
#   (74, 1),
#   (75, 1),
#   (76, 6),
#   (77, 1),
#   (78, 1),
#   (79, 2),
#   (80, 15),
#   (81, 2),
#   (82, 1),
#   (83, 2),
#   (84, 3),
#   (85, 1),
#   (86, 1),
#   (87, 4),
#   (88, 1),
#   (89, 2),
#   (90, 1),
#   (91, 1),
#   (92, 2),
#   (93, 1),
#   (94, 2),
#   (95, 1),
#   (96, 1),
#   (97, 1),
#   (98, 3),
#   (99, 1),
#   (100, 2),
#   (101, 1),
#   (102, 3),
#   (103, 27),
#   (104, 1),
#   (105, 2),
#   (106, 23),
#   (107, 1),
#   (108, 1),
#   (109, 1),
#   (110, 1),
#   (111, 1),
#   (112, 2),
#   (113, 2),
#   (114, 1),
#   (115, 3),
#   (116, 1),
#   (117, 3),
#   (118, 5),
#   (119, 3),
#   (120, 2),
#   (121, 1),
#   (122, 1),
#   (123, 2),
#   (124, 1),
#   (125, 3),
#   (126, 2),
#   (127, 3),
#   (128, 1),
#   (129, 1),
#   (130, 1),
#   (131, 1),
#   (132, 3),
#   (133, 1),
#   (134, 1),
#   (135, 1),
#   (136, 3),
#   (137, 2),
#   (138, 3),
#   (139, 1),
#   (140, 1),
#   (141, 1),
#   (142, 3),
#   (143, 5),
#   (144, 2),
#   (145, 1),
#   (146, 1),
#   (147, 2),
#   (148, 11),
#   (149, 1),
#   (150, 12),
#   (151, 4),
#   (152, 5),
#   (153, 1),
#   (154, 1),
#   (155, 4),
#   (156, 1),
#   (157, 1),
#   (158, 8),
#   (159, 2),
#   (160, 1),
#   (161, 2),
#   (162, 11),
#   (163, 2),
#   (164, 1),
#   (165, 2),
#   (166, 4),
#   (167, 1),
#   (168, 1),
#   (169, 1),
#   (170, 1),
#   (171, 14),
#   (172, 1),
#   (173, 1),
#   (174, 1),
#   (175, 4),
#   (176, 1),
#   (177, 2),
#   (178, 1),
#   (179, 1),
#   (180, 1),
#   (181, 2),
#   (182, 1),
#   (183, 1),
#   (184, 1),
#   (185, 2),
#   (186, 1),
#   (187, 2),
#   (188, 1),
#   (189, 2),
#   (190, 1),
#   (191, 1),
#   (192, 7),
#   (193, 2),
#   (194, 1),
#   (195, 1),
#   (196, 1),
#   (197, 2),
#   (198, 1),
#   (199, 1),
#   (200, 9),
#   (201, 1),
#   (202, 1),
#   (203, 2),
#   (204, 5),
#   (205, 1),
#   (206, 2),
#   (207, 1),
#   (208, 1),
#   (209, 1),
#   (210, 1),
#   (211, 1),
#   (212, 1),
#   (213, 1),
#   (214, 1),
#   (215, 1),
#   (216, 1),
#   (217, 7),
#   (218, 3),
#   (219, 1),
#   (220, 1),
#   (221, 1),
#   (222, 1),
#   (223, 3),
#   (224, 1),
#   (225, 8),
#   (226, 2),
#   (227, 3),
#   (228, 1),
#   (229, 11),
#   (230, 4),
#   (231, 1),
#   (232, 2),
#   (233, 5),
#   (234, 1),
#   (235, 1),
#   (236, 1),
#   (237, 1),
#   (238, 10),
#   (239, 1),
#   (240, 2),
#   (241, 1),
#   (242, 85),
#   (243, 1),
#   (244, 19),
#   (245, 1),
#   (246, 1),
#   (247, 6),
#   (248, 6),
#   (249, 3),
#   (250, 1),
#   (251, 1),
#   (252, 1),
#   (253, 7),
#   (254, 4),
#   (255, 10),
#   (256, 2),
#   (257, 1),
#   (258, 2),
#   (259, 4),
#   (260, 1),
#   (261, 1),
#   (262, 1),
#   (263, 1),
#   (264, 1),
#   (265, 2),
#   (266, 1),
#   (267, 1),
#   (268, 1),
#   (269, 4),
#   (270, 1),
#   (271, 2),
#   (272, 1),
#   (273, 41),
#   (274, 35),
#   (275, 1),
#   (276, 1),
#   (277, 1),
#   (278, 4),
#   (279, 5),
#   (280, 3),
#   (281, 1),
#   (282, 7),
#   (283, 16),
#   (284, 1),
#   (285, 1),
#   (286, 1),
#   (287, 1),
#   (288, 1),
#   (289, 10),
#   (290, 1),
#   (291, 1),
#   (292, 1),
#   (293, 1),
#   (294, 3),
#   (295, 1),
#   (296, 11),
#   (297, 1),
#   (298, 3),
#   (299, 3),
#   (300, 7),
#   (301, 1),
#   (302, 8),
#   (303, 1),
#   (304, 1),
#   (305, 1),
#   (306, 1),
#   (307, 1),
#   (308, 2),
#   (309, 1),
#   (310, 2),
#   (311, 3),
#   (312, 1),
#   (313, 2),
#   (314, 1),
#   (315, 2),
#   (316, 2),
#   (317, 1),
#   (318, 6),
#   (319, 2),
#   (320, 1),
#   (321, 1),
#   (322, 2),
#   (323, 1),
#   (324, 1),
#   (325, 1),
#   (326, 1),
#   (327, 2),
#   (328, 5),
#   (329, 2),
#   (330, 4),
#   (331, 7),
#   (332, 1),
#   (333, 1),
#   (334, 3),
#   (335, 1),
#   (336, 3),
#   (337, 2),
#   (338, 1),
#   (339, 1),
#   (340, 3),
#   (341, 1),
#   (342, 3),
#   (343, 1),
#   (344, 1),
#   (345, 1),
#   (346, 1),
#   (347, 1),
#   (348, 10),
#   (349, 1),
#   (350, 3),
#   (351, 2),
#   (352, 8),
#   (353, 3),
#   (354, 1),
#   (355, 2),
#   (356, 1),
#   (357, 1),
#   (358, 16),
#   (359, 21),
#   (360, 1),
#   (361, 2),
#   (362, 1),
#   (363, 1),
#   (364, 1),
#   (365, 1),
#   (366, 1),
#   (367, 1),
#   (368, 2),
#   (369, 1),
#   (370, 1),
#   (371, 5),
#   (372, 1),
#   (373, 3),
#   (374, 1),
#   (375, 1),
#   (376, 1),
#   (377, 1),
#   (378, 13),
#   (379, 6),
#   (380, 1),
#   (381, 6),
#   (382, 3),
#   (383, 1),
#   (384, 5),
#   (385, 3),
#   (386, 2),
#   (387, 3),
#   (388, 19),
#   (389, 1),
#   (390, 1),
#   (391, 2),
#   (392, 1),
#   (393, 1),
#   (394, 1),
#   (395, 1),
#   (396, 1),
#   (397, 2),
#   (398, 1),
#   (399, 1),
#   (400, 1),
#   (401, 1),
#   (402, 1),
#   (403, 1),
#   (404, 44),
#   (405, 2),
#   (406, 1),
#   (407, 1),
#   (408, 1),
#   (409, 2),
#   (410, 1),
#   (411, 9),
#   (412, 5),
#   (413, 3),
#   (414, 1),
#   (415, 1),
#   (416, 62),
#   (417, 2),
#   (418, 2),
#   (419, 1),
#   (420, 3),
#   (421, 5),
#   (422, 1),
#   (423, 1),
#   (424, 11),
#   (425, 2),
#   (426, 3),
#   (427, 2),
#   (428, 9),
#   (429, 1),
#   (430, 1),
#   (431, 1),
#   (432, 2),
#   (433, 1),
#   (434, 3),
#   (435, 5),
#   (436, 2),
#   (437, 1),
#   (438, 1),
#   (439, 2),
#   (440, 2),
#   (441, 1),
#   (442, 2),
#   (443, 1),
#   (444, 3),
#   (445, 2),
#   (446, 1),
#   (447, 3),
#   (448, 9),
#   (449, 1),
#   (450, 27),
#   (451, 1),
#   (452, 1),
#   (453, 1),
#   (454, 50),
#   (455, 1),
#   (456, 18),
#   (457, 1),
#   (458, 2),
#   (459, 13),
#   (460, 3),
#   (461, 1),
#   (462, 4),
#   (463, 1),
#   (464, 2),
#   (465, 3),
#   (466, 1),
#   (467, 1),
#   (468, 1),
#   (469, 1),
#   (470, 4),
#   (471, 2),
#   (472, 1),
#   (473, 1),
#   (474, 5),
#   (475, 1),
#   (476, 1),
#   (477, 1),
#   (478, 2),
#   (479, 1),
#   (480, 1),
#   (481, 2),
#   (482, 2),
#   (483, 1),
#   (484, 1),
#   (485, 2),
#   (486, 1),
#   (487, 1),
#   (488, 5),
#   (489, 1),
#   (490, 1),
#   (491, 2),
#   (492, 8),
#   (493, 3),
#   (494, 1),
#   (495, 1),
#   (496, 1),
#   (497, 1),
#   (498, 2),
#   (499, 1),
#   (500, 3),
#   (501, 5),
#   (502, 1),
#   (503, 1),
#   (504, 1),
#   (505, 1),
#   (506, 7),
#   (507, 2),
#   (508, 1),
#   (509, 4),
#   (510, 1),
#   (511, 5),
#   (512, 1),
#   (513, 2),
#   (514, 3),
#   (515, 1),
#   (516, 4),
#   (517, 6),
#   (518, 3),
#   (519, 1),
#   (520, 1),
#   (521, 1),
#   (522, 1),
#   (523, 1),
#   (524, 1),
#   (525, 1),
#   (526, 3),
#   (527, 2),
#   (528, 39),
#   (529, 1),
#   (530, 2),
#   (531, 1),
#   (532, 1),
#   (533, 1),
#   (534, 1),
#   (535, 1),
#   (536, 1),
#   (537, 3),
#   (538, 3),
#   (539, 1),
#   (540, 5),
#   (541, 1),
#   (542, 2),
#   (543, 1),
#   (544, 1),
#   (545, 2),
#   (546, 1),
#   (547, 6),
#   (548, 3),
#   (549, 1),
#   (550, 1),
#   (551, 3),
#   (552, 1),
#   (553, 2),
#   (554, 2),
#   (555, 1),
#   (556, 1),
#   (557, 1),
#   (558, 1),
#   (559, 3),
#   (560, 1),
#   (561, 1),
#   (562, 2),
#   (563, 3),
#   (564, 1),
#   (565, 4),
#   (566, 1),
#   (567, 2),
#   (568, 1),
#   (569, 24),
#   (570, 1),
#   (571, 1),
#   (572, 2),
#   (573, 1),
#   (574, 1),
#   (575, 2),
#   (576, 9),
#   (577, 1),
#   (578, 2),
#   (579, 3),
#   (580, 1),
#   (581, 1),
#   (582, 2),
#   (583, 9),
#   (584, 1),
#   (585, 2),
#   (586, 1),
#   (587, 3),
#   (588, 1),
#   (589, 1),
#   (590, 1),
#   (591, 1),
#   (592, 3),
#   (593, 2),
#   (594, 2),
#   (595, 1),
#   (596, 1),
#   (597, 1),
#   (598, 2),
#   (599, 14),
#   (600, 1),
#   (601, 1),
#   (602, 1),
#   (603, 2),
#   (604, 1),
#   (605, 1),
#   (606, 6),
#   (607, 6),
#   (608, 1),
#   (609, 1),
#   (610, 1),
#   (611, 1),
#   (612, 1),
#   (613, 1),
#   (614, 1),
#   (615, 4),
#   (616, 1),
#   (617, 1),
#   (618, 5),
#   (619, 1),
#   (620, 6),
#   (621, 4),
#   (622, 1),
#   (623, 1),
#   (624, 9),
#   (625, 2),
#   (626, 1),
#   (627, 10),
#   (628, 2),
#   (629, 1),
#   (630, 1),
#   (631, 4),
#   (632, 7),
#   (633, 2),
#   (634, 1),
#   (635, 16),
#   (636, 1),
#   (637, 1),
#   (638, 1),
#   (639, 1),
#   (640, 3),
#   (641, 1),
#   (642, 11),
#   (643, 10),
#   (644, 1),
#   (645, 6),
#   (646, 2),
#   (647, 1),
#   (648, 1),
#   (649, 1),
#   (650, 12),
#   (651, 1),
#   (652, 1),
#   (653, 2),
#   (654, 3),
#   (655, 1),
#   (656, 4),
#   (657, 3),
#   (658, 1),
#   (659, 1),
#   (660, 3),
#   (661, 3),
#   (662, 1),
#   (663, 3),
#   (664, 1),
#   (665, 1),
#   (666, 1),
#   (667, 2),
#   (668, 3),
#   (669, 1),
#   (670, 1),
#   (671, 1),
#   (672, 1),
#   (673, 1),
#   (674, 2),
#   (675, 4),
#   (676, 3),
#   (677, 1),
#   (678, 2),
#   (679, 1),
#   (680, 4),
#   (681, 3),
#   (682, 13),
#   (683, 4),
#   (684, 1),
#   (685, 1),
#   (686, 2),
#   (687, 1),
#   (688, 1),
#   (689, 1),
#   (690, 1),
#   (691, 9),
#   (692, 2),
#   (693, 2),
#   (694, 8),
#   (695, 2),
#   (696, 1),
#   (697, 2),
#   (698, 7),
#   (699, 2),
#   (700, 2),
#   (701, 1),
#   (702, 1),
#   (703, 6),
#   (704, 2),
#   (705, 32),
#   (706, 4),
#   (707, 1),
#   (708, 1),
#   (709, 1),
#   (710, 1),
#   (711, 1),
#   (712, 3),
#   (713, 3),
#   (714, 1),
#   (715, 2),
#   (716, 2),
#   (717, 2),
#   (718, 1),
#   (719, 1),
#   (720, 3),
#   (721, 3),
#   (722, 11),
#   (723, 1),
#   (724, 2),
#   (725, 1),
#   (726, 1),
#   (727, 1),
#   (728, 3),
#   (729, 3),
#   (730, 1),
#   (731, 3),
#   (732, 3),
#   (733, 1),
#   (734, 3),
#   (735, 5),
#   (736, 1),
#   (737, 1),
#   (738, 5),
#   (739, 1),
#   (740, 3),
#   (741, 5),
#   (742, 1),
#   (743, 1),
#   (744, 6),
#   (745, 1),
#   (746, 1),
#   (747, 1),
#   (748, 8),
#   (749, 2),
#   (750, 1),
#   (751, 1),
#   (752, 2),
#   (753, 1),
#   (754, 1),
#   (755, 1),
#   (756, 3),
#   (757, 1),
#   (758, 3),
#   (759, 1),
#   (760, 2),
#   (761, 1),
#   (762, 1),
#   (763, 1),
#   (764, 1),
#   (765, 2),
#   (766, 6),
#   (767, 14),
#   (768, 1),
#   (769, 2),
#   (770, 1),
#   (771, 1),
#   (772, 1),
#   (773, 1),
#   (774, 2),
#   (775, 4),
#   (776, 1),
#   (777, 1),
#   (778, 2),
#   (779, 3),
#   (780, 1),
#   (781, 18),
#   (782, 1),
#   (783, 5),
#   (784, 1),
#   (785, 1),
#   (786, 4),
#   (787, 1),
#   (788, 3),
#   (789, 1),
#   (790, 1),
#   (791, 40),
#   (792, 1),
#   (793, 3),
#   (794, 1),
#   (795, 1),
#   (796, 6),
#   (797, 1),
#   (798, 1),
#   (799, 1),
#   (800, 1),
#   (801, 1),
#   (802, 1),
#   (803, 11),
#   (804, 1),
#   (805, 1),
#   (806, 3),
#   (807, 1),
#   (808, 1),
#   (809, 2),
#   (810, 1),
#   (811, 1),
#   (812, 1),
#   (813, 7),
#   (814, 1),
#   (815, 2),
#   (816, 13),
#   (817, 2),
#   (818, 2),
#   (819, 1),
#   (820, 1),
#   (821, 2),
#   (822, 1),
#   (823, 3),
#   (824, 1),
#   (825, 2),
#   (826, 1),
#   (827, 1),
#   (828, 33),
#   (829, 6),
#   (830, 10),
#   (831, 1),
#   (832, 1),
#   (833, 1),
#   (834, 1),
#   (835, 1),
#   (836, 5),
#   (837, 2),
#   (838, 2),
#   (839, 1),
#   (840, 22),
#   (841, 3),
#   (842, 1),
#   (843, 4),
#   (844, 2),
#   (845, 1),
#   (846, 3),
#   (847, 1),
#   (848, 1),
#   (849, 1),
#   (850, 2),
#   (851, 12),
#   (852, 1),
#   (853, 3),
#   (854, 17),
#   (855, 1),
#   (856, 1),
#   (857, 1),
#   (858, 2),
#   (859, 2),
#   (860, 7),
#   (861, 2),
#   (862, 1),
#   (863, 2),
#   (864, 1),
#   (865, 9),
#   (866, 1),
#   (867, 8),
#   (868, 6),
#   (869, 1),
#   (870, 3),
#   (871, 1),
#   (872, 2),
#   (873, 1),
#   (874, 1),
#   (875, 3),
#   (876, 1),
#   (877, 1),
#   (878, 1),
#   (879, 1),
#   (880, 4),
#   (881, 1),
#   (882, 1),
#   (883, 1),
#   (884, 2),
#   (885, 4),
#   (886, 5),
#   (887, 1),
#   (888, 3),
#   (889, 1),
#   (890, 3),
#   (891, 3),
#   (892, 1),
#   (893, 4),
#   (894, 1),
#   (895, 2),
#   (896, 2),
#   (897, 9),
#   (898, 1),
#   (899, 1),
#   (900, 1),
#   (901, 4),
#   (902, 3),
#   (903, 1),
#   (904, 7),
#   (905, 1),
#   (906, 1),
#   (907, 1),
#   (908, 1),
#   (909, 1),
#   (910, 40),
#   (911, 1),
#   (912, 20),
#   (913, 2),
#   (914, 1),
#   (915, 2),
#   (916, 1),
#   (917, 3),
#   (918, 10),
#   (919, 1),
#   (920, 11),
#   (921, 10),
#   (922, 2),
#   (923, 4),
#   (924, 16),
#   (925, 8),
#   (926, 32),
#   (927, 4),
#   (928, 1),
#   (929, 2),
#   (930, 1),
#   (931, 2),
#   (932, 3),
#   (933, 1),
#   (934, 1),
#   (935, 6),
#   (936, 2),
#   (937, 1),
#   (938, 1),
#   (939, 1),
#   (940, 2),
#   (941, 3),
#   (942, 1),
#   (943, 1),
#   (944, 1),
#   (945, 1),
#   (946, 6),
#   (947, 1),
#   (948, 4),
#   (949, 2),
#   (950, 1),
#   (951, 2),
#   (952, 1),
#   (953, 1),
#   (954, 2),
#   (955, 3),
#   (956, 1),
#   (957, 3),
#   (958, 1),
#   (959, 1),
#   (960, 1),
#   (961, 1),
#   (962, 1),
#   (963, 1),
#   (964, 15),
#   (965, 2),
#   (966, 3),
#   (967, 5),
#   (968, 1),
#   (969, 4),
#   (970, 2),
#   (971, 3),
#   (972, 1),
#   (973, 1),
#   (974, 1),
#   (975, 1),
#   (976, 14),
#   (977, 5),
#   (978, 1),
#   (979, 1),
#   (980, 1),
#   (981, 1),
#   (982, 4),
#   (983, 7),
#   (984, 1),
#   (985, 12),
#   (986, 8),
#   (987, 19),
#   (988, 1),
#   (989, 2),
#   (990, 1),
#   (991, 1),
#   (992, 1),
#   (993, 34),
#   (994, 6),
#   (995, 1),
#   (996, 1),
#   (997, 1),
#   (998, 1),
#   (999, 1),
#   ...],
#  [(1, 1),
#   (14, 1),
#   (16, 1),
#   (21, 1),
#   (36, 1),
#   (64, 1),
#   (66, 1),
#   (69, 1),
#   (70, 2),
#   (76, 9),
#   (77, 2),
#   (97, 6),
#   (98, 1),
#   (106, 1),
#   (128, 2),
#   (142, 2),
#   (150, 1),
#   (162, 1),
#   (202, 1),
#   (214, 3),
#   (217, 8),
#   (225, 1),
#   (263, 3),
#   (277, 1),
#   (286, 1),
#   (296, 1),
#   (312, 3),
#   (314, 2),
#   (317, 1),
#   (327, 1),
#   (329, 1),
#   (331, 1),
#   (334, 4),
#   (340, 1),
#   (343, 1),
#   (345, 2),
#   (346, 2),
#   (354, 1),
#   (369, 1),
#   (371, 1),
#   (384, 1),
#   (386, 1),
#   (388, 1),
#   (421, 4),
#   (444, 17),
#   (445, 1),
#   (446, 2),
#   (448, 32),
#   (449, 1),
#   (453, 1),
#   (457, 2),
#   (469, 3),
#   (478, 1),
#   (482, 5),
#   (491, 2),
#   (492, 4),
#   (509, 1),
#   (512, 3),
#   (543, 1),
#   (562, 2),
#   (569, 1),
#   (579, 2),
#   (580, 1),
#   (598, 1),
#   (605, 2),
#   (607, 3),
#   (621, 1),
#   (622, 1),
#   (633, 1),
#   (665, 1),
#   (667, 1),
#   (671, 1),
#   (697, 1),
#   (704, 1),
#   (714, 13),
#   (722, 1),
#   (723, 1),
#   (734, 3),
#   (744, 1),
#   (746, 1),
#   (749, 1),
#   (765, 1),
#   (788, 3),
#   (789, 3),
#   (803, 1),
#   (832, 2),
#   (836, 2),
#   (840, 3),
#   (867, 1),
#   (885, 1),
#   (891, 1),
#   (897, 3),
#   (910, 5),
#   (912, 1),
#   (916, 1),
#   (923, 2),
#   (931, 1),
#   (932, 7),
#   (954, 1),
#   (959, 1),
#   (964, 1),
#   (1002, 3),
#   (1007, 2),
#   (1015, 1),
#   (1038, 4),
#   (1041, 2),
#   (1043, 2),
#   (1059, 3),
#   (1069, 1),
#   (1073, 1),
#   (1077, 1),
#   (1087, 1),
#   (1090, 1),
#   (1098, 1),
#   (1104, 1),
#   (1106, 1),
#   (1109, 2),
#   (1110, 1),
#   (1121, 1),
#   (1147, 3),
#   (1211, 1),
#   (1220, 1),
#   (1225, 7),
#   (1251, 2),
#   (1269, 1),
#   (1280, 1),
#   (1283, 1),
#   (1287, 1),
#   (1290, 2),
#   (1293, 2),
#   (1295, 1),
#   (1323, 1),
#   (1355, 2),
#   (1356, 2),
#   (1367, 1),
#   (1390, 3),
#   (1427, 1),
#   (1437, 2),
#   (1441, 1),
#   (1464, 3),
#   (1465, 1),
#   (1467, 2),
#   (1478, 1),
#   (1485, 4),
#   (1515, 2),
#   (1526, 2),
#   (1540, 1),
#   (1549, 1),
#   (1551, 1),
#   (1552, 1),
#   (1553, 1),
#   (1554, 1),
#   (1562, 2),
#   (1565, 2),
#   (1580, 2),
#   (1585, 1),
#   (1588, 2),
#   (1593, 1),
#   (1657, 8),
#   (1658, 3),
#   (1659, 4),
#   (1681, 1),
#   (1696, 2),
#   (1697, 3),
#   (1729, 1),
#   (1730, 1),
#   (1742, 2),
#   (1753, 1),
#   (1758, 1),
#   (1762, 1),
#   (1774, 1),
#   (1804, 17),
#   (1841, 1),
#   (1849, 2),
#   (1875, 4),
#   (1885, 1),
#   (1886, 4),
#   (1893, 2),
#   (1901, 2),
#   (1927, 1),
#   (1929, 1),
#   (1935, 1),
#   (1966, 2),
#   (1996, 3),
#   (2011, 3),
#   (2012, 3),
#   (2014, 2),
#   (2021, 2),
#   (2066, 2),
#   (2077, 1),
#   (2080, 1),
#   (2085, 1),
#   (2088, 1),
#   (2095, 2),
#   (2103, 2),
#   (2112, 1),
#   (2113, 1),
#   (2114, 1),
#   (2115, 2),
#   (2116, 1),
#   (2117, 1),
#   (2118, 1),
#   (2119, 1),
#   (2120, 2),
#   (2121, 2),
#   (2122, 1),
#   (2123, 1),
#   (2124, 1),
#   (2125, 2),
#   (2126, 4),
#   (2127, 3),
#   (2128, 1),
#   (2129, 1),
#   (2130, 1),
#   (2131, 1),
#   (2132, 1),
#   (2133, 1),
#   (2134, 1),
#   (2135, 2),
#   (2136, 1),
#   (2137, 3),
#   (2138, 6),
#   (2139, 1),
#   (2140, 1),
#   (2141, 1),
#   (2142, 1),
#   (2143, 1),
#   (2144, 3),
#   (2145, 1),
#   (2146, 3),
#   (2147, 1),
#   (2148, 1),
#   (2149, 1),
#   (2150, 1),
#   (2151, 1),
#   (2152, 1),
#   (2153, 1),
#   (2154, 1),
#   (2155, 1),
#   (2156, 2),
#   (2157, 4),
#   (2158, 1),
#   (2159, 3),
#   (2160, 1),
#   (2161, 2),
#   (2162, 1),
#   (2163, 1),
#   (2164, 2),
#   (2165, 21),
#   (2166, 8),
#   (2167, 1),
#   (2168, 17),
#   (2169, 1),
#   (2170, 2),
#   (2171, 1),
#   (2172, 1),
#   (2173, 5),
#   (2174, 1),
#   (2175, 1),
#   (2176, 1),
#   (2177, 2),
#   (2178, 1),
#   (2179, 1),
#   (2180, 1),
#   (2181, 1),
#   (2182, 1),
#   (2183, 1),
#   (2184, 1),
#   (2185, 1),
#   (2186, 2),
#   (2187, 1),
#   (2188, 1),
#   (2189, 1),
#   (2190, 2),
#   (2191, 1),
#   (2192, 1),
#   (2193, 3),
#   (2194, 1),
#   (2195, 1),
#   (2196, 1),
#   (2197, 2),
#   (2198, 1),
#   (2199, 1),
#   (2200, 1),
#   (2201, 1),
#   (2202, 1),
#   (2203, 1),
#   (2204, 4),
#   (2205, 1),
#   (2206, 1),
#   (2207, 1),
#   (2208, 1),
#   (2209, 1),
#   (2210, 1),
#   (2211, 1),
#   (2212, 1),
#   (2213, 1),
#   (2214, 2),
#   (2215, 1),
#   (2216, 1),
#   (2217, 1),
#   (2218, 1),
#   (2219, 1),
#   (2220, 1),
#   (2221, 1),
#   (2222, 1),
#   (2223, 1),
#   (2224, 1),
#   (2225, 1),
#   (2226, 1),
#   (2227, 1),
#   (2228, 1),
#   (2229, 2),
#   (2230, 2),
#   (2231, 1),
#   (2232, 1),
#   (2233, 1),
#   (2234, 2),
#   (2235, 2),
#   (2236, 1),
#   (2237, 1),
#   (2238, 1),
#   (2239, 1),
#   (2240, 4),
#   (2241, 5),
#   (2242, 2),
#   (2243, 3),
#   (2244, 1),
#   (2245, 8),
#   (2246, 1),
#   (2247, 2),
#   (2248, 1),
#   (2249, 2),
#   (2250, 1),
#   (2251, 4),
#   (2252, 1),
#   (2253, 2),
#   (2254, 3),
#   (2255, 1),
#   (2256, 1),
#   (2257, 1),
#   (2258, 1),
#   (2259, 1),
#   (2260, 1),
#   (2261, 1),
#   (2262, 1),
#   (2263, 1),
#   (2264, 2),
#   (2265, 1),
#   (2266, 1),
#   (2267, 1),
#   (2268, 1),
#   (2269, 1),
#   (2270, 2),
#   (2271, 1),
#   (2272, 1),
#   (2273, 1),
#   (2274, 1),
#   (2275, 1),
#   (2276, 1),
#   (2277, 1),
#   (2278, 1),
#   (2279, 1),
#   (2280, 1),
#   (2281, 4),
#   (2282, 2),
#   (2283, 4),
#   (2284, 1),
#   (2285, 2),
#   (2286, 1),
#   (2287, 2),
#   (2288, 1),
#   (2289, 4),
#   (2290, 1),
#   (2291, 1),
#   (2292, 2),
#   (2293, 1),
#   (2294, 1),
#   (2295, 1),
#   (2296, 1),
#   (2297, 1),
#   (2298, 1),
#   (2299, 2),
#   (2300, 1),
#   (2301, 1),
#   (2302, 1),
#   (2303, 1),
#   (2304, 1),
#   (2305, 7),
#   (2306, 1),
#   (2307, 1),
#   (2308, 1),
#   (2309, 4),
#   (2310, 3),
#   (2311, 1),
#   (2312, 2),
#   (2313, 1),
#   (2314, 1),
#   (2315, 1),
#   (2316, 1),
#   (2317, 1),
#   (2318, 1),
#   (2319, 1),
#   (2320, 1),
#   (2321, 1),
#   (2322, 1),
#   (2323, 1),
#   (2324, 1),
#   (2325, 7),
#   (2326, 1),
#   (2327, 1),
#   (2328, 1),
#   (2329, 4),
#   (2330, 1),
#   (2331, 1),
#   (2332, 1),
#   (2333, 1),
#   (2334, 1),
#   (2335, 1),
#   (2336, 1),
#   (2337, 1),
#   (2338, 1),
#   (2339, 1),
#   (2340, 1),
#   (2341, 1),
#   (2342, 1),
#   (2343, 1),
#   (2344, 1),
#   (2345, 1),
#   (2346, 7),
#   (2347, 1),
#   (2348, 1),
#   (2349, 1),
#   (2350, 1),
#   (2351, 1),
#   (2352, 1),
#   (2353, 1),
#   (2354, 1)],
#  [(0, 1),
#   (9, 1),
#   (10, 7),
#   (15, 4),
#   (16, 1),
#   (18, 1),
#   (21, 1),
#   (23, 1),
#   (24, 2),
#   (25, 4),
#   (26, 1),
#   (32, 2),
#   (33, 1),
#   (42, 1),
#   (46, 2),
#   (49, 1),
#   (53, 2),
#   (54, 2),
#   (55, 1),
#   (64, 7),
#   (65, 2),
#   (69, 2),
#   (70, 1),
#   (80, 1),
#   (82, 1),
#   (90, 1),
#   (94, 4),
#   (95, 1),
#   (98, 3),
#   (106, 4),
#   (113, 2),
#   (115, 1),
#   (127, 1),
#   (128, 1),
#   (135, 1),
#   (136, 5),
#   (137, 1),
#   (143, 1),
#   (144, 13),
#   (150, 1),
#   (152, 1),
#   (155, 4),
#   (158, 1),
#   (163, 3),
#   (164, 1),
#   (165, 1),
#   (166, 30),
#   (168, 1),
#   (171, 12),
#   (174, 3),
#   (177, 3),
#   (186, 1),
#   (187, 1),
#   (192, 6),
#   (202, 1),
#   (208, 3),
#   (209, 1),
#   (222, 2),
#   (225, 21),
#   (227, 1),
#   (242, 13),
#   (244, 3),
#   (251, 1),
#   (254, 1),
#   (255, 2),
#   (263, 9),
#   (271, 2),
#   (279, 3),
#   (284, 4),
#   (289, 2),
#   (296, 4),
#   (300, 1),
#   (310, 1),
#   (316, 1),
#   (317, 1),
#   (318, 4),
#   (328, 3),
#   (336, 1),
#   (337, 1),
#   (340, 3),
#   (348, 1),
#   (349, 1),
#   (352, 2),
#   (353, 2),
#   (354, 3),
#   (368, 1),
#   (371, 4),
#   (379, 1),
#   (383, 6),
#   (384, 3),
#   (385, 1),
#   (390, 1),
#   (393, 1),
#   (412, 5),
#   (416, 9),
#   (418, 3),
#   (422, 2),
#   (435, 1),
#   (436, 3),
#   (439, 1),
#   (441, 1),
#   (447, 2),
#   (448, 1),
#   (450, 11),
#   (451, 2),
#   (453, 1),
#   (456, 2),
#   (457, 5),
#   (459, 3),
#   (465, 3),
#   (472, 3),
#   (473, 8),
#   (478, 3),
#   (482, 2),
#   (491, 1),
#   (492, 4),
#   (493, 3),
#   (506, 1),
#   (507, 1),
#   (508, 3),
#   (510, 3),
#   (515, 3),
#   (534, 9),
#   (545, 1),
#   (549, 3),
#   (562, 4),
#   (569, 10),
#   (570, 6),
#   (572, 2),
#   (579, 1),
#   (582, 3),
#   (584, 2),
#   (605, 1),
#   (606, 1),
#   (607, 27),
#   (608, 1),
#   (612, 1),
#   (615, 21),
#   (617, 3),
#   (618, 1),
#   (620, 2),
#   (627, 2),
#   (631, 5),
#   (633, 5),
#   (643, 1),
#   (649, 2),
#   (650, 2),
#   (654, 2),
#   (656, 7),
#   (657, 1),
#   (659, 1),
#   (663, 2),
#   (665, 1),
#   (666, 1),
#   (668, 1),
#   (676, 2),
#   (679, 3),
#   (682, 1),
#   (683, 1),
#   (684, 3),
#   (687, 1),
#   (691, 2),
#   (697, 4),
#   (704, 1),
#   (714, 28),
#   (721, 2),
#   (722, 1),
#   (724, 1),
#   (728, 3),
#   (735, 3),
#   (739, 11),
#   (741, 1),
#   (744, 16),
#   (745, 1),
#   (750, 4),
#   (759, 2),
#   (767, 3),
#   (768, 8),
#   (779, 7),
#   (781, 2),
#   (783, 1),
#   (786, 3),
#   (787, 1),
#   (788, 4),
#   (792, 1),
#   (796, 6),
#   (802, 10),
#   (803, 4),
#   (804, 1),
#   (813, 4),
#   (816, 4),
#   (817, 2),
#   (819, 3),
#   (823, 3),
#   (825, 4),
#   (828, 1),
#   (836, 3),
#   (837, 1),
#   (840, 4),
#   (841, 2),
#   (842, 1),
#   (843, 2),
#   (844, 13),
#   (846, 6),
#   (851, 2),
#   (858, 1),
#   (860, 3),
#   (883, 1),
#   (885, 2),
#   (888, 1),
#   (889, 1),
#   (890, 1),
#   (891, 6),
#   (894, 2),
#   (897, 2),
#   (900, 1),
#   (901, 1),
#   (905, 2),
#   (909, 1),
#   (910, 16),
#   (911, 1),
#   (912, 3),
#   (914, 1),
#   (918, 3),
#   (919, 2),
#   (921, 1),
#   (929, 4),
#   (932, 1),
#   (938, 2),
#   (941, 2),
#   (944, 3),
#   (955, 2),
#   (964, 25),
#   (966, 1),
#   (969, 7),
#   (973, 6),
#   (985, 3),
#   (993, 3),
#   (1002, 1),
#   (1004, 1),
#   (1011, 1),
#   (1015, 3),
#   (1020, 4),
#   (1021, 1),
#   (1022, 4),
#   (1024, 8),
#   (1037, 2),
#   (1038, 2),
#   (1040, 1),
#   (1041, 1),
#   (1043, 1),
#   (1045, 24),
#   (1047, 4),
#   (1049, 8),
#   (1051, 6),
#   (1052, 1),
#   (1059, 7),
#   (1064, 2),
#   (1066, 2),
#   (1067, 2),
#   (1068, 1),
#   (1069, 1),
#   (1071, 1),
#   (1072, 6),
#   (1073, 1),
#   (1075, 4),
#   (1077, 1),
#   (1080, 3),
#   (1089, 5),
#   (1090, 8),
#   (1092, 4),
#   (1093, 1),
#   (1095, 4),
#   (1101, 1),
#   (1102, 3),
#   (1104, 6),
#   (1106, 4),
#   (1108, 2),
#   (1109, 1),
#   (1112, 1),
#   (1113, 1),
#   (1119, 1),
#   (1120, 4),
#   (1125, 62),
#   (1129, 1),
#   (1130, 5),
#   (1138, 1),
#   (1140, 1),
#   (1142, 15),
#   (1147, 3),
#   (1152, 5),
#   (1177, 1),
#   (1178, 1),
#   (1182, 1),
#   (1188, 1),
#   (1196, 1),
#   (1210, 9),
#   (1211, 10),
#   (1217, 2),
#   (1218, 1),
#   (1219, 3),
#   (1220, 5),
#   (1224, 1),
#   (1225, 11),
#   (1226, 1),
#   (1229, 1),
#   (1237, 4),
#   (1238, 3),
#   (1239, 3),
#   (1244, 2),
#   (1251, 15),
#   (1252, 2),
#   (1256, 1),
#   (1260, 1),
#   (1262, 2),
#   (1265, 4),
#   (1266, 1),
#   (1269, 4),
#   (1274, 1),
#   (1280, 1),
#   (1286, 2),
#   (1290, 7),
#   (1291, 3),
#   (1292, 5),
#   (1295, 3),
#   (1296, 3),
#   (1297, 2),
#   (1299, 1),
#   (1307, 4),
#   (1311, 2),
#   (1313, 1),
#   (1318, 2),
#   (1326, 1),
#   (1327, 1),
#   (1330, 1),
#   (1335, 3),
#   (1341, 2),
#   (1344, 1),
#   (1350, 1),
#   (1352, 1),
#   (1357, 3),
#   (1359, 1),
#   (1362, 1),
#   (1365, 1),
#   (1373, 2),
#   (1381, 1),
#   (1385, 6),
#   (1396, 6),
#   (1407, 1),
#   (1408, 1),
#   (1411, 1),
#   (1413, 6),
#   (1414, 1),
#   (1417, 1),
#   (1418, 1),
#   (1424, 4),
#   (1435, 2),
#   (1441, 2),
#   (1447, 5),
#   (1450, 1),
#   (1451, 1),
#   (1453, 1),
#   (1454, 1),
#   (1457, 1),
#   (1458, 2),
#   (1465, 3),
#   (1467, 8),
#   (1470, 3),
#   (1475, 1),
#   (1478, 1),
#   (1479, 2),
#   (1481, 5),
#   (1485, 1),
#   (1488, 1),
#   (1494, 1),
#   (1499, 2),
#   (1504, 2),
#   (1510, 1),
#   (1515, 2),
#   (1523, 4),
#   (1525, 1),
#   (1526, 1),
#   (1528, 2),
#   (1533, 4),
#   (1543, 1),
#   (1546, 9),
#   (1552, 1),
#   (1553, 4),
#   (1557, 1),
#   (1562, 1),
#   (1566, 2),
#   (1569, 1),
#   (1572, 5),
#   (1580, 2),
#   (1585, 2),
#   (1593, 1),
#   (1600, 3),
#   (1603, 6),
#   (1608, 1),
#   (1611, 1),
#   (1612, 7),
#   (1617, 5),
#   (1620, 1),
#   (1632, 5),
#   (1634, 40),
#   (1638, 4),
#   (1640, 1),
#   (1647, 5),
#   (1648, 1),
#   (1651, 1),
#   (1653, 4),
#   (1655, 5),
#   (1666, 4),
#   (1668, 4),
#   (1674, 2),
#   (1675, 2),
#   (1676, 2),
#   (1678, 1),
#   (1681, 2),
#   (1686, 2),
#   (1691, 3),
#   (1697, 1),
#   (1703, 3),
#   (1718, 3),
#   (1722, 2),
#   (1729, 2),
#   (1732, 1),
#   (1736, 7),
#   (1737, 2),
#   (1738, 1),
#   (1740, 1),
#   (1742, 1),
#   (1745, 3),
#   (1751, 3),
#   (1753, 1),
#   (1760, 1),
#   (1762, 3),
#   (1763, 4),
#   (1764, 6),
#   (1773, 2),
#   (1779, 21),
#   (1780, 1),
#   (1781, 3),
#   (1786, 3),
#   (1787, 2),
#   (1791, 2),
#   (1792, 1),
#   (1794, 3),
#   (1796, 5),
#   (1800, 4),
#   (1801, 2),
#   (1803, 1),
#   (1804, 2),
#   (1807, 1),
#   (1810, 3),
#   (1822, 1),
#   (1826, 5),
#   (1827, 1),
#   (1831, 3),
#   (1836, 1),
#   (1837, 2),
#   (1840, 1),
#   (1841, 1),
#   (1843, 2),
#   (1852, 4),
#   (1875, 1),
#   (1881, 11),
#   (1884, 59),
#   (1885, 1),
#   (1893, 12),
#   (1895, 18),
#   (1905, 1),
#   (1911, 17),
#   (1921, 5),
#   (1922, 5),
#   (1924, 5),
#   (1932, 1),
#   (1935, 1),
#   (1946, 1),
#   (1947, 2),
#   (1960, 4),
#   (1963, 4),
#   (1964, 1),
#   (1965, 6),
#   (1966, 1),
#   (1979, 2),
#   (1991, 3),
#   (1993, 1),
#   (1996, 2),
#   (2005, 2),
#   (2011, 1),
#   (2012, 3),
#   (2016, 16),
#   (2021, 1),
#   (2022, 1),
#   (2028, 1),
#   (2029, 2),
#   (2030, 2),
#   (2042, 1),
#   (2051, 1),
#   (2053, 1),
#   (2054, 5),
#   (2063, 3),
#   (2065, 15),
#   (2068, 1),
#   (2069, 1),
#   (2071, 5),
#   (2072, 2),
#   (2074, 5),
#   (2076, 7),
#   (2077, 1),
#   (2080, 1),
#   (2084, 14),
#   (2085, 1),
#   (2088, 8),
#   (2095, 4),
#   (2103, 7),
#   (2107, 4),
#   (2109, 2),
#   (2118, 1),
#   (2129, 2),
#   (2134, 4),
#   (2139, 2),
#   (2141, 1),
#   (2144, 2),
#   (2145, 22),
#   (2154, 1),
#   (2159, 2),
#   (2163, 1),
#   (2173, 2),
#   (2176, 1),
#   (2186, 10),
#   (2194, 2),
#   (2200, 1),
#   (2227, 4),
#   (2237, 1),
#   (2241, 2),
#   (2249, 1),
#   (2254, 2),
#   (2267, 1),
#   (2268, 1),
#   (2272, 1),
#   (2274, 5),
#   (2275, 2),
#   (2279, 2),
#   (2291, 1),
#   (2293, 1),
#   (2294, 2),
#   (2295, 1),
#   (2296, 1),
#   (2297, 4),
#   (2299, 1),
#   (2304, 2),
#   (2307, 1),
#   (2309, 2),
#   (2312, 1),
#   (2315, 1),
#   (2328, 2),
#   (2341, 1),
#   (2350, 1),
#   (2351, 1),
#   (2355, 2),
#   (2356, 1),
#   (2357, 1),
#   (2358, 1),
#   (2359, 1),
#   (2360, 1),
#   (2361, 1),
#   (2362, 1),
#   (2363, 2),
#   (2364, 1),
#   (2365, 1),
#   (2366, 1),
#   (2367, 1),
#   (2368, 3),
#   (2369, 2),
#   (2370, 1),
#   (2371, 1),
#   (2372, 1),
#   (2373, 1),
#   (2374, 1),
#   (2375, 3),
#   (2376, 1),
#   (2377, 1),
#   (2378, 8),
#   (2379, 1),
#   (2380, 1),
#   (2381, 1),
#   (2382, 1),
#   (2383, 1),
#   (2384, 1),
#   (2385, 1),
#   (2386, 4),
#   (2387, 1),
#   (2388, 1),
#   (2389, 1),
#   (2390, 3),
#   (2391, 1),
#   (2392, 1),
#   (2393, 1),
#   (2394, 1),
#   (2395, 1),
#   (2396, 5),
#   (2397, 1),
#   (2398, 1),
#   (2399, 1),
#   (2400, 6),
#   (2401, 1),
#   (2402, 1),
#   (2403, 1),
#   (2404, 3),
#   (2405, 1),
#   (2406, 65),
#   (2407, 2),
#   (2408, 1),
#   (2409, 5),
#   (2410, 66),
#   (2411, 1),
#   (2412, 3),
#   (2413, 20),
#   (2414, 1),
#   (2415, 2),
#   (2416, 1),
#   (2417, 1),
#   (2418, 1),
#   (2419, 1),
#   (2420, 1),
#   (2421, 3),
#   (2422, 1),
#   (2423, 1),
#   (2424, 1),
#   (2425, 1),
#   (2426, 1),
#   (2427, 1),
#   (2428, 1),
#   (2429, 7),
#   (2430, 1),
#   (2431, 30),
#   (2432, 38),
#   (2433, 11),
#   (2434, 3),
#   (2435, 2),
#   (2436, 1),
#   (2437, 1),
#   (2438, 1),
#   (2439, 1),
#   (2440, 1),
#   (2441, 1),
#   (2442, 1),
#   (2443, 1),
#   (2444, 3),
#   (2445, 1),
#   (2446, 1),
#   (2447, 1),
#   (2448, 1),
#   (2449, 1),
#   (2450, 1),
#   (2451, 2),
#   (2452, 13),
#   (2453, 1),
#   (2454, 2),
#   (2455, 1),
#   (2456, 3),
#   (2457, 1),
#   (2458, 1),
#   (2459, 1),
#   (2460, 6),
#   (2461, 1),
#   (2462, 2),
#   (2463, 1),
#   (2464, 2),
#   (2465, 8),
#   (2466, 1),
#   (2467, 1),
#   (2468, 1),
#   (2469, 2),
#   (2470, 1),
#   (2471, 1),
#   (2472, 3),
#   (2473, 1),
#   (2474, 18),
#   (2475, 4),
#   (2476, 1),
#   (2477, 3),
#   (2478, 24),
#   (2479, 3),
#   (2480, 1),
#   (2481, 6),
#   (2482, 1),
#   (2483, 3),
#   (2484, 1),
#   (2485, 1),
#   (2486, 1),
#   (2487, 1),
#   (2488, 2),
#   (2489, 2),
#   (2490, 2),
#   (2491, 1),
#   (2492, 1),
#   (2493, 11),
#   (2494, 2),
#   (2495, 1),
#   (2496, 1),
#   (2497, 1),
#   (2498, 1),
#   (2499, 3),
#   (2500, 1),
#   (2501, 2),
#   (2502, 1),
#   (2503, 1),
#   (2504, 1),
#   (2505, 2),
#   (2506, 1),
#   (2507, 2),
#   (2508, 1),
#   (2509, 1),
#   (2510, 1),
#   (2511, 2),
#   (2512, 1),
#   (2513, 1),
#   (2514, 14),
#   (2515, 1),
#   (2516, 1),
#   (2517, 5),
#   (2518, 17),
#   (2519, 1),
#   (2520, 1),
#   (2521, 133),
#   (2522, 2),
#   (2523, 7),
#   (2524, 1),
#   (2525, 1),
#   (2526, 1),
#   (2527, 1),
#   (2528, 1),
#   (2529, 1),
#   (2530, 1),
#   (2531, 1),
#   (2532, 1),
#   (2533, 3),
#   (2534, 1),
#   (2535, 2),
#   (2536, 4),
#   (2537, 1),
#   (2538, 2),
#   (2539, 1),
#   (2540, 1),
#   (2541, 1),
#   (2542, 2),
#   (2543, 1),
#   (2544, 1),
#   (2545, 1),
#   (2546, 1),
#   (2547, 2),
#   (2548, 2),
#   (2549, 1),
#   (2550, 1),
#   (2551, 3),
#   (2552, 1),
#   (2553, 2),
#   (2554, 1),
#   (2555, 1),
#   (2556, 1),
#   (2557, 1),
#   (2558, 1),
#   (2559, 1),
#   (2560, 1),
#   (2561, 1),
#   (2562, 1),
#   (2563, 3),
#   (2564, 2),
#   (2565, 1),
#   (2566, 2),
#   (2567, 1),
#   (2568, 2),
#   (2569, 1),
#   (2570, 1),
#   (2571, 1),
#   (2572, 3),
#   (2573, 1),
#   (2574, 2),
#   (2575, 1),
#   (2576, 7),
#   (2577, 2),
#   (2578, 1),
#   (2579, 1),
#   (2580, 1),
#   (2581, 1),
#   (2582, 1),
#   (2583, 1),
#   (2584, 1),
#   (2585, 1),
#   (2586, 1),
#   (2587, 1),
#   (2588, 1),
#   (2589, 1),
#   (2590, 3),
#   (2591, 1),
#   (2592, 1),
#   (2593, 2),
#   (2594, 3),
#   (2595, 1),
#   (2596, 1),
#   (2597, 1),
#   (2598, 2),
#   (2599, 1),
#   (2600, 1),
#   (2601, 1),
#   (2602, 7),
#   (2603, 10),
#   (2604, 1),
#   (2605, 1),
#   (2606, 1),
#   (2607, 1),
#   (2608, 1),
#   (2609, 1),
#   (2610, 1),
#   (2611, 1),
#   (2612, 1),
#   (2613, 1),
#   (2614, 1),
#   (2615, 1),
#   (2616, 1),
#   (2617, 2),
#   (2618, 2),
#   (2619, 1),
#   (2620, 1),
#   (2621, 1),
#   (2622, 1),
#   (2623, 1),
#   (2624, 1),
#   (2625, 5),
#   (2626, 1),
#   (2627, 1),
#   (2628, 1),
#   (2629, 1),
#   (2630, 1),
#   (2631, 2),
#   (2632, 4),
#   (2633, 1),
#   (2634, 1),
#   (2635, 1),
#   (2636, 1),
#   (2637, 1),
#   (2638, 2),
#   (2639, 1),
#   (2640, 11),
#   (2641, 10),
#   (2642, 1),
#   (2643, 3),
#   (2644, 1),
#   (2645, 1),
#   (2646, 3),
#   (2647, 2),
#   (2648, 2),
#   (2649, 1),
#   (2650, 1),
#   (2651, 1),
#   (2652, 1),
#   (2653, 1),
#   (2654, 5),
#   (2655, 1),
#   (2656, 1),
#   (2657, 2),
#   (2658, 5),
#   (2659, 2),
#   (2660, 1),
#   (2661, 7),
#   (2662, 1),
#   (2663, 1),
#   (2664, 1),
#   (2665, 1),
#   (2666, 1),
#   (2667, 3),
#   (2668, 32),
#   (2669, 3),
#   (2670, 1),
#   (2671, 4),
#   (2672, 1),
#   (2673, 2),
#   (2674, 2),
#   (2675, 1),
#   (2676, 2),
#   (2677, 1),
#   (2678, 5),
#   (2679, 1),
#   (2680, 1),
#   (2681, 2),
#   (2682, 1),
#   (2683, 3),
#   (2684, 2),
#   (2685, 2),
#   (2686, 3),
#   (2687, 1),
#   (2688, 1),
#   (2689, 1),
#   (2690, 4),
#   (2691, 1),
#   (2692, 1),
#   (2693, 2),
#   (2694, 1),
#   (2695, 1),
#   (2696, 2),
#   (2697, 1),
#   (2698, 2),
#   (2699, 1),
#   (2700, 1),
#   (2701, 1),
#   (2702, 1),
#   (2703, 1),
#   (2704, 1),
#   (2705, 1),
#   (2706, 4),
#   (2707, 1),
#   (2708, 1),
#   (2709, 1),
#   (2710, 2),
#   (2711, 8),
#   (2712, 5),
#   (2713, 1),
#   (2714, 1),
#   (2715, 1),
#   (2716, 1),
#   (2717, 1),
#   (2718, 18),
#   (2719, 6),
#   (2720, 1),
#   (2721, 1),
#   (2722, 1),
#   (2723, 4),
#   (2724, 1),
#   (2725, 2),
#   (2726, 3),
#   (2727, 1),
#   (2728, 1),
#   (2729, 1),
#   (2730, 2),
#   (2731, 14),
#   (2732, 22),
#   (2733, 1),
#   (2734, 3),
#   (2735, 1),
#   (2736, 1),
#   (2737, 1),
#   (2738, 12),
#   (2739, 1),
#   (2740, 2),
#   (2741, 1),
#   (2742, 1),
#   (2743, 1),
#   (2744, 1),
#   (2745, 3),
#   (2746, 1),
#   (2747, 1),
#   (2748, 1),
#   (2749, 1),
#   (2750, 1),
#   (2751, 1),
#   (2752, 1),
#   (2753, 1),
#   (2754, 1),
#   (2755, 1),
#   (2756, 3),
#   (2757, 1),
#   (2758, 1),
#   (2759, 2),
#   (2760, 1),
#   (2761, 1),
#   (2762, 1),
#   (2763, 1),
#   (2764, 1),
#   (2765, 1),
#   (2766, 1),
#   (2767, 1),
#   (2768, 1),
#   (2769, 1),
#   (2770, 1),
#   (2771, 2),
#   (2772, 2),
#   (2773, 3),
#   (2774, 3),
#   (2775, 9),
#   (2776, 4),
#   (2777, 1),
#   (2778, 1),
#   (2779, 1),
#   (2780, 21),
#   (2781, 1),
#   (2782, 1),
#   (2783, 1),
#   (2784, 1),
#   (2785, 4),
#   (2786, 1),
#   (2787, 1),
#   (2788, 4),
#   (2789, 1),
#   (2790, 1),
#   (2791, 3),
#   (2792, 1),
#   (2793, 6),
#   ...],
#  [(10, 2),
#   (11, 1),
#   (21, 2),
#   (24, 1),
#   (25, 2),
#   (26, 1),
#   (46, 1),
#   (55, 2),
#   (64, 2),
#   (79, 1),
#   (80, 1),
#   (83, 1),
#   (95, 2),
#   (98, 1),
#   (102, 3),
#   (103, 1),
#   (105, 1),
#   (106, 9),
#   (111, 1),
#   (113, 2),
#   (115, 1),
#   (117, 1),
#   (127, 1),
#   (129, 1),
#   (131, 1),
#   (135, 2),
#   (143, 1),
#   (159, 2),
#   (162, 9),
#   (163, 2),
#   (165, 2),
#   (168, 1),
#   (177, 3),
#   (186, 3),
#   (192, 1),
#   (196, 1),
#   (197, 2),
#   (206, 2),
#   (208, 2),
#   (214, 14),
#   (215, 25),
#   (225, 6),
#   (242, 2),
#   (244, 2),
#   (254, 3),
#   (255, 5),
#   (263, 2),
#   (271, 1),
#   (273, 1),
#   (277, 1),
#   (280, 1),
#   (282, 2),
#   (283, 3),
#   (284, 10),
#   (289, 1),
#   (291, 1),
#   (296, 1),
#   (298, 1),
#   (309, 2),
#   (318, 4),
#   (321, 2),
#   (325, 3),
#   (328, 1),
#   (340, 8),
#   (341, 1),
#   (348, 1),
#   (354, 1),
#   (365, 1),
#   (375, 7),
#   (376, 10),
#   (384, 2),
#   (385, 1),
#   (386, 2),
#   (388, 2),
#   (391, 4),
#   (409, 4),
#   (416, 1),
#   (418, 2),
#   (421, 5),
#   (428, 1),
#   (436, 4),
#   (440, 1),
#   (447, 1),
#   (450, 4),
#   (454, 3),
#   (459, 2),
#   (460, 3),
#   (471, 2),
#   (477, 1),
#   (482, 3),
#   (484, 1),
#   (487, 1),
#   (506, 1),
#   (507, 1),
#   (511, 1),
#   (534, 2),
#   (545, 3),
#   (548, 2),
#   (551, 1),
#   (553, 1),
#   (569, 6),
#   (572, 1),
#   (582, 1),
#   (584, 1),
#   (587, 1),
#   (595, 1),
#   (600, 1),
#   (607, 4),
#   (618, 1),
#   (620, 2),
#   (621, 1),
#   (623, 1),
#   (631, 1),
#   (635, 5),
#   (643, 2),
#   (650, 2),
#   (654, 4),
#   (656, 2),
#   (663, 3),
#   (676, 1),
#   (678, 1),
#   (679, 1),
#   (682, 7),
#   (691, 3),
#   (692, 2),
#   (695, 2),
#   (704, 4),
#   (705, 2),
#   (716, 1),
#   (722, 4),
#   (724, 2),
#   (734, 2),
#   (741, 2),
#   (742, 1),
#   (744, 8),
#   (745, 2),
#   (752, 2),
#   (756, 1),
#   (767, 1),
#   (774, 3),
#   (779, 1),
#   (786, 1),
#   (788, 1),
#   (791, 5),
#   (796, 1),
#   (802, 2),
#   (803, 1),
#   (834, 2),
#   (836, 1),
#   (838, 3),
#   (840, 5),
#   (843, 1),
#   (846, 3),
#   (860, 1),
#   (861, 7),
#   (883, 2),
#   (885, 2),
#   (891, 1),
#   (900, 1),
#   (910, 10),
#   (912, 1),
#   (918, 15),
#   (919, 8),
#   (920, 1),
#   (936, 1),
#   (937, 1),
#   (941, 2),
#   (946, 1),
#   (952, 1),
#   (969, 1),
#   (973, 1),
#   (981, 4),
#   (986, 1),
#   (991, 2),
#   (1011, 1),
#   (1018, 1),
#   (1024, 1),
#   (1032, 1),
#   (1035, 2),
#   (1037, 1),
#   (1038, 12),
#   (1040, 1),
#   (1041, 2),
#   (1047, 1),
#   (1048, 2),
#   (1059, 6),
#   (1066, 4),
#   (1067, 3),
#   (1072, 2),
#   (1073, 1),
#   (1075, 2),
#   (1076, 1),
#   (1089, 1),
#   (1090, 3),
#   (1095, 4),
#   (1106, 1),
#   (1108, 2),
#   (1110, 1),
#   (1120, 1),
#   (1121, 1),
#   (1126, 4),
#   (1130, 4),
#   (1132, 2),
#   (1138, 1),
#   (1142, 1),
#   (1160, 2),
#   (1182, 3),
#   (1183, 2),
#   (1187, 11),
#   (1202, 1),
#   (1211, 2),
#   (1217, 2),
#   (1218, 1),
#   (1220, 1),
#   (1225, 5),
#   (1239, 2),
#   (1240, 1),
#   (1244, 1),
#   (1248, 2),
#   (1251, 1),
#   (1262, 1),
#   (1265, 3),
#   (1268, 1),
#   (1280, 6),
#   (1290, 3),
#   (1295, 2),
#   (1296, 1),
#   (1297, 1),
#   (1302, 2),
#   (1306, 1),
#   (1318, 1),
#   (1326, 1),
#   (1327, 4),
#   (1333, 2),
#   (1334, 2),
#   (1335, 1),
#   (1350, 1),
#   (1357, 4),
#   (1361, 6),
#   (1364, 2),
#   (1368, 2),
#   (1373, 1),
#   (1385, 5),
#   (1386, 3),
#   (1396, 2),
#   (1404, 1),
#   (1412, 1),
#   (1414, 1),
#   (1418, 1),
#   (1422, 1),
#   (1425, 1),
#   (1426, 3),
#   (1441, 1),
#   (1447, 1),
#   (1453, 2),
#   (1456, 1),
#   (1473, 1),
#   (1485, 3),
#   (1506, 1),
#   (1523, 7),
#   (1528, 1),
#   (1533, 2),
#   (1539, 3),
#   (1540, 2),
#   (1544, 1),
#   (1546, 1),
#   (1549, 2),
#   (1552, 1),
#   (1553, 2),
#   (1554, 5),
#   (1556, 1),
#   (1562, 2),
#   (1566, 1),
#   (1568, 1),
#   (1572, 2),
#   (1575, 1),
#   (1579, 1),
#   (1580, 2),
#   (1597, 2),
#   (1612, 1),
#   (1617, 1),
#   (1647, 3),
#   (1658, 1),
#   (1662, 4),
#   (1668, 1),
#   (1674, 3),
#   (1686, 1),
#   (1691, 1),
#   (1697, 3),
#   (1703, 1),
#   (1722, 1),
#   (1728, 2),
#   (1730, 1),
#   (1732, 1),
#   (1738, 6),
#   (1741, 1),
#   (1747, 5),
#   (1751, 1),
#   (1760, 1),
#   (1762, 2),
#   (1763, 5),
#   (1769, 2),
#   (1773, 1),
#   (1784, 1),
#   (1786, 2),
#   (1787, 1),
#   (1792, 1),
#   (1794, 1),
#   (1796, 2),
#   (1800, 5),
#   (1805, 1),
#   (1815, 1),
#   (1824, 1),
#   (1832, 1),
#   (1837, 1),
#   (1841, 6),
#   (1849, 2),
#   (1852, 4),
#   (1858, 3),
#   (1875, 2),
#   (1878, 2),
#   (1881, 5),
#   (1884, 1),
#   (1888, 1),
#   (1891, 7),
#   (1901, 6),
#   (1905, 1),
#   (1908, 2),
#   (1911, 4),
#   (1921, 1),
#   (1925, 4),
#   (1926, 4),
#   (1935, 6),
#   (1936, 1),
#   (1944, 2),
#   (1947, 5),
#   (1949, 1),
#   (1958, 1),
#   (1963, 3),
#   (1965, 1),
#   (1989, 1),
#   (2012, 5),
#   (2022, 1),
#   (2039, 1),
#   (2042, 3),
#   (2043, 1),
#   (2049, 1),
#   (2054, 1),
#   (2061, 5),
#   (2067, 1),
#   (2069, 1),
#   (2071, 1),
#   (2074, 3),
#   (2080, 2),
#   (2082, 1),
#   (2084, 1),
#   (2085, 8),
#   (2086, 2),
#   (2088, 9),
#   (2095, 3),
#   (2103, 11),
#   (2110, 1),
#   (2126, 4),
#   (2137, 1),
#   (2139, 1),
#   (2145, 7),
#   (2154, 18),
#   (2172, 1),
#   (2173, 19),
#   (2178, 1),
#   (2182, 1),
#   (2186, 1),
#   (2202, 1),
#   (2221, 3),
#   (2232, 1),
#   (2237, 1),
#   (2253, 1),
#   (2254, 1),
#   (2267, 1),
#   (2270, 2),
#   (2277, 1),
#   (2294, 1),
#   (2296, 1),
#   (2301, 2),
#   (2314, 1),
#   (2328, 1),
#   (2333, 2),
#   (2339, 1),
#   (2350, 1),
#   (2368, 1),
#   (2370, 1),
#   (2387, 1),
#   (2394, 2),
#   (2400, 2),
#   (2401, 2),
#   (2405, 1),
#   (2420, 1),
#   (2426, 2),
#   (2434, 2),
#   (2455, 1),
#   (2456, 1),
#   (2479, 1),
#   (2487, 1),
#   (2488, 1),
#   (2496, 3),
#   (2498, 2),
#   (2503, 1),
#   (2508, 6),
#   (2517, 6),
#   (2539, 1),
#   (2541, 1),
#   (2544, 2),
#   (2553, 2),
#   (2563, 1),
#   (2566, 3),
#   (2577, 1),
#   (2592, 1),
#   (2594, 1),
#   (2597, 2),
#   (2598, 3),
#   (2611, 2),
#   (2618, 1),
#   (2632, 1),
#   (2634, 2),
#   (2635, 2),
#   (2642, 2),
#   (2643, 1),
#   (2656, 1),
#   (2670, 1),
#   (2707, 2),
#   (2710, 1),
#   (2717, 1),
#   (2721, 1),
#   (2734, 1),
#   (2737, 7),
#   (2748, 3),
#   (2767, 2),
#   (2776, 1),
#   (2781, 2),
#   (2785, 3),
#   (2788, 8),
#   (2806, 4),
#   (2815, 1),
#   (2816, 3),
#   (2819, 1),
#   (2825, 1),
#   (2843, 1),
#   (2860, 2),
#   (2861, 1),
#   (2870, 1),
#   (2871, 1),
#   (2891, 2),
#   (2896, 2),
#   (2910, 1),
#   (2918, 1),
#   (2926, 2),
#   (2929, 3),
#   (2938, 1),
#   (2942, 1),
#   (2943, 1),
#   (2954, 1),
#   (2982, 3),
#   (2983, 1),
#   (2990, 7),
#   (2995, 1),
#   (3002, 7),
#   (3005, 5),
#   (3008, 1),
#   (3014, 6),
#   (3020, 1),
#   (3040, 1),
#   (3056, 4),
#   (3058, 1),
#   (3089, 1),
#   (3104, 5),
#   (3108, 2),
#   (3114, 2),
#   (3125, 1),
#   (3136, 3),
#   (3140, 1),
#   (3163, 1),
#   (3166, 1),
#   (3172, 2),
#   (3175, 2),
#   (3176, 1),
#   (3177, 2),
#   (3178, 2),
#   (3179, 1),
#   (3180, 2),
#   (3181, 1),
#   (3182, 1),
#   (3183, 1),
#   (3184, 2),
#   (3185, 1),
#   (3186, 1),
#   (3187, 1),
#   (3188, 1),
#   (3189, 7),
#   (3190, 1),
#   (3191, 2),
#   (3192, 1),
#   (3193, 1),
#   (3194, 1),
#   (3195, 3),
#   (3196, 1),
#   (3197, 1),
#   (3198, 1),
#   (3199, 1),
#   (3200, 1),
#   (3201, 1),
#   (3202, 1),
#   (3203, 1),
#   (3204, 1),
#   (3205, 4),
#   (3206, 3),
#   (3207, 1),
#   (3208, 1),
#   (3209, 2),
#   (3210, 7),
#   (3211, 4),
#   (3212, 1),
#   (3213, 1),
#   (3214, 1),
#   (3215, 2),
#   (3216, 1),
#   (3217, 1),
#   (3218, 1),
#   (3219, 3),
#   (3220, 1),
#   (3221, 1),
#   (3222, 1),
#   (3223, 1),
#   (3224, 1),
#   (3225, 1),
#   (3226, 1),
#   (3227, 1),
#   (3228, 2),
#   (3229, 1),
#   (3230, 6),
#   (3231, 1),
#   (3232, 1),
#   (3233, 1),
#   (3234, 2),
#   (3235, 1),
#   (3236, 2),
#   (3237, 1),
#   (3238, 1),
#   (3239, 1),
#   (3240, 1),
#   (3241, 1),
#   (3242, 1),
#   (3243, 1),
#   (3244, 1),
#   (3245, 3),
#   (3246, 1),
#   (3247, 1),
#   (3248, 1),
#   (3249, 1),
#   (3250, 4),
#   (3251, 7),
#   (3252, 1),
#   (3253, 1),
#   (3254, 1),
#   (3255, 1),
#   (3256, 1),
#   (3257, 2),
#   (3258, 1),
#   (3259, 1),
#   (3260, 1),
#   (3261, 1),
#   (3262, 1),
#   (3263, 1),
#   (3264, 1),
#   (3265, 1),
#   (3266, 1),
#   (3267, 1),
#   (3268, 3),
#   (3269, 8),
#   (3270, 1),
#   (3271, 1),
#   (3272, 1),
#   (3273, 1),
#   (3274, 2),
#   (3275, 6),
#   (3276, 1),
#   (3277, 6),
#   (3278, 1),
#   (3279, 8),
#   (3280, 3),
#   (3281, 1),
#   (3282, 4),
#   (3283, 1),
#   (3284, 5),
#   (3285, 1),
#   (3286, 1),
#   (3287, 1),
#   (3288, 1),
#   (3289, 1),
#   (3290, 1),
#   (3291, 1),
#   (3292, 1),
#   (3293, 1),
#   (3294, 1),
#   (3295, 1),
#   (3296, 1),
#   (3297, 1),
#   (3298, 1),
#   (3299, 2),
#   (3300, 2),
#   (3301, 2),
#   (3302, 1),
#   (3303, 1),
#   (3304, 1),
#   (3305, 3),
#   (3306, 1),
#   (3307, 2),
#   (3308, 1),
#   (3309, 1),
#   (3310, 1),
#   (3311, 1),
#   (3312, 7),
#   (3313, 5),
#   (3314, 1),
#   (3315, 7),
#   (3316, 1),
#   (3317, 2),
#   (3318, 1),
#   (3319, 1),
#   (3320, 1),
#   (3321, 1),
#   (3322, 1),
#   (3323, 1),
#   (3324, 1),
#   (3325, 1),
#   (3326, 1),
#   (3327, 2),
#   (3328, 1),
#   (3329, 1),
#   (3330, 1),
#   (3331, 1),
#   (3332, 1),
#   (3333, 1),
#   (3334, 1),
#   (3335, 1),
#   (3336, 1),
#   (3337, 1),
#   (3338, 1),
#   (3339, 1),
#   (3340, 2),
#   (3341, 1),
#   (3342, 1),
#   (3343, 1),
#   (3344, 18),
#   (3345, 1),
#   (3346, 1),
#   (3347, 1),
#   (3348, 2),
#   (3349, 1),
#   (3350, 1),
#   (3351, 1),
#   (3352, 1),
#   (3353, 1),
#   (3354, 1),
#   (3355, 4),
#   (3356, 1),
#   (3357, 1),
#   (3358, 7),
#   (3359, 1),
#   (3360, 1),
#   (3361, 1),
#   (3362, 5),
#   (3363, 1),
#   (3364, 1),
#   (3365, 1),
#   (3366, 1),
#   (3367, 1),
#   (3368, 1),
#   (3369, 2),
#   (3370, 1),
#   (3371, 1),
#   (3372, 1),
#   (3373, 1),
#   (3374, 1),
#   (3375, 1),
#   (3376, 1),
#   (3377, 1),
#   (3378, 1),
#   (3379, 5),
#   (3380, 1),
#   (3381, 1),
#   (3382, 1),
#   (3383, 2),
#   (3384, 1),
#   (3385, 1),
#   (3386, 7),
#   (3387, 1),
#   (3388, 3),
#   (3389, 1),
#   (3390, 2),
#   (3391, 3),
#   (3392, 1),
#   (3393, 1),
#   (3394, 1),
#   (3395, 1),
#   (3396, 2),
#   (3397, 1),
#   (3398, 1),
#   (3399, 3),
#   (3400, 1),
#   (3401, 1),
#   (3402, 3),
#   (3403, 4),
#   (3404, 1),
#   (3405, 1),
#   (3406, 1),
#   (3407, 25),
#   (3408, 2),
#   (3409, 4),
#   (3410, 1),
#   (3411, 1),
#   (3412, 1),
#   (3413, 1),
#   (3414, 5),
#   (3415, 1),
#   (3416, 3),
#   (3417, 1),
#   (3418, 1),
#   (3419, 3),
#   (3420, 1),
#   (3421, 1),
#   (3422, 2),
#   (3423, 1),
#   (3424, 1),
#   (3425, 1),
#   (3426, 1),
#   (3427, 1),
#   (3428, 1),
#   (3429, 1),
#   (3430, 2),
#   (3431, 1),
#   (3432, 1),
#   (3433, 3),
#   (3434, 1),
#   (3435, 1),
#   (3436, 1),
#   (3437, 1),
#   (3438, 1),
#   (3439, 1),
#   (3440, 1),
#   (3441, 1),
#   (3442, 1),
#   (3443, 1),
#   (3444, 2),
#   (3445, 1),
#   (3446, 5),
#   (3447, 1),
#   (3448, 1),
#   (3449, 1),
#   (3450, 1),
#   (3451, 1),
#   (3452, 1),
#   (3453, 1),
#   (3454, 1),
#   (3455, 1),
#   (3456, 1),
#   (3457, 1),
#   (3458, 1),
#   (3459, 2),
#   (3460, 11),
#   (3461, 3),
#   (3462, 2),
#   (3463, 5),
#   (3464, 1),
#   (3465, 3),
#   (3466, 3),
#   (3467, 1),
#   (3468, 3),
#   (3469, 1),
#   (3470, 1),
#   (3471, 1),
#   (3472, 1),
#   (3473, 2),
#   (3474, 1),
#   (3475, 2),
#   (3476, 1),
#   (3477, 1),
#   (3478, 1),
#   (3479, 2),
#   (3480, 1),
#   (3481, 1),
#   (3482, 1),
#   (3483, 1),
#   (3484, 2),
#   (3485, 4),
#   (3486, 2),
#   (3487, 1),
#   (3488, 1),
#   (3489, 1),
#   (3490, 1),
#   (3491, 1),
#   (3492, 2),
#   (3493, 1),
#   (3494, 1),
#   (3495, 1),
#   (3496, 5),
#   (3497, 1),
#   (3498, 2),
#   (3499, 1),
#   (3500, 1),
#   (3501, 2),
#   (3502, 1),
#   (3503, 1),
#   (3504, 3),
#   (3505, 1),
#   (3506, 1),
#   (3507, 2),
#   (3508, 1),
#   (3509, 2),
#   (3510, 1),
#   (3511, 1),
#   (3512, 2),
#   (3513, 1),
#   (3514, 2),
#   (3515, 1),
#   (3516, 1),
#   (3517, 1),
#   (3518, 1),
#   (3519, 3),
#   (3520, 1),
#   (3521, 1),
#   (3522, 1),
#   (3523, 1),
#   (3524, 1),
#   (3525, 1),
#   (3526, 2),
#   (3527, 1),
#   (3528, 1),
#   (3529, 1),
#   (3530, 1),
#   (3531, 19),
#   (3532, 1),
#   (3533, 4),
#   (3534, 1),
#   (3535, 1),
#   (3536, 10),
#   (3537, 1),
#   (3538, 1),
#   (3539, 1),
#   (3540, 7),
#   (3541, 2),
#   (3542, 1),
#   (3543, 1),
#   (3544, 1),
#   (3545, 8),
#   (3546, 2),
#   (3547, 1),
#   (3548, 1),
#   (3549, 1),
#   (3550, 1),
#   (3551, 6),
#   (3552, 1),
#   (3553, 3),
#   (3554, 1),
#   (3555, 5),
#   (3556, 1),
#   (3557, 3),
#   (3558, 1),
#   (3559, 19),
#   (3560, 1),
#   (3561, 4),
#   (3562, 6),
#   (3563, 1),
#   (3564, 1),
#   (3565, 1),
#   (3566, 2),
#   (3567, 1),
#   (3568, 1),
#   (3569, 3),
#   (3570, 1),
#   (3571, 2),
#   (3572, 1),
#   (3573, 1),
#   (3574, 2),
#   (3575, 1),
#   (3576, 3),
#   (3577, 1),
#   (3578, 1),
#   (3579, 1),
#   (3580, 1),
#   (3581, 1),
#   (3582, 1),
#   (3583, 2),
#   (3584, 1),
#   (3585, 1),
#   (3586, 1),
#   (3587, 4),
#   (3588, 1),
#   (3589, 1),
#   (3590, 1),
#   (3591, 1),
#   (3592, 1),
#   (3593, 1),
#   (3594, 2),
#   (3595, 4),
#   (3596, 4),
#   (3597, 1),
#   (3598, 1),
#   (3599, 1),
#   (3600, 1),
#   (3601, 1),
#   (3602, 2),
#   (3603, 1),
#   (3604, 2),
#   (3605, 1),
#   (3606, 2),
#   (3607, 1),
#   (3608, 1),
#   (3609, 1),
#   (3610, 2),
#   (3611, 1),
#   (3612, 1),
#   (3613, 5),
#   (3614, 1),
#   (3615, 1),
#   (3616, 5),
#   (3617, 1),
#   (3618, 1),
#   (3619, 3),
#   (3620, 3),
#   (3621, 1),
#   (3622, 2),
#   (3623, 1),
#   (3624, 6),
#   (3625, 1),
#   (3626, 1),
#   (3627, 1),
#   (3628, 1),
#   (3629, 1),
#   (3630, 1),
#   (3631, 1),
#   (3632, 3),
#   (3633, 3),
#   (3634, 1),
#   (3635, 1),
#   (3636, 1),
#   (3637, 1),
#   (3638, 1),
#   (3639, 1),
#   (3640, 2),
#   (3641, 1),
#   (3642, 1),
#   (3643, 1),
#   (3644, 1),
#   (3645, 1),
#   (3646, 1),
#   (3647, 1),
#   (3648, 1),
#   (3649, 3),
#   (3650, 1),
#   (3651, 1),
#   (3652, 1),
#   (3653, 1),
#   (3654, 1),
#   (3655, 1),
#   (3656, 2),
#   (3657, 1),
#   (3658, 1),
#   (3659, 1),
#   (3660, 1),
#   (3661, 1),
#   (3662, 2),
#   (3663, 1),
#   (3664, 1),
#   (3665, 1),
#   (3666, 1),
#   (3667, 1),
#   (3668, 11),
#   (3669, 1),
#   (3670, 2),
#   (3671, 1),
#   (3672, 1),
#   (3673, 1),
#   (3674, 2),
#   (3675, 1),
#   (3676, 1),
#   (3677, 1),
#   (3678, 1),
#   (3679, 4),
#   (3680, 1),
#   (3681, 1),
#   (3682, 1),
#   (3683, 4),
#   (3684, 6),
#   (3685, 1),
#   (3686, 1),
#   (3687, 1),
#   (3688, 3),
#   (3689, 2),
#   (3690, 1),
#   (3691, 1),
#   ...]]

# %%
ldamodel = LdaModel(corpus=corpus, num_topics=4, id2word=dictionary, passes=20)

# %%
topics=ldamodel.print_topics(num_words=10)
topics
# Out:
# [(0,
#   '0.018*"datum" + 0.012*"data_science" + 0.010*"statistic" + 0.010*"data" + 0.010*"datum_science" + 0.007*"field" + 0.005*"analysis" + 0.005*"business" + 0.005*"science" + 0.005*"machine_learning"'),
#  (1,
#   '0.013*"taj_mahal" + 0.011*"tomb" + 0.008*"building" + 0.008*"garden" + 0.007*"shah_jahan" + 0.006*"design" + 0.006*"marble" + 0.006*"mughal" + 0.005*"complex" + 0.005*"dome"'),
#  (2,
#   '0.011*"cricket" + 0.008*"case" + 0.006*"country" + 0.006*"report" + 0.006*"batsman" + 0.005*"ball" + 0.005*"match" + 0.005*"people" + 0.005*"march" + 0.005*"outbreak"'),
#  (3,
#   '0.000*"cricket" + 0.000*"play" + 0.000*"case" + 0.000*"batsman" + 0.000*"match" + 0.000*"ball" + 0.000*"team" + 0.000*"include" + 0.000*"wicket" + 0.000*"bowler"')]

# %%
sent='pretty Great Structures were built in the times of Mughals. They were very beautiful'
cleaned_sent=clean(sent)
doc_sent=nlp(cleaned_sent)
article_sent = []
for w in doc_sent:
    # if it's not a stop word or punctuation mark, add it to our article
    if not w.is_stop and not w.is_punct and not w.like_num:
        # we add the lematized version of the word
        article_sent.append(w.lemma_)
text_sent=article_sent

# %%
# text_sent = [bigram[line] for line in text_sent]
text_sent=dictionary.doc2bow(text_sent)

# %%
text_sent
# Out:
# [(214, 1), (796, 1), (1911, 1), (3056, 1), (3559, 1)]

# %%
ldamodel.get_document_topics(text_sent)
# Out:
# [(0, 0.04189828), (1, 0.8679399), (2, 0.04843729), (3, 0.04172455)]
